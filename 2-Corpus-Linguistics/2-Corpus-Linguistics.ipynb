# %% [markdown]
# # Week 2 - Corpus Linguistics
#
# This week, we take text corpora that we have developed, spidered, scraped, and encoded, and we find and count words and simple phrases and properties of those counts (e.g., word frequency distributions). Initially, we model how to search corpora for keywords or phrases. Next, we examine the distributions of terms and phrases across a corpus, and the corelation between different words and phrase counts. In order to do this effectively, we coarsely disambiguate words based of part-of-speech (POS) tagging, and normalize them through stemming and lemmatization. Next we distinguish *important* words and phrase within the corpus, and image them with Wordls! Then we calculate word frequenceis, conditional frequences (the frequency of word *shock* conditional on the presence of word *awe*), and statistically significant collocations of lengths 2 through $n$. Finally, we calculate and visualize Differences (Divergences and Distances) between the word frequency distributions from two corpora.
#
# For this notebook we will be using the following packages

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
import lucem_illud #pip install git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
import requests #for http requests
import nltk #the Natural Language Toolkit
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import wordcloud #Makes word clouds
import numpy as np #For divergences/distances
import scipy #For divergences/distances
import seaborn as sns #makes our plots look nicer
import sklearn.manifold #For a manifold plot
from nltk.corpus import stopwords #For stopwords
import json #For API responses
import urllib.parse #For joining urls
import io #for making http requests look like files
import bs4 #called `beautifulsoup4`, an html parser

#Stuff for pdfs
#Install as `pdfminer2`
import pdfminer.pdfinterp
import pdfminer.converter
import pdfminer.layout
import pdfminer.pdfpage

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook
# %matplotlib inline

import urllib.parse #For joining urls
import io #for making http requests look like files
import os.path #For checking if files exist
import os #For making directories

# %% [markdown]
# # Retrieving exemplary corpora
#
# To get started we will need some examples. Let's start by downloading one of the corpuses from `nltk`, a Natural Language Toolkit developed by computational linguists at the University of Pennsylvania. Let's take a look at how that works.
#
# First we can get a list of works available from the Gutenburg corpus, with the [corpus module](http://www.nltk.org/api/nltk.corpus.html). To do this we will need to tell nltk where the data are, and download them if need be.

# %%
#You should have them already downloaded in the data directory
try:
    #adding path for both local and server, only one of these will actually be used at a time
    nltk.data.path.append('/project2/macs60000/shared_data/nltk')
    nltk.data.path.append('../data')
    #Check that everything is in place
    nltk.corpus.gutenberg.fileids()
except LookupError:
    print("You have to download all the documents")
    print("Downloading to ../data this should only take a couple minutes")
    nltk.download('all', download_dir = '../data')
    nltk.data.path.append('../data')
#If you haven't downloaded the copura then you will have to run `nltk.download()`
print(nltk.corpus.gutenberg.fileids())
print(len(nltk.corpus.gutenberg.fileids()))
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# 18

# %% [markdown]
# We can also look at the individual works

# %%
nltk.corpus.gutenberg.raw('shakespeare-macbeth.txt')[2000:4000]
# Out:
# "es,\nBut the Norweyan Lord, surueying vantage,\nWith furbusht Armes, and new supplyes of men,\nBegan a fresh assault\n\n   King. Dismay'd not this our Captaines, Macbeth and\nBanquoh?\n  Cap. Yes, as Sparrowes, Eagles;\nOr the Hare, the Lyon:\nIf I say sooth, I must report they were\nAs Cannons ouer-charg'd with double Cracks,\nSo they doubly redoubled stroakes vpon the Foe:\nExcept they meant to bathe in reeking Wounds,\nOr memorize another Golgotha,\nI cannot tell: but I am faint,\nMy Gashes cry for helpe\n\n   King. So well thy words become thee, as thy wounds,\nThey smack of Honor both: Goe get him Surgeons.\nEnter Rosse and Angus.\n\nWho comes here?\n  Mal. The worthy Thane of Rosse\n\n   Lenox. What a haste lookes through his eyes?\nSo should he looke, that seemes to speake things strange\n\n   Rosse. God saue the King\n\n   King. Whence cam'st thou, worthy Thane?\n  Rosse. From Fiffe, great King,\nWhere the Norweyan Banners flowt the Skie,\nAnd fanne our people cold.\nNorway himselfe, with terrible numbers,\nAssisted by that most disloyall Traytor,\nThe Thane of Cawdor, began a dismall Conflict,\nTill that Bellona's Bridegroome, lapt in proofe,\nConfronted him with selfe-comparisons,\nPoint against Point, rebellious Arme 'gainst Arme,\nCurbing his lauish spirit: and to conclude,\nThe Victorie fell on vs\n\n   King. Great happinesse\n\n   Rosse. That now Sweno, the Norwayes King,\nCraues composition:\nNor would we deigne him buriall of his men,\nTill he disbursed, at Saint Colmes ynch,\nTen thousand Dollars, to our generall vse\n\n   King. No more that Thane of Cawdor shall deceiue\nOur Bosome interest: Goe pronounce his present death,\nAnd with his former Title greet Macbeth\n\n   Rosse. Ile see it done\n\n   King. What he hath lost, Noble Macbeth hath wonne.\n\nExeunt.\n\n\nScena Tertia.\n\nThunder. Enter the three Witches.\n\n  1. Where hast thou beene, Sister?\n  2. Killing Swine\n\n   3. Sister, where thou?\n  1. A Saylors Wife had Chestnuts in her Lappe,\nAnd mouncht, & mouncht, and mouncht:\nGiue me, quoth I.\nAroynt thee, "

# %% [markdown]
# All the listed works have been nicely marked up and classified for us so we can do much better than just looking at raw text.

# %%
print(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
print(nltk.corpus.gutenberg.sents('shakespeare-macbeth.txt'))
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', ...]
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]

# %% [markdown]
# # Counting words
#
# If we want to do some analysis we can start by simply counting the number of times each word occurs within the corpus.

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        #We usually need to normalize the case
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))
countedWords[:10]
# Out:
#    count         word
# 0      4            [
# 1    650          the
# 2      2     tragedie
# 3    338           of
# 4     62      macbeth
# 5     49           by
# 6      1      william
# 7      1  shakespeare
# 8      1         1603
# 9      4            ]

# %% [markdown]
# Notice how `wordCounter()` is not a very complicated function. That is because the hard parts have already been done by `nltk`. If we were using unprocessed text we would have to tokenize and determine what to do with the non-word characters.
#
# nltk also offers a built-in way for getting a frequency distribution from a list of words:

# %%
words = [word.lower() for word in nltk.corpus.gutenberg.words('shakespeare-macbeth.txt')]
freq = nltk.FreqDist(words)
print (freq['macbeth'])
# Out:
# 62

# %% [markdown]
# Lets sort and plot our counts to investigate the shape of our word frequency distribution.
#
# First we need to sort the words by count.

# %%
#Doing this in place (changing the original DataFrame) as we don't need the unsorted DataFrame
countedWords.sort_values('count', ascending=False, inplace=True)
countedWords[:100]
# Out:
#      count    word
# 29    1962       ,
# 12    1235       .
# 1      650     the
# 36     637       '
# 16     546     and
# 64     477       :
# 54     384      to
# 56     348       i
# 3      338      of
# 27     241       ?
# 84     241       a
# 43     238    that
# 153    224       d
# 487    206     you
# 110    203      my
# 28     201      in
# 66     188      is
# 242    165     not
# 122    161      it
# 55     153    with
# 95     146     his
# 45     137      be
# 474    137    macb
# 37     131       s
# 501    126    your
# 196    123     our
# 413    122    haue
# 162    120     but
# 87     118    what
# 391    113      me
# ..     ...     ...
# 105     49    good
# 630     49     was
# 5       49      by
# 289     49   rosse
# 880     48    lady
# 478     48       t
# 567     48    them
# 529     46    time
# 250     45      if
# 104     43    like
# 386     43     her
# 297     42  should
# 306     42      st
# 453     42     did
# 735     42     let
# 116     41     say
# 22      40    when
# 473     39  banquo
# 254     39    were
# 49      39   where
# 468     39    make
# 198     38       o
# 230     38    lord
# 129     38     doe
# 665     37     tis
# 30      37      or
# 21      36       1
# 252     36    must
# 489     35     may
# 38      35    done
#
# [100 rows x 2 columns]

# %% [markdown]
# Punctuation and very common words (articles 'a' and 'the'; prepositions 'of' and 'to') make up the most common values, but this isn't very interesting and can actually get in the way of our analysis. We may remove these 'function words' by removing according to a stopword list, setting some frequency threshold, or using a weighting scheme (like tf.idf) to decrease their influence (all modeled later in this tutorial).

# %%
#Creating a figure and axis lets us do things like change the scaling or add a title
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
plt.show()

# %% [markdown]
# This shows that likelihood of a word occurring is inversely proportional to its rank. This effect is called [Zipf's Law](https://en.wikipedia.org/wiki/Zipf%27s_law), and suggests that the most frequent word will occur approximately twice as often as the second most frequent word, three times as often as the third most frequent word, etc. Zipf's law is most easily observed by plotting the data on a log-log graph, with the axes being log (rank order) and log (frequency) resulting in a linear relationship.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %% [markdown]
# (The same relationship occurs in many other rankings, such as population ranks of cities, corporation sizes, income rankings, etc.)
#
# The distribution was imagined by Zipf to be driven by a principle of 'least effort' where speakers did not work any harder than necessary to communicate a given idea, but the basis for this relationship is still not well understood and conforms at least as well to a process of [preferential attachment](https://en.wikipedia.org/wiki/Preferential_attachment) whereby people disproportionately attend to popular words.
#
# There are many other properties of words we can examine. First lets look surrounding words with the concordance. To do this we need to load the text into a `ConcordanceIndex`

# %%
macbethIndex = nltk.text.ConcordanceIndex(nltk.corpus.gutenberg.words('shakespeare-macbeth.txt'))

# %% [markdown]
# Then we can retrieve all the words that cooccur with a word in a given word window. Let's first look at `'macbeth'`.

# %%
macbethIndex.print_concordance('macbeth')
# Out:
# No matches

# %% [markdown]
# Weird?! `'macbeth'` doesn't occur anywhere in the the text. What happened?
#
# `ConcordanceIndex` is case sensitive, lets try looking for `'Macbeth'`

# %%
macbethIndex.print_concordance('Macbeth')
# Out:
# Displaying 25 of 61 matches:
#                                   Macbeth by William Shakespeare 1603 ] Act
#  the Heath 3 . There to meet with Macbeth 1 . I come , Gray - Malkin All .
# but all ' s too weake : For braue Macbeth ( well hee deserues that Name ) D
# smay ' d not this our Captaines , Macbeth and Banquoh ? Cap . Yes , as Spar
# , And with his former Title greet Macbeth Rosse . Ile see it done King . Wh
#  King . What he hath lost , Noble Macbeth hath wonne . Exeunt . Scena Terti
# ithin . 3 . A Drumme , a Drumme : Macbeth doth come All . The weyward Siste
# , the Charme ' s wound vp . Enter Macbeth and Banquo . Macb . So foule and
# an : what are you ? 1 . All haile Macbeth , haile to thee Thane of Glamis 2
# hee Thane of Glamis 2 . All haile Macbeth , haile to thee Thane of Cawdor 3
# hee Thane of Cawdor 3 . All haile Macbeth , that shalt be King hereafter Ba
# . Hayle 3 . Hayle 1 . Lesser than Macbeth , and greater 2 . Not so happy ,
# hough thou be none : So all haile Macbeth , and Banquo 1 . Banquo , and Mac
# eth , and Banquo 1 . Banquo , and Macbeth , all haile Macb . Stay you imper
# he King hath happily receiu ' d , Macbeth , The newes of thy successe : and
# gh the roughest Day Banq . Worthy Macbeth , wee stay vpon your leysure Macb
# I built An absolute Trust . Enter Macbeth , Banquo , Rosse , and Angus . O
# ke , To cry , hold , hold . Enter Macbeth . Great Glamys , worthy Cawdor ,
# ruice ouer the Stage . Then enter Macbeth Macb . If it were done , when ' t
# re giues way to in repose . Enter Macbeth , and a Seruant with a Torch . Gi
# hether they liue , or dye . Enter Macbeth . Macb . Who ' s there ? what hoa
# ard a voyce cry , Sleep no more : Macbeth does murther Sleepe , the innocen
# ore Cawdor Shall sleepe no more : Macbeth shall sleepe no more Lady . Who w
#  made a Shift to cast him . Enter Macbeth . Macd . Is thy Master stirring ?
# selues : awake , awake , Exeunt . Macbeth and Lenox . Ring the Alarum Bell

# %% [markdown]
# That's better. What about something a lot less frequent?

# %%
print(countedWords[countedWords['word'] == 'donalbaine'])
macbethIndex.print_concordance('Donalbaine')
# Out:
#     count        word
# 80      7  donalbaine
# Displaying 7 of 7 matches:
# m within . Enter King Malcome , Donalbaine , Lenox , with attendants , mee
# Enter King , Lenox , Malcolme , Donalbaine , and Attendants . King . Is ex
# rches . Enter King , Malcolme , Donalbaine , Banquo , Lenox , Macduff , Ro
#  ' th ' second Chamber ? Lady . Donalbaine Mac . This is a sorry sight Lad
# er , and Treason , Banquo , and Donalbaine : Malcolme awake , Shake off th
# to brag of . Enter Malcolme and Donalbaine . Donal . What is amisse ? Macb
# were subborned , Malcolme , and Donalbaine the Kings two Sonnes Are stolne

# %% [markdown]
# # Getting and working with raw text
#
# First, we will retrieve a collection of press releases from a *GitHub API* that archived them, based on a number of analyses by Justin Grimmer, a political scientist whose work we will read next week, and who will be joining the University of Chicago next July!
#
# GitHub API requests are made to `'https://api.github.com/'` and responses are in JSON, similar to Tumblr's API.
#
# We will get the information on [github.com/lintool/GrimmerSenatePressReleases](https://github.com/lintool/GrimmerSenatePressReleases) as it contains a nice set documents.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases')
senateReleasesData = json.loads(r.text)
print(senateReleasesData.keys())
print(senateReleasesData['description'])
# Out:
# dict_keys(['id', 'name', 'full_name', 'owner', 'private', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'open_issues_count', 'license', 'forks', 'open_issues', 'watchers', 'default_branch', 'network_count', 'subscribers_count'])
# Grimmer's Senate Press Releases

# %% [markdown]
# What we are interested in here is the `'contents_url'`

# %%
print(senateReleasesData['contents_url'])
# Out:
# https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/{+path}

# %% [markdown]
# We can use this to get any or all of the files from the repo.

# %%
r = requests.get('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse')
whitehouseLinks = json.loads(r.text)
whitehouseLinks[0]
# Out:
# {'_links': {'git': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#   'html': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#   'self': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'},
#  'download_url': 'https://raw.githubusercontent.com/lintool/GrimmerSenatePressReleases/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'git_url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/git/blobs/f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'html_url': 'https://github.com/lintool/GrimmerSenatePressReleases/blob/master/raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'name': '10Apr2007Whitehouse123.txt',
#  'path': 'raw/Whitehouse/10Apr2007Whitehouse123.txt',
#  'sha': 'f524289ee563dca58690c8d36c23dce5dbd9962a',
#  'size': 2206,
#  'type': 'file',
#  'url': 'https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse/10Apr2007Whitehouse123.txt?ref=master'}

# %% [markdown]
# Now we have a list of information about Whitehouse press releases. Let's look at one of them.

# %%
r = requests.get(whitehouseLinks[0]['download_url'])
whitehouseRelease = r.text
print(whitehouseRelease[:1000])
len(whitehouseRelease)
# Out:
# SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY IN PUSH FOR STEM CELL RESEARCH
#   Sharing the story of Lila Barber, a 12 year old girl from Westerly, Sen. Sheldon Whitehouse (D-R.I.) on Tuesday, April 10, 2007, illustrated the hope stem cell research can offer in a speech on the Senate floor in favor of legislation to expand federal funding for stem cell research.
#    Whitehouse met Lila two weeks ago. She was diagnosed two years ago with osteosarcoma, a cancerous bone condition, and last year underwent cadaver bone transplant surgery. The procedure saved her leg and is helping her remain cancer-free, but the transplanted tissue will not grow with her and likely will break down over time. Stem cell research, Whitehouse explained, could vastly improve the care of patients like Lila by allowing surgeons to enhance transplants with a patient's own stem cells, which could replace the lost bone and cartilage, or grow entirely new replacement bones and joints.
#    "Stem cell research gives hope
# 2206

# %% [markdown]
# Now we have a string of correctly encoded text, similar to those we constructed from last week's assignment. For analysis of its words, next we need to tokenize it, or to split it into a sequence of tokens or word instances.

# %%
whTokens = nltk.word_tokenize(whitehouseRelease)
whTokens[10:30]
# Out:
# ['STEM',
#  'CELL',
#  'RESEARCH',
#  'Sharing',
#  'the',
#  'story',
#  'of',
#  'Lila',
#  'Barber',
#  ',',
#  'a',
#  '12',
#  'year',
#  'old',
#  'girl',
#  'from',
#  'Westerly',
#  ',',
#  'Sen.',
#  'Sheldon']

# %% [markdown]
# `whTokens` is a list of 'words' constructed from nltk's `word_tokenize` method built on the [Penn Treebank tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.treebank). While it's better than `.split(' ')`, a general python string method that splits on whitespace, it is not perfect. There are many different ways to tokenize a string. `word_tokenize` is unfortunately unaware of sentences and is essentially a complicated regular expression (regex) run across the string.
#
# If we want to find sentences we can use something like `nltk.sent_tokenize()`, which implements the [Punkt Sentence tokenizer](http://www.nltk.org/api/nltk.tokenize.html#nltk.tokenize.punkt.PunktSentenceTokenizer), a machine learning based algorithm that works well for many European languages.
#
# We could also use the [Stanford tokenizer](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.stanford) or construct our own regex with [`RegexpTokenizer()`](http://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.regexp). Picking the correct tokenizer is important as the tokens form the base of our analysis.
#
# For our purposes in this example, the Penn Treebank tokenizer is fine.
#
# To use the list of tokens in `nltk`, and take advantage of functions like `concordance`, shown above, we can convert it into a `Text`.

# %%
whText = nltk.Text(whTokens)

whitehouseIndex = nltk.text.ConcordanceIndex(whText) 
whitehouseIndex.print_concordance('Whitehouse')
# Out:
# Displaying 5 of 5 matches:
# rl from Westerly , Sen. Sheldon Whitehouse ( D-R.I. ) on Tuesday , April 1
# unding for stem cell research . Whitehouse met Lila two weeks ago . She wa
# ver time . Stem cell research , Whitehouse explained , could vastly improv
# ch might help or even cure , '' Whitehouse said . Whitehouse also praised
# ven cure , '' Whitehouse said . Whitehouse also praised the efforts of Rho

# %% [markdown]
# *Note* that the `Text` class is for doing rapid, exploratory analysis. It provides an easy interface to many of the operations we want to do, but it does not allow us much control over the particular operations it glosses. When you are doing a more complete analysis, you should be using the module specifically designed for that task instead of the shortcut method `Text` provides, e.g. use  [`collocations` Module](http://www.nltk.org/api/nltk.html#module-nltk.collocations) instead of `.collocations()`.
#
# Now that we have gotten this loaded, let's glance at few features we will delve into more deeply later.
#
# For example, we can find words that statistically tend to occur together and typically have a composite, idiomatic meaning irreducible to the semantics of its component words. We will do this later with more control over exactly how these are identified.

# %%
whText.collocations()
# Out:
# Rhode Island; stem cells; cell research; Cell Enhancement; Enhancement
# Act; President Bush; Stem Cell; stem cell; Stem cell

# %% [markdown]
# Or we can pick a word (or words) and find what words tend to occur around it.

# %%
whText.common_contexts(['stem'])
# Out:
# for_cell hope_cell ._cell own_cells ``_cell of_cell on_cells the_cell
# embryonic_cells

# %% [markdown]
# We can also just count the number of times the word occurs.

# %%
whText.count('cell')
# Out:
# 5

# %% [markdown]
# We can also plot each time a set of words occurs.

# %%
sns.reset_orig() #Seaborn messes with this plot, disabling it
whText.dispersion_plot(['Sen.','stem', 'cell', 'federal' ,'Lila', 'Barber', 'Whitehouse'])
sns.set() #Re-enabling seaborn

# %% [markdown]
# If we want to do an analysis of all the Whitehouse press releases we will first need to obtain them. By looking at the API we can see the the URL we want is [https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse](https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse), so we can create a function to scrape the individual files.
#
# If you want to know more about downloading from APIs, refer back to the 1st notebook.

# %%
def getGithubFiles(target, maxFiles = 100):
    #We are setting a max so our examples don't take too long to run
    #For converting to a DataFrame
    releasesDict = {
        'name' : [], #The name of the file
        'text' : [], #The text of the file, watch out for binary files
        'path' : [], #The path in the git repo to the file
        'html_url' : [], #The url to see the file on Github
        'download_url' : [], #The url to download the file
    }

    #Get the directory information from Github
    r = requests.get(target)
    filesLst = json.loads(r.text)

    for fileDict in filesLst[:maxFiles]:
        #These are provided by the directory
        releasesDict['name'].append(fileDict['name'])
        releasesDict['path'].append(fileDict['path'])
        releasesDict['html_url'].append(fileDict['html_url'])
        releasesDict['download_url'].append(fileDict['download_url'])

        #We need to download the text though
        text = requests.get(fileDict['download_url']).text
        releasesDict['text'].append(text)

    return pandas.DataFrame(releasesDict)

whReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Whitehouse', maxFiles = 10)
whReleases[:5]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
# 2  https://github.com/lintool/GrimmerSenatePressR...
# 3  https://github.com/lintool/GrimmerSenatePressR...
# 4  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
# 2    10Apr2008Whitehouse3.txt    raw/Whitehouse/10Apr2008Whitehouse3.txt
# 3   10Aug2007Whitehouse78.txt   raw/Whitehouse/10Aug2007Whitehouse78.txt
# 4   10Jan2008Whitehouse35.txt   raw/Whitehouse/10Jan2008Whitehouse35.txt
#
#                                                 text
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
# 2  EPA MUST REVIEW LEGAL PROCESS TO ROOT OUT POLI...
# 3  R.I. SENATORS PRAISE SEN. DENIAL OF LNG FACILI...
# 4  SEN. WHITEHOUSE COMMENTS ON ONE-YEAR ANNIVERSA...

# %% [markdown]
# If you are having trouble downloading the data uncomment this next cell

# %%
#whReleases = pandas.read_csv('../data/whReleases.csv')

# %% [markdown]
# Now we have all the texts in a DataFrame we can look at a few things.
#
# First let's tokenize the texts with the same tokenizer as we used before. We will just save the tokens as a list for now; no need to convert to `Text`s.

# %%
whReleases['tokenized_text'] = whReleases['text'].apply(lambda x: nltk.word_tokenize(x))

# %% [markdown]
# Now lets see how long each of the press releases is:

# %%
whReleases['word_counts'] = whReleases['tokenized_text'].apply(lambda x: len(x))
whReleases['word_counts']
# Out:
# 0    397
# 1    344
# 2    553
# 3    216
# 4    257
# 5    380
# 6    270
# 7    521
# 8    484
# 9    482
# Name: word_counts, dtype: int64

# %% [markdown]
# ## <span style="color:red">*Exercise 1*</span>
#
# <span style="color:red">Construct cells immediately below this that input and interrogate a corpus relating to your anticipated final project. Turn your text into an nltk `Text` object, and explore all of the features examined above, and others that relate to better understanding your corpus in relation to your research question. </span>

# %% [markdown]
# In this part, I intend to input and interrogate a corpus which contains text from the book Harry Potter and the Sorcerer's Stone, which is the first book of Harry Potter series. My work contains three parts: 1) import texual data, 2) convert the text into nltk `Text` object, 3)explore fundamental features of this text to get a holistic picture of this corpus.

# %% [markdown]
# ## Import Textual Data

# %% [markdown]
# First of all, I will import the data by converting the pdf file into readable text

# %%
hp_sorcerer_stone_pdf = "http://www2.sdfi.edu.cn/netclass/jiaoan/englit/download/Harry%20Potter%20and%20the%20Sorcerer's%20Stone.pdf"

hpStoneRequest = requests.get(hp_sorcerer_stone_pdf,stream=True)
print(hpStoneRequest.text[:1000])
# Out:
# %����
# stream
# ����c�����٬{v%.N�$O׳�d�
# 	H�����d��I�r��	7�*���̯�������|x��o�er泋�,�;�y����^x�yL���dAk_C��:X��?�nz
# ۤ�)m��>���,�|셷-m����J��r��܌�h����&��U��m���E�Dn:�E��*)	��m�hKb��ٺ)�c�׻���6$�h�����d���̳u�:�����)IP֑��� xN+���J�l�z�Ӌ�+U�LV!��?�k~
# `^]|%�=�d�#>�\5��w���x��[)y&�5��E�Ay�~��i6� �Ϣ�q�	 ��uTF�+��F�F�p�

# %% [markdown]
# Define a function to read pdf file

# %%
def readPDF(pdfFile):
    #Based on code from http://stackoverflow.com/a/20905381/4955164
    #Using utf-8, if there are a bunch of random symbols try changing this
    codec = 'utf-8'
    rsrcmgr = pdfminer.pdfinterp.PDFResourceManager()
    retstr = io.StringIO()
    layoutParams = pdfminer.layout.LAParams()
    device = pdfminer.converter.TextConverter(rsrcmgr, retstr, laparams = layoutParams, codec = codec)
    #We need a device and an interpreter
    interpreter = pdfminer.pdfinterp.PDFPageInterpreter(rsrcmgr, device)
    password = ''
    maxpages = 0
    caching = True
    pagenos=set()
    for page in pdfminer.pdfpage.PDFPage.get_pages(pdfFile, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    device.close()
    returnedString = retstr.getvalue()
    retstr.close()
    return returnedString

# %%
hpStoneBytes = io.BytesIO(hpStoneRequest.content)

# %%
hpStoneContent = readPDF(hpStoneBytes)
print(hpStoneContent[:550])
len(hpStoneContent)
# Out:
# Harry Potter and the Sorcerer's Stone
# CHAPTER ONE
#
# THE BOY WHO LIVED
#
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say
# that they were perfectly normal, thank you very much. They were the last
# people you'd expect to be involved in anything strange or mysterious,
# because they just didn't hold with such nonsense.
#
# Mr. Dursley was the director of a firm called Grunnings, which made
# drills. He was a big, beefy man with hardly any neck, although he did
# have a very large mustache. Mrs. Dursley was thin and blonde and had
# nearly t
# 441210

# %% [markdown]
# Now we got the full text with the length of 441210 words, ready for further investigation.

# %% [markdown]
# ## Turn Text into nltk `Text` Object

# %% [markdown]
# Using `nltk` method to tokenize the text.

# %%
hpStoneTokens = nltk.word_tokenize(hpStoneContent)
hpStoneTokens[1000:1050]
# Out:
# ['the',
#  'bakery',
#  '.',
#  '2',
#  'He',
#  "'d",
#  'forgotten',
#  'all',
#  'about',
#  'the',
#  'people',
#  'in',
#  'cloaks',
#  'until',
#  'he',
#  'passed',
#  'a',
#  'group',
#  'of',
#  'them',
#  'next',
#  'to',
#  'the',
#  'baker',
#  "'s",
#  '.',
#  'He',
#  'eyed',
#  'them',
#  'angrily',
#  'as',
#  'he',
#  'passed',
#  '.',
#  'He',
#  "didn't",
#  'know',
#  'why',
#  ',',
#  'but',
#  'they',
#  'made',
#  'him',
#  'uneasy',
#  '.',
#  'This',
#  'bunch',
#  'were',
#  'whispering',
#  'excitedly']

# %% [markdown]
# `hpStoneTokens` is a list of 'words' constructed from nltk's `word_tokenize` method. Now I will convert `hpStoneTokens` into a `Text` to use this list of tokens.

# %%
hpStoneText = nltk.Text(hpStoneTokens)

# %% [markdown]
# Now we are ready to explore some features of this corpora.

# %% [markdown]
# ## Explore Textual Features

# %% [markdown]
# ### Count Words
#
# First of all, I am going to start with counting the number of times each word occurs within the corpus.

# %%
def wordCounter(wordLst):
    wordCounts = {}
    for word in wordLst:
        wLower = word.lower()
        if wLower in wordCounts:
            wordCounts[wLower] += 1
        else:
            wordCounts[wLower] = 1
    #convert to DataFrame
    countsForFrame = {'word' : [], 'count' : []}
    for w, c in wordCounts.items():
        countsForFrame['word'].append(w)
        countsForFrame['count'].append(c)
    return pandas.DataFrame(countsForFrame)

countedWords = wordCounter(hpStoneText)
countedWords[80:90]
# Out:
#     count     word
# 80     75     came
# 81      6   useful
# 82    526       as
# 83    251      she
# 84     11    spent
# 85    238       so
# 86    179      her
# 87    119     time
# 88      2  craning
# 89    171     over

# %% [markdown]
# We can also check the frequency distribution for certain words. For example, I will examine the frequency of 'harry' and 'dumbledore'.

# %%
words = [word.lower() for word in hpStoneText]
freq = nltk.FreqDist(words)
print (freq['harry'])
print (freq['dumbledore'])
# Out:
# 1314
# 158

# %% [markdown]
# Next I will sort and plot the counts to invertigate the overall shape of the word frequency distribution in this book.

# %%
#Sort the words by count
countedWords.sort_values('count',ascending=False, inplace=True)
countedWords[:100]
# Out:
#       count        word
# 15     5658           ,
# 33     5181           .
# 3      3626         the
# 219    2553          ''
# 216    2206          ``
# 2      1917         and
# 23     1855          to
# 62     1743          he
# 55     1688           a
# 0      1314       harry
# 53     1258         was
# 16     1258          of
# 115    1175          it
# 30     1003         you
# 40      964          in
# 5       942          's
# 179     937         his
# 407     903           i
# 259     794        said
# 231     788          --
# 48      782         n't
# 75      754         had
# 248     754           ?
# 25      685        that
# 26      681        they
# 93      636          on
# 199     625          at
# 82      526          as
# 147     500         him
# 107     483         but
# ...     ...         ...
# 157     194        like
# 276     193         get
# 394     188        know
# 46      180        just
# 776     180   professor
# 319     180         see
# 355     180        down
# 86      179         her
# 158     177        when
# 10      176         who
# 601     172         've
# 31      172        very
# 89      171        over
# 4015    170       snape
# 412     169      looked
# 558     169         are
# 210     166         now
# 237     164        then
# 734     158  dumbledore
# 811     157         'll
# 113     155       would
# 280     150          by
# 628     148        your
# 240     142      around
# 98      137      dudley
# 532     136         how
# 131     135           ;
# 580     135       going
# 1113    134          go
# 229     132   something
#
# [100 rows x 2 columns]

# %% [markdown]
# As we can see, some of the most common words are punctuations, prepositions and articles, which is not very helpful for our analysis. So I will remove these words by removing according to a stopword list, setting some frequency threshold, or using a weighting scheme to decrease their influence (cover later).

# %%
#Creating a figure and axis
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
#name the figure
plt.suptitle("Frequency Distribution of Harry Potter and the Sorcerer's Stone")
#add labels to figure
plt.xlabel('Rank of Words')
plt.ylabel('Likelihood of a word')
plt.show()

# %%
#Create a figure and axis
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(range(len(countedWords)), countedWords['count'])
#change the scale of axises into log
ax.set_yscale('log')
ax.set_xscale('log')
#name the figure
plt.suptitle("Frequency Distribution of Harry Potter and the Sorcerer's Stone(by log)")
#add labels to figure
plt.xlabel('Rank of Words')
plt.ylabel('Likelihood of a word')
#show the figure
plt.show()

# %% [markdown]
# This figure shows that the frequency distribution is commited to Zipf's law, which means the likelihood of a word occurring is inversely proportional to its rank.
#
# ### Concordance
#
# Next, I will examine the surrounding words with the concordance. To do this, I will load the text into a `ConcordanceIndex`.

# %%
hpStoneIndex = nltk.text.ConcordanceIndex(hpStoneText)

# %% [markdown]
# Now we are able to retrieve all the words that cooccur with a word in a given word window. Let's look at what happenes around 'Harry' and 'Dumbledore'.

# %%
hpStoneIndex.print_concordance('Harry')
hpStoneIndex.print_concordance('Dumbledore')
# Out:
# Displaying 25 of 1313 matches:
#                                    Harry Potter and the Sorcerer 's Stone C
#  's what I heard yes , their son , Harry '' Mr. Dursley stopped dead . Fear
# called Potter who had a son called Harry . Come to think of it , he was n't
# 't even sure his nephew was called Harry . He 'd never even seen the boy .
# again ? Howard , is n't it ? '' `` Harry . Nasty , common name , if you ask
#  tried to kill the Potter 's son , Harry . But -- he could n't . He could n
# saying that when he could n't kill Harry Potter , Voldemort's power somehow
#  but how in the name of heaven did Harry survive ? '' `` We can only guess
# places ? '' `` I 've come to bring Harry to his aunt and uncle . They 're t
# he street , screaming for sweets . Harry Potter come and live here ! '' ``
# be surprised if today was known as Harry Potter day in the future -- there
#  there will be books written about Harry -- every child in our world will k
# ugh she thought he might be hiding Harry underneath it . `` Hagrid 's bring
# his over with . '' Dumbledore took Harry in his arms and turned toward the
# nt his 11 great , shaggy head over Harry and gave him what must have been a
# n ' James dead -- an ' poor little Harry off ter live with Muggles - '' ''
# walked to the front door . He laid Harry gently on the doorstep , took a le
# ut of his cloak , tucked it inside Harry 's blankets , and then came back t
# ep of number four . `` Good luck , Harry , '' he murmured . He turned on hi
# ect astonishing things to happen . Harry Potter rolled over inside his blan
# nd saying in hushed voices : `` To Harry Potter -- the boy who lived ! '' C
# boy lived in the house , too . Yet Harry Potter was still there , asleep at
# he day . `` Up ! Get up ! Now ! '' Harry woke with a start . His aunt rappe
# again . `` Up ! '' she screeched . Harry heard her walking toward the kitch
# she demanded . `` Nearly , '' said Harry . `` Well , get a move on , I want
# Displaying 25 of 156 matches:
# ce . This man 's name was Albus Dumbledore . Albus Dumbledore did n't seem
# me was Albus Dumbledore . Albus Dumbledore did n't seem to realize that he
# appening down on the pavement . Dumbledore slipped the Put-Outer back insi
# You ca n't blame them , '' said Dumbledore gently . `` We 've had precious
# ew a sharp , sideways glance at Dumbledore here , as though hoping he was
#  suppose he 7 really has gone , Dumbledore ? '' `` It certainly seems so ,
# It certainly seems so , '' said Dumbledore . `` We have much to be thankfu
# essor McGonagall flinched , but Dumbledore , who was unsticking two lemon
#  '' `` You flatter me , '' said Dumbledore calmly . `` Voldemort had power
# McGonagall shot a sharp look at Dumbledore and said , `` The owls are noth
# at nor as a woman had she fixed Dumbledore with such a piercing stare as s
# not going to believe it until 8 Dumbledore told her it was true . Dumbledo
# mbledore told her it was true . Dumbledore , however , was choosing anothe
# re -- that they 're -- dead. `` Dumbledore bowed his head . Professor McGo
# elieve it ... Oh , Albus ... '' Dumbledore reached out and patted her on t
# -- and that 's why he 's gone . Dumbledore nodded glumly . `` It 's -- it
#  `` We can only guess , '' said Dumbledore . `` We may never know . '' Pro
# r eyes beneath her spectacles . Dumbledore gave a great sniff as he took a
# ge . It must have made sense to Dumbledore , though , because he put it ba
# nd pointing at number four . `` Dumbledore -- you ca n't . I 've been watc
# he best place for him , '' said Dumbledore firmly . `` His aunt and uncle
#  down on the wall . `` Really , Dumbledore , you think you can explain all
#  name ! '' `` Exactly , '' said Dumbledore , looking very seriously over t
# t how is the boy getting here , Dumbledore ? '' She eyed his cloak suddenl
# t Hagrid with my life , '' said Dumbledore . `` I 'm not saying his heart

# %% [markdown]
# Also, we can find words that statistically tend to occur togther.

# %%
hpStoneText.collocations()
# Out:
# Uncle Vernon; Professor McGonagall; Aunt Petunia; said Ron; could n't;
# 've got; said Harry; said Hagrid; Mr. Dursley; Privet Drive; common
# room; would n't; Nimbus Two; Great Hall; n't know; Two Thousand; Mrs.
# Dursley; Mr. Ollivander; invisibility cloak; Madam Pomfrey

# %% [markdown]
# Pick words and find what what words tend to occur around them. Let's try Ron and Hermione.

# %%
hpStoneText.common_contexts(['Ron'])
hpStoneText.common_contexts(['Hermione'])
# Out:
# ?_'s before_. ``_, said_. after_. said_again ,_. mumbled_. is_, and_.
# ''_blurted ._stared said_eagerly found_just as_found ''_reached ''_'s
# told_so cheer_up ''_gasped
# 'm_granger said_. or_granger ,_granger to_. said_in and_.
# except_granger heard_whisper ,_! ''_almost and_were only_granger
# gave_a ._granger ;_'s ignored_'s ''_stretched ignoring_'s ,_stood

# %% [markdown]
# Make a plot to show each time a set of words occurs

# %%
sns.reset_orig()
hpStoneText.dispersion_plot(['Harry','Ron','Hermione','Dumbledore','Hagrid','Voldemort'])
sns.set()
#How to add title and label?

# %% [markdown]
# As we can see, 'Harry' occurs all the time in this book. Ron and Hermione, as the other two most important character, occur frequently except for the first 1/3 of the timeline, when Harry arrived Hogwartz. Hagird plays an important role in introducing Harry about the magic world, while Dumbledore shows up frequently at the beginning and the end part. Voldemort, as the biggest villain in this book, shows up at the almost ending part, which lead to the climax of the story.

# %% [markdown]
# # Filtering and normalizing text
#
# As we want to start comparing the different releases we may choose to do a bit of filtering and normalizing that will allow us to focus on what we most care about. We can first make all of the words lower case, then drop the non-word tokens. Next, we can remove some 'stop words', stem the remaining words to remove suffixes, prefixes and (in some languages) infixes, or lemmatize tokens by intelligently grouping inflected or variant forms of the same word (e.g., with a stemmer and a dictionary).
#
# To begin this process, we will first define a function to work over the tokenized lists, then another to add normalized tokens to a new column.

# %% [markdown]
# Nltk has a built-in list of stopwords. They are already imported in the import section. Let's first take a look at what they are.

# %%
print(', '.join(stopwords.words('english')))
# Out:
# i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, mustn't, needn, needn't, shan, shan't, shouldn, shouldn't, wasn, wasn't, weren, weren't, won, won't, wouldn, wouldn't

# %% [markdown]
# We can remove these stopwords from the analysis by fiat, but we could also take a more principled approach by looking at the frequency distribution of words and selecting a specific cut-off associated with the preservation of 'meaningful words' identified upon inspection. Alternatively, we could automatically set a cut-off by rule, such as removal of all words more frequent then the most frequent verb, or the most frequent noun (not pronoun), or some term of central interest.

# %% [markdown]
# Lets generate our own stop list now.

# %%
countsDict = {}
for word in whReleases['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-85818b37de78> in <module>()
#       1 countsDict = {}
# ----> 2 for word in whReleases['tokenized_text'].sum():
#       3     if word in countsDict:
#       4         countsDict[word] += 1
#       5     else:
#
# NameError: name 'whReleases' is not defined

# %% [markdown]
# We can look at this and pick the cutoff, usually it is at the first noun. So we will cut all words before `'Whitehouse'`.

# %%
#The stop list is then all words that occur before the first noun
stop_words_freq = []
for word, count in word_counts:
    if word == 'Whitehouse':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq
wordnet = nltk.stem.WordNetLemmatizer()
wordnet.lemmatize('are')
# Out:
# 'are'

# %% [markdown]
# Now we can create our function to normalize the tokens

# %%
stop_words_nltk = stopwords.words('english')
#stop_words = ["the","it","she","he", "a"] #Uncomment this line if you want to use your own list of stopwords.

#The stemmers and lemmers need to be initialized before bing run
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):
    #We can use a generator here as we just need to iterate over it

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))

whReleases
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
# 5  https://raw.githubusercontent.com/lintool/Grim...
# 6  https://raw.githubusercontent.com/lintool/Grim...
# 7  https://raw.githubusercontent.com/lintool/Grim...
# 8  https://raw.githubusercontent.com/lintool/Grim...
# 9  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url  \
# 0  https://github.com/lintool/GrimmerSenatePressR...
# 1  https://github.com/lintool/GrimmerSenatePressR...
# 2  https://github.com/lintool/GrimmerSenatePressR...
# 3  https://github.com/lintool/GrimmerSenatePressR...
# 4  https://github.com/lintool/GrimmerSenatePressR...
# 5  https://github.com/lintool/GrimmerSenatePressR...
# 6  https://github.com/lintool/GrimmerSenatePressR...
# 7  https://github.com/lintool/GrimmerSenatePressR...
# 8  https://github.com/lintool/GrimmerSenatePressR...
# 9  https://github.com/lintool/GrimmerSenatePressR...
#
#                          name                                       path  \
# 0  10Apr2007Whitehouse123.txt  raw/Whitehouse/10Apr2007Whitehouse123.txt
# 1    10Apr2008Whitehouse2.txt    raw/Whitehouse/10Apr2008Whitehouse2.txt
# 2    10Apr2008Whitehouse3.txt    raw/Whitehouse/10Apr2008Whitehouse3.txt
# 3   10Aug2007Whitehouse78.txt   raw/Whitehouse/10Aug2007Whitehouse78.txt
# 4   10Jan2008Whitehouse35.txt   raw/Whitehouse/10Jan2008Whitehouse35.txt
# 5    10Mar2008Whitehouse8.txt    raw/Whitehouse/10Mar2008Whitehouse8.txt
# 6   10Sep2007Whitehouse72.txt   raw/Whitehouse/10Sep2007Whitehouse72.txt
# 7  11Apr2007Whitehouse122.txt  raw/Whitehouse/11Apr2007Whitehouse122.txt
# 8  11Jan2007Whitehouse161.txt  raw/Whitehouse/11Jan2007Whitehouse161.txt
# 9    11Mar2008Whitehouse7.txt    raw/Whitehouse/11Mar2008Whitehouse7.txt
#
#                                                 text  \
# 0  SEN. WHITEHOUSE SHARES WESTERLY GIRL'S STORY I...
# 1  SEN. WHITEHOUSE SAYS PRESIDENT BUSH MUST BEGIN...
# 2  EPA MUST REVIEW LEGAL PROCESS TO ROOT OUT POLI...
# 3  R.I. SENATORS PRAISE SEN. DENIAL OF LNG FACILI...
# 4  SEN. WHITEHOUSE COMMENTS ON ONE-YEAR ANNIVERSA...
# 5  SENS. REED, WHITEHOUSE WELCOME RHODE ISLAND ST...
# 6  REP. WHITEHOUSE ISSUES STATEMENT ON GEN. PETRA...
# 7  SEN. WHITEHOUSE URGES BUSH FOR NEW DIRECTION I...
# 8  SENS. REED, WHITEHOUSE URGE PORTUGAL TO RECONS...
# 9  WHITEHOUSE UNVEILS 'BUSH DEBT': $7.7 TRILLION ...
#
#                                       tokenized_text  word_counts  \
# 0  [SEN., WHITEHOUSE, SHARES, WESTERLY, GIRL, 'S,...          397
# 1  [SEN., WHITEHOUSE, SAYS, PRESIDENT, BUSH, MUST...          344
# 2  [EPA, MUST, REVIEW, LEGAL, PROCESS, TO, ROOT, ...          553
# 3  [R.I, ., SENATORS, PRAISE, SEN, ., DENIAL, OF,...          216
# 4  [SEN., WHITEHOUSE, COMMENTS, ON, ONE-YEAR, ANN...          257
# 5  [SENS, ., REED, ,, WHITEHOUSE, WELCOME, RHODE,...          380
# 6  [REP., WHITEHOUSE, ISSUES, STATEMENT, ON, GEN....          270
# 7  [SEN., WHITEHOUSE, URGES, BUSH, FOR, NEW, DIRE...          521
# 8  [SENS, ., REED, ,, WHITEHOUSE, URGE, PORTUGAL,...          484
# 9  [WHITEHOUSE, UNVEILS, 'BUSH, DEBT, ', :, $, 7....          482
#
#                                    normalized_tokens  normalized_tokens_count
# 0  [whitehous, share, westerli, girl, stori, push...                      231
# 1  [whitehous, say, presid, bush, must, begin, br...                      171
# 2  [epa, must, review, legal, process, root, poli...                      305
# 3  [senat, prais, sen, denial, lng, facil, permit...                      115
# 4  [whitehous, comment, anniversari, presid, bush...                      132
# 5  [sen, reed, whitehous, welcom, rhode, island, ...                      195
# 6  [whitehous, issu, statement, petraeu, iraq, re...                      118
# 7  [whitehous, urg, bush, new, direct, iraq, shel...                      257
# 8  [sen, reed, whitehous, urg, portug, reconsid, ...                      254
# 9  [whitehous, unveil, debt, trillion, foregon, s...                      260

# %% [markdown]
# The stemmer we use here is called the [Porter Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.porter), there are many others, including another good one by the same person (Martin Porter) called the [Snowball Stemmer](http://www.nltk.org/api/nltk.stem.html#module-nltk.stem.snowball) or 'another stemmer' called the [Lancaster Stemmer](http://www.nltk.org/_modules/nltk/stem/lancaster.html). We can also normalize our words by lemmatizing them, or matching word variants or inflected forms to a common morpheme in a dictionary like [WordNet](https://wordnet.princeton.edu) through intelligent stemming rules. (The WordNet function `morphy` returns the given word if it cannot be matched to a word in the dictionary).
#
# Now that it is cleaned we start analyzing the dataset. We can start by finding frequency distributions for the dataset. Lets start looking at all the press releases together. The [`ConditionalFreqDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) class reads in an iterable of tuples, the first element is the condition and the second the focal word. For starters, we will use word lengths as the conditions, but tags or clusters will provide more useful results.

# %%
#.sum() adds together the lists from each row into a single list
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))

#print the number of words
print(whcfdist.N())
# Out:
# 2038

# %% [markdown]
# From this we can lookup the distributions of different word lengths

# %%
whcfdist[3].plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-0ce1cd6ce4c6> in <module>()
#       1 whcfdist[3].plot()
# ----> 2 whcfdist[3].title('222')
#
# AttributeError: 'FreqDist' object has no attribute 'title'

# %% [markdown]
# See that the most frequent 3-character word is "thi". But what is "thi"? It is actually "this" stemmed by the Porter Stemmer.

# %%
porter = nltk.stem.porter.PorterStemmer()
print (porter.stem('this'))
# Out:
# thi

# %% [markdown]
# Let's try with the Snowball Stemer. See that "this" is corretly stemmed as a 4-character word.

# %%
print (snowball.stem('this'))

whReleases['normalized_tokens'] = whReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
whReleases['normalized_tokens_count'] = whReleases['normalized_tokens'].apply(lambda x: len(x))
whcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in whReleases['normalized_tokens'].sum()))
whcfdist[3].plot()
# Out:
# this

# %% [markdown]
# We can also create a Conditional Probability Distribution or [`ConditionalProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ConditionalProbDist) from the `ConditionalFreqDist`. To do this, however, we need a model for the probability distribution. A simple model is [`ELEProbDist`](http://www.nltk.org/api/nltk.html#nltk.probability.ELEProbDist) which gives the expected likelihood estimate for the probability distribution of the experiment used to generate the observed frequency distribution.

# %%
whcpdist = nltk.ConditionalProbDist(whcfdist, nltk.ELEProbDist)

#print the most common 2 letter word
print(whcpdist[2].max())

#And its probability
print(whcpdist[2].prob(whcpdist[2].max()))
# Out:
# us
# 0.6470588235294118

# %% [markdown]
# Length is one feature of a word, but there are many more important features we care about. Another critical feature is a word's role in the sentence, or its part of speech (POS). Here, we will be classifying words according to their part of speech (POS), using the [`nltk.pos_tag()`](http://www.nltk.org/api/nltk.tag.html#nltk.tag.pos_tag). The tags used here are those from the [Brown Corpus tagset](http://www.scs.leeds.ac.uk/amalgam/tagsets/brown.html).

# %%
whReleases['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in whReleases['normalized_tokens']]

# %% [markdown]
# This gives us a new column with the part of speech as a short initialism and the word in a tuple, exactly how the `nltk.ConditionalFreqDist()` function wants them. We can now construct another conditional frequency distribution.

# %%
whcfdist_WordtoPOS = nltk.ConditionalFreqDist(whReleases['normalized_tokens_POS'].sum())
list(whcfdist_WordtoPOS.items())[:10]
# Out:
# [('whitehous', FreqDist({'JJ': 39, 'NN': 1})),
#  ('share', FreqDist({'NN': 4})),
#  ('wester', FreqDist({'NN': 1, 'RBR': 1})),
#  ('girl', FreqDist({'NN': 2})),
#  ('stori', FreqDist({'FW': 2})),
#  ('push', FreqDist({'NN': 2})),
#  ('stem', FreqDist({'NN': 12})),
#  ('cell', FreqDist({'NN': 9, 'VBP': 3})),
#  ('research', FreqDist({'NN': 9})),
#  ('lila', FreqDist({'CD': 1, 'JJ': 1, 'NN': 2}))]

# %% [markdown]
# This gives the frequency of each word as each part of speech...which can be uninformative and boring.

# %%
whcfdist_WordtoPOS['administr'].plot()

# %% [markdown]
# What we want is the converse; the frequency of each part of speech for each word.

# %%
whcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in whReleases['normalized_tokens_POS'].sum())

# %% [markdown]
# We can now identify and collect all of the superlative adjectives

# %%
whcfdist_POStoWord['JJS']
# Out:
# FreqDist({'best': 1, 'strongest': 2})

# %% [markdown]
# Or look at the most common nouns

# %%
whcfdist_POStoWord['NN'].most_common(5)
# Out:
# [('bush', 24), ('presid', 23), ('iraq', 22), ('rhode', 18), ('island', 18)]

# %% [markdown]
# Or plot the base form verbs against their number of occurrences

# %%
whcfdist_POStoWord['VB'].plot()

# %% [markdown]
# We can then do a similar analysis of the word probabilities

# %%
whcpdist_POStoWord = nltk.ConditionalProbDist(whcfdist_POStoWord, nltk.ELEProbDist)

#print the most common nouns
print(whcpdist_POStoWord['NN'].max())

#And its probability
print(whcpdist_POStoWord['NN'].prob(whcpdist_POStoWord['NN'].max()))
# Out:
# bush
# 0.017844136926438457

# %% [markdown]
# We can even create a...wait for it...*WORD CLOUD* or Wordl to gaze at and draw mystical, approximate inferences about important nouns and verbs in our corpus:

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(whReleases['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.savefig("whitehouse_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ## <span style="color:red">*Exercise 2*</span>
#
# <span style="color:red">Construct cells immediately below this that filter, stem and lemmatize the tokens in your corpus, and then creates plots (with titles and labels) that map the word frequency distribution, word probability distribution, and at least two conditional probability distributions that help us better understand the social and cultural game underlying the production of your corpus. Create a wordl of words (or normalized words) and add a few vague comments about what mysteries are revealed through it.</span>

# %% [markdown]
# In this part, I intend to filter and normalize the tokens in my corpus, as well as explore the word distribution of it. My work contains three part: 1)filter, stem and lemmatize the tokens, 2) plot word frequency / probability distribution and 3)create a word cloud to see how can we learn from it.

# %% [markdown]
# ## Filter and Normalize Data

# %% [markdown]
# As we can see from the exercise 1, our list now contains a lot of non-word tokens (like punctuations) and meaningless words (like prepositions and articles). In order to better analyzing the text, I will filter the tokens in my corpus using the stopwords list.
#
# Firstly, I will create a `DataFrame` to contain text.

# %%
#Convert the text into dataframe
hpStoneSentences = hpStoneContent.replace('\n','').split('.')
hpStoneSentencesDF = pandas.DataFrame(hpStoneSentences,columns=['text'])
#Add a column to contain tokenized text
hpStoneSentencesDF['tokenized_text'] = hpStoneSentencesDF['text'].apply(lambda x: nltk.word_tokenize(x))
#Add a column to contain word counts
hpStoneSentencesDF['word_counts'] = hpStoneSentencesDF['tokenized_text'].apply(lambda x: len(x))
hpStoneSentencesDF['word_counts']
# Out:
# 0       11
# 1        2
# 2       22
# 3       25
# 4        1
# 5       12
# 6       19
# 7        1
# 8       34
# 9       17
# 10      23
# 11      13
# 12       1
# 13       3
# 14      17
# 15      23
# 16      16
# 17      19
# 18      21
# 19       2
# 20       2
# 21      33
# 22       1
# 23      14
# 24      13
# 25      13
# 26       6
# 27       8
# 28      26
# 29       7
#         ..
# 6107    29
# 6108    14
# 6109    11
# 6110    31
# 6111     7
# 6112    20
# 6113     2
# 6114     5
# 6115     7
# 6116     6
# 6117    10
# 6118     1
# 6119     9
# 6120    39
# 6121    16
# 6122    11
# 6123     1
# 6124    11
# 6125    10
# 6126     4
# 6127    11
# 6128     8
# 6129    27
# 6130    22
# 6131    13
# 6132    13
# 6133     0
# 6134     0
# 6135     0
# 6136     3
# Name: word_counts, Length: 6137, dtype: int64

# %% [markdown]
# Now, I will create my own stop list

# %%
#Create a dictionary for stop words
countsDict = {}
for word in hpStoneSentencesDF['tokenized_text'].sum():
    if word in countsDict:
        countsDict[word] += 1
    else:
        countsDict[word] = 1
word_counts = sorted(countsDict.items(), key = lambda x : x[1], reverse = True)
word_counts[:10]
# Out:
# [(',', 5648),
#  ('``', 3349),
#  ('the', 2880),
#  ('to', 1649),
#  ('and', 1612),
#  ('a', 1417),
#  ("''", 1410),
#  ('Harry', 1222),
#  ('of', 1114),
#  ('was', 1114)]

# %% [markdown]
# Here I will pick "Harry" as the cutoff, cut all words before "Harry".

# %%
#The stop list is then all words that occur before 'Harry'
stop_words_freq = []
for word, count in word_counts:
    if word == 'Harry':
        break
    else:
        stop_words_freq.append(word)
stop_words_freq

wordnet = nltk.stem.WordNetLemmatizer()
#Check if the command can lemmatize words
wordnet.lemmatize('democracies')
# Out:
# 'democracy'

# %% [markdown]
# Create a function to normalize the tokens.

# %%
#Use the stop words list for English
stop_words_nltk = stopwords.words('english')

#Initialize the stemmer and lemmer
porter = nltk.stem.porter.PorterStemmer()
snowball = nltk.stem.snowball.SnowballStemmer('english')
wordnet = nltk.stem.WordNetLemmatizer()

#The function to normalize tokens
def normlizeTokens(tokenLst, stopwordLst = None, stemmer = None, lemmer = None):

    #Lowering the case and removing non-words
    workingIter = (w.lower() for w in tokenLst if w.isalpha())

    #Now we can use the semmer, if provided
    if stemmer is not None:
        workingIter = (stemmer.stem(w) for w in workingIter)
        
    #And the lemmer
    if lemmer is not None:
        workingIter = (lemmer.lemmatize(w) for w in workingIter)
    
    #And remove the stopwords
    if stopwordLst is not None:
        workingIter = (w for w in workingIter if w not in stopwordLst)
    #We will return a list with the stopwords removed
    return list(workingIter)

hpStoneSentencesDF['normalized_tokens'] = hpStoneSentencesDF['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

hpStoneSentencesDF['normalized_tokens_count'] = hpStoneSentencesDF['normalized_tokens'].apply(lambda x: len(x))

hpStoneSentencesDF
# Out:
#                                                    text  \
# 0
# Harry Potter and the Sorcerer's StoneCHAPTER ...
# 1                                               and Mrs
# 2      Dursley, of number four, Privet Drive, were p...
# 3      They were the lastpeople you'd expect to be i...
# 4                                                    Mr
# 5      Dursley was the director of a firm called Gru...
# 6      He was a big, beefy man with hardly any neck,...
# 7                                                   Mrs
# 8      Dursley was thin and blonde and hadnearly twi...
# 9      The Dursleys had a small son called Dudley an...
# 10    The Dursleys had everything they wanted, but t...
# 11     They didn'tthink they could bear it if anyone...
# 12                                                  Mrs
# 13                                       Potter was Mrs
# 14     Dursley's sister, but they hadn't met for sev...
# 15     Dursley pretended she didn't have a sister, b...
# 16     The Dursleys shuddered to think what the neig...
# 17     The Dursleys knew that thePotters had a small...
# 18     This boywas another good reason for keeping t...
# 19                                              When Mr
# 20                                              and Mrs
# 21     Dursley woke up on the dull, gray Tuesday our...
# 22                                                   Mr
# 23     Dursley hummed as he picked out his most bori...
# 24     Dursley gossiped away happily as she wrestled...
# 25    None of them noticed a large, tawny owl flutte...
# 26                               At half past eight, Mr
# 27          Dursley picked up his briefcase, pecked Mrs
# 28    Dursley on the cheek, and tried to kiss Dudley...
# 29                           "Little tyke," chortled Mr
# ...                                                 ...
# 6107   Some of them called:"Bye, Harry!""See you, Po...
# 6108   "Not where I'm going, I promise you," said Harry
# 6109  He, Ron, and Hermione passed through the gatew...
# 6110   "There he is,Mom, there he is, look!"248
# It w...
# 6111                       "Harry Potter!" she squealed
# 6112   "Look, Mom! I can see"Be quiet, Ginny, and it...
# 6113                                               "Mrs
# 6114                        Weasley smiled down at them
# 6115                              "Busy year?" she said
# 6116                                 "Very," said Harry
# 6117         "Thanks for the fudge and the sweater, Mrs
# 6118                                            Weasley
# 6119                         ""Oh, it was nothing, dear
# 6120  ""Ready, are you?"It was Uncle Vernon, still p...
# 6121   Behind him stood Aunt Petunia and Dudley,look...
# 6122             "You must be Harry's family!" said Mrs
# 6123                                            Weasley
# 6124       "In a manner of speaking," said Uncle Vernon
# 6125              "Hurry up, boy, we haven'tgot all day
# 6126                                   " He walked away
# 6127  Harry hung back for a last word with Ron and H...
# 6128                     "See you over the summer, then
# 6129  ""Hope you have -- er -- a good holiday," said...
# 6130  "Oh, I will," said Harry, and they were surpri...
# 6131   "They don't know we're not allowed to use mag...
# 6132   I'm going to have a lot of fun with Dudley th...
# 6133
# 6134
# 6135
# 6136                                       "THE END249
#
#
#                                          tokenized_text  word_counts  \
# 6132  [I, 'm, going, to, have, a, lot, of, fun, with...           13
# 6133                                                 []            0
# 6134                                                 []            0
# 6135                                                 []            0
# 6136                                  [``, THE, END249]            3
#
#                                       normalized_tokens  \
# 0     [harri, potter, sorcer, stonechapt, oneth, boy...
# 1                                                  [mr]
# 2     [dursley, number, four, privet, drive, proud, ...
# 3     [lastpeopl, expect, involv, anyth, strang, mys...
# 4                                                  [mr]
# 5     [dursley, wa, director, firm, call, grun, made...
# 6     [wa, big, beefi, man, hardli, ani, neck, altho...
# 7                                                  [mr]
# 8     [dursley, wa, thin, blond, hadnearli, twice, u...
# 9     [dursley, small, son, call, dudley, theiropini...
# 10    [dursley, everyth, want, also, secret, andthei...
# 11                  [could, bear, anyon, found, potter]
# 12                                                 [mr]
# 13                                     [potter, wa, mr]
# 14        [dursley, sister, met, sever, year, fact, mr]
# 15    [dursley, pretend, sister, becaus, hersist, hu...
# 16    [dursley, shudder, think, neighbor, wouldsay, ...
# 17    [dursley, knew, thepott, small, son, never, ev...
# 18    [thi, boywa, anoth, good, reason, keep, potter...
# 19                                                 [mr]
# 20                                                 [mr]
# 21    [dursley, woke, dull, gray, tuesday, storystar...
# 22                                                 [mr]
# 23     [dursley, hum, pick, hi, bore, tie, forwork, mr]
# 24    [dursley, gossip, away, happili, wrestl, screa...
# 25    [none, notic, larg, tawni, owl, flutter, past,...
# 26                              [half, past, eight, mr]
# 27              [dursley, pick, hi, briefcas, peck, mr]
# 28    [dursley, cheek, tri, kiss, dudley, becaus, du...
# 29                            [littl, tyke, chortl, mr]
# ...                                                 ...
# 6107  [call, bye, harri, see, potter, still, famou, ...
# 6108                          [go, promis, said, harri]
# 6109              [ron, hermion, pass, gateway, togeth]
# 6110  [mom, look, wa, ginni, weasley, ron, younger, ...
# 6111                            [harri, potter, squeal]
# 6112        [look, mom, see, quiet, ginni, rude, point]
# 6113                                               [mr]
# 6114                                   [weasley, smile]
# 6115                                 [busi, year, said]
# 6116                                [veri, said, harri]
# 6117                         [thank, fudg, sweater, mr]
# 6118                                          [weasley]
# 6119                               [oh, wa, noth, dear]
# 6120  [readi, wa, uncl, vernon, still, still, mustac...
# 6121  [behind, stood, aunt, petunia, dudley, look, t...
# 6122                    [must, harri, famili, said, mr]
# 6123                                          [weasley]
# 6124                [manner, speak, said, uncl, vernon]
# 6125                                  [hurri, boy, day]
# 6126                                       [walk, away]
# 6127      [harri, hung, back, last, word, ron, hermion]
# 6128                                      [see, summer]
# 6129  [hope, er, good, holiday, said, hermion, looki...
# 6130  [oh, said, harri, surpris, grin, wasspread, hi...
# 6131                  [know, allow, use, magicat, home]
# 6132                [go, lot, fun, dudley, thi, summer]
# 6133                                                 []
# 6134                                                 []
# 6135                                                 []
# 6136                                                 []
#
#       normalized_tokens_count
# 0                           7
# 1                           1
# 2                          12
# 3                           9
# 4                           1
# 5                           7
# 6                          12
# 7                           1
# 8                          20
# 9                          10
# 10                         12
# 11                          5
# 12                          1
# 13                          3
# 14                          7
# 15                          8
# 16                          8
# 17                          8
# 18                         12
# 19                          1
# 20                          1
# 21                         19
# 22                          1
# 23                          8
# 24                          9
# 25                          8
# 26                          4
# 27                          6
# 28                         13
# 29                          4
# ...                       ...
# 6107                       10
# 6108                        4
# 6109                        5
# 6110                       11
# 6111                        3
# 6112                        7
# 6113                        1
# 6114                        2
# 6115                        3
# 6116                        3
# 6117                        4
# 6118                        1
# 6119                        4
# 6120                       17
# 6121                       10
# 6122                        5
# 6123                        1
# 6124                        5
# 6125                        3
# 6126                        2
# 6127                        7
# 6128                        2
# 6129                       13
# 6130                        8
# 6131                        5
# 6132                        6
# 6133                        0
# 6134                        0
# 6135                        0
# 6136                        0
#
# [6137 rows x 5 columns]

# %% [markdown]
# ## Word Distributions
#
# ### Frequency Distributions
#
# After filtering and normalizing the text, now we can start analyzing the textual content in HP book. I will start with finding frequency distributions.
#
# To this end, I will apply the `ConditionalFreqDist` and use word lengths as the conditions.

# %%
#.sum() adds together the lists from each row into a single list
hpcfdist = nltk.ConditionalFreqDist(((len(w), w) for w in hpStoneSentencesDF['normalized_tokens'].sum()))

#print the number of words
print(hpcfdist.N())
# Out:
# 42603

# %% [markdown]
# #### Frequency Distributions based on Word Length

# %% [markdown]
# Lookup the distributions of different word lengths.

# %%
hpcfdist[3].plot(20) #Only plot first 20 words

# %% [markdown]
# As the figure shows, the most common 3-character word in the first HP book is 'ron', which is the name of one of the main characters. And the other most frequent words includes 'one','thi','get' and 'got'.
#
# I want to make sure that 'thi' if is stemmed from 'this' by the Porter Stemmer.

# %%
porter = nltk.stem.porter.PorterStemmer()
print (porter.stem('this'))
# Out:
# thi

# %% [markdown]
# #### Frequency Distribution based on POS

# %% [markdown]
# Another feature of word is a word's role in the sentence, or say, its part of speech (POS). So next I will classify words based on their POS, using the `nltk.pos_tag()`.

# %%
hpStoneSentencesDF['normalized_tokens_POS'] = [nltk.pos_tag(t) for t in hpStoneSentencesDF['normalized_tokens']]

# %% [markdown]
# Now we have a new column with the POS as a short initialism and the word in a tuple. Therefore, we can construct another frequency distribution according to the POS.

# %%
hpcfdist_WordtoPOS = nltk.ConditionalFreqDist(hpStoneSentencesDF['normalized_tokens_POS'].sum())
list(hpcfdist_WordtoPOS.items())[:10]
# Out:
# [('harri',
#   FreqDist({'CD': 2,
#             'JJ': 160,
#             'NN': 995,
#             'NNS': 14,
#             'PRP': 3,
#             'PRP$': 2,
#             'RB': 13,
#             'RBR': 2,
#             'VB': 8,
#             'VBD': 10,
#             'VBN': 2,
#             'VBP': 8,
#             'VBZ': 4})),
#  ('potter', FreqDist({'JJ': 3, 'JJR': 1, 'NN': 98, 'RB': 1, 'VB': 1})),
#  ('sorcer', FreqDist({'JJ': 1, 'NN': 12, 'VBD': 2})),
#  ('stonechapt', FreqDist({'NN': 1})),
#  ('oneth', FreqDist({'VBP': 1, 'VBZ': 1})),
#  ('boy', FreqDist({'IN': 5, 'JJ': 7, 'NN': 72, 'NNS': 1, 'UH': 3})),
#  ('livedmr', FreqDist({'NN': 1})),
#  ('mr', FreqDist({'JJ': 1, 'NN': 120, 'VBD': 1})),
#  ('dursley',
#   FreqDist({'JJ': 8,
#             'NN': 76,
#             'NNS': 3,
#             'RB': 2,
#             'VB': 1,
#             'VBD': 1,
#             'VBZ': 3})),
#  ('number', FreqDist({'NN': 18}))]

# %% [markdown]
# Simply looking at the frequency of each word as each part of speench is uninformative. I want to see what is the part-of-speech role of the word 'professor', which is a frequent word in this book.

# %%
hpcfdist_WordtoPOS['professor'].plot()

# %% [markdown]
# As we can see, the word 'professor' most often acts like the noun (NN) and sometimes the adjective (JJ), which means it either used to represent someone or in front someone's name.
#
# However, what can be more useful is the frequency of each POS for each word.

# %%
hpcfdist_POStoWord = nltk.ConditionalFreqDist((p, w) for w, p in hpStoneSentencesDF['normalized_tokens_POS'].sum())

#Identify and collect all of the superlative adjectives
hpcfdist_POStoWord['JJS']
#See the most common ones
hpcfdist_POStoWord['JJS'].most_common(10)
# Out:
# [('best', 30),
#  ('forest', 21),
#  ('least', 11),
#  ('nearest', 6),
#  ('greatest', 5),
#  ('youngest', 5),
#  ('worst', 4),
#  ('smallest', 4),
#  ('biggest', 3),
#  ('safest', 2)]

# %% [markdown]
# The most frequent superlative adjectives is 'best'.
#
# We can also look at the most common interjection.

# %%
hpcfdist_POStoWord['UH'].most_common(10)
# Out:
# [('oh', 33), ('boy', 3)]

# %% [markdown]
# Moreover, we can plot the base form verbs against their number of occurences.

# %%
hpcfdist_POStoWord['VB'].plot(20)

# %% [markdown]
# ### Conditional Probability Distributions

# %% [markdown]
# In addition to the word frequency distribution, I will explore the word probability distribution as well. Similarly, what I am looking for here is the conditional distribution.
#
# I will examine the conditional probability distribution of words using `ConditionalFreqDist`. The model I apply here is `ELEProbDist` which gives the expected likelihood estimate for the probability distribution.
#
# #### Conditional Probability based on word length
#
# Firstly, let's see the distribution based on the word length.

# %%
hpcpdist = nltk.ConditionalProbDist(hpcfdist, nltk.ELEProbDist)

#print the most common 3 letter word
print(hpcpdist[3].max())
#And its probability
print(hpcpdist[3].prob(hpcpdist[3].max()))
# Out:
# ron
# 0.07833572453371593

# %% [markdown]
# The most common 3 letter word is 'ron' with a probability of approximately 0.078.

# %% [markdown]
# #### Conditional Probability based on POS

# %% [markdown]
# Secondly, I will examine word probability distribution based on their POS.

# %%
hpcpdist_POStoWord = nltk.ConditionalProbDist(hpcfdist_POStoWord, nltk.ELEProbDist)

#print the most common nouns
print(hpcpdist_POStoWord['NN'].max())

#And its probability
print(hpcpdist_POStoWord['NN'].prob(hpcpdist_POStoWord['NN'].max()))
# Out:
# harri
# 0.03782438542497815

# %% [markdown]
# The most common nouns is 'harri' (stemmed from 'Harry') with a probability of approximately 0.038.

# %%
#print the most common adjective
print(hpcpdist_POStoWord['VB'].max())
#And its probability
print(hpcpdist_POStoWord['VB'].prob(hpcpdist_POStoWord['VB'].max()))
# Out:
# go
# 0.06361579079708322

# %% [markdown]
# The most common verb is "go" with a probability of approximately 0.064.
#
# ### Word Cloud
#
# At last, I will create a Word Cloud (using normalized words) to draw mystical, approximately inferences about important nouns and verbs in my corpus.

# %%
wc = wordcloud.WordCloud(background_color="white", max_words=500, width= 1000, height = 1000, mode ='RGBA', scale=.5).generate(' '.join(hpStoneSentencesDF['normalized_tokens'].sum()))
plt.imshow(wc)
plt.axis("off")
plt.suptitle("Word Cloud for Harry Potter and the Sorcerer's Stone")
plt.savefig("hpStone_word_cloud.pdf", format = 'pdf')

# %% [markdown]
# ### Interpretations

# %% [markdown]
# There are few things we can learn from this word cloud:
#
# 1) Most of the important nouns in the book 'Harry Potter and the Sorcerer's Stone' are the name of the characters. Except for 'Harry', other words includes 'Ron','Hermione','Hagrid','Snape', 'Malfoy' and 'Nevil'. This feature is consistent with the theme of Harry Potter series, which focuses on the life trajectory of Harry and his friends. It's interesting that all the characters from Gryffindor are written in their first names (e.g. Ron,Nevil, Hagrid), while the ones from Slytherin are called in their last names (e.g. Snape, Malfoy). So even without the story plots, we can know that JK Rowling tried to build Gryffindor as the good side and Slytherin as the villain.
#
# 2) Most of the important verbs in this book, including 'look','go','got','know','think','say','come','want', are words that represent for positive action. This reveals that as the first book of HP series, what Harry experienced are basically good and new things, like knowing new people, learing magic and experiencing adventures. Also, verbs with high frequency are all very easy English word, which make JK Rowling's book easy to read and follow.

# %% [markdown]
# # Collocations

# %% [markdown]
# As illustrated above, we might want to find significant bigrams (two-word phrases), trigrams (three-word phrases), n-grams (*n*-word phrases) or skip-grams (noncontinguous 'phrases' with skip-length *n*). We will begin with the [`nltk.collocations.BigramCollocationFinder`](http://www.nltk.org/api/nltk.html?highlight=bigramcollocationfinder#nltk.collocations.BigramCollocationFinder) class, which can be given raw lists of strings with the `from_words()` method. By default it only looks at continuous bigrams but there is an option (`window_size`) to allow skip-grams.

# %%
whBigrams = nltk.collocations.BigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(whBigrams.N))
# Out:
# There are 1999 bigrams in the finder

# %% [markdown]
# To compare the bigrams we need to tell nltk what our score function is. Initially, we will look at the raw counts.

# %%
def bigramScoring(count, wordsTuple, total):
    return count

print(whBigrams.nbest(bigramScoring, 10))
# Out:
# [('rhode', 'island'), ('presid', 'bush'), ('sheldon', 'whitehous'), ('stem', 'cell'), ('whitehous', 'said'), ('bush', 'administr'), ('american', 'peopl'), ('bring', 'troop'), ('senat', 'sheldon'), ('troop', 'home')]

# %% [markdown]
# One note about how `BigramCollocationFinder` works. It doesn't use the strings internally.

# %%
birgramScores = []

def bigramPrinting(count, wordsTuple, total):
    global birgramScores
    birgramScores.append("The first word is:  {}, The second word is: {}".format(*wordsTuple))
    #Returns None so all the tuples are considered to have the same rank

whBigrams.nbest(bigramPrinting, 10)
print('\n'.join(birgramScores[:10]))
# Out:
# The first word is:  40, The second word is: 4
# The first word is:  4, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 2
# The first word is:  2, The second word is: 12
# The first word is:  12, The second word is: 12
# The first word is:  12, The second word is: 9
# The first word is:  9, The second word is: 4
# The first word is:  4, The second word is: 2

# %% [markdown]
# The words are each given numeric IDs and there is a dictionary that maps the IDs to the words they represent. This is a common performance optimization.
#
# Two words can appear together by chance. Recall from  Manning and Schütze's textbook that a $t-value can be computed for each bigram to see how significant the association is. You may also want to try computing the $\chi^2$, likelihood ratio, and pointwise mutual information statistics.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
whBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:40]
# other options include student_t, chi_sq, likelihood_ratio, pmi
# Out:
# [(('rhode', 'island'), 223.9860316954852),
#  (('stem', 'cell'), 146.69971583676724),
#  (('presid', 'bush'), 124.78339903371594),
#  (('sheldon', 'whitehous'), 97.83057167237577),
#  (('unit', 'state'), 63.7408597571739),
#  (('whitehous', 'said'), 50.85365409523493),
#  (('jack', 'reed'), 46.61449955206517),
#  (('honor', 'societi'), 45.00623576992483),
#  (('american', 'peopl'), 44.4949166648486),
#  (('bring', 'troop'), 43.29082241816299),
#  (('bush', 'administr'), 42.73672706610401),
#  (('cell', 'research'), 41.25934273451902),
#  (('youth', 'program'), 38.276119099832265),
#  (('troop', 'home'), 36.87601441962918),
#  (('come', 'home'), 36.661589434392276),
#  (('senat', 'sheldon'), 36.08708619238288),
#  (('epw', 'committe'), 34.42122395939712),
#  (('potenti', 'close'), 33.7794434582587),
#  (('budget', 'resolut'), 32.192797473966614),
#  (('district', 'columbia'), 31.62701894759353),
#  (('humpti', 'dumpti'), 31.62701894759353),
#  (('jose', 'socrat'), 31.62701894759353),
#  (('prime', 'minist'), 31.62701894759353),
#  (('weaver', 'cove'), 31.62701894759353),
#  (('chang', 'cours'), 31.55001446652071),
#  (('confirm', 'hear'), 27.80793393782465),
#  (('harm', 'way'), 27.80793393782465),
#  (('interest', 'payment'), 27.80793393782465),
#  (('trillion', 'foregon'), 27.80793393782465),
#  (('foregon', 'surplus'), 26.081841503113964),
#  (('senat', 'youth'), 25.938248175532106),
#  (('consul', 'provid'), 25.75753014835219),
#  (('year', 'ago'), 25.07814446954526),
#  (('high', 'school'), 24.896902277500963),
#  (('reconsid', 'potenti'), 24.896902277500963),
#  (('one', 'thing'), 23.98985093210625),
#  (('circuit', 'court'), 23.988848928055774),
#  (('cost', 'america'), 23.988848928055774),
#  (('general', 'counsel'), 23.988848928055774),
#  (('misguid', 'polici'), 23.988848928055774)]

# %% [markdown]
# There are a few other available measures

# %%
[s for s in dir(bigram_measures) if s[0] != '_']
# Out:
# ['chi_sq',
#  'dice',
#  'fisher',
#  'jaccard',
#  'likelihood_ratio',
#  'mi_like',
#  'phi_sq',
#  'pmi',
#  'poisson_stirling',
#  'raw_freq',
#  'student_t']

# %% [markdown]
# We can also look at trigrams

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
whTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(whReleases['normalized_tokens'].sum())
whTrigrams.score_ngrams(trigram_measures.student_t)[:20]
# Out:
# [(('bring', 'troop', 'home'), 2.449202865677887),
#  (('senat', 'sheldon', 'whitehous'), 2.4481166557834917),
#  (('stem', 'cell', 'research'), 2.2359229352888974),
#  (('whitehous', 'said', 'today'), 1.9987987990993996),
#  (('jack', 'reed', 'sheldon'), 1.7319953264758123),
#  (('senat', 'youth', 'program'), 1.7319901251233376),
#  (('unit', 'state', 'senat'), 1.73173525885207),
#  (('new', 'direct', 'iraq'), 1.7316624399174225),
#  (('reed', 'sheldon', 'whitehous'), 1.7314959966382275),
#  (('sheldon', 'whitehous', 'said'), 1.7309411857075774),
#  (('trillion', 'foregon', 'surplus'), 1.414209315486583),
#  (('reconsid', 'potenti', 'close'), 1.4142064842289084),
#  (('sent', 'clear', 'messag'), 1.414205599460885),
#  (('today', 'confirm', 'hear'), 1.4141976365486753),
#  (('select', 'committe', 'intellig'), 1.4141965748270473),
#  (('general', 'david', 'petraeus'), 1.4141923279405353),
#  (('take', 'respons', 'secur'), 1.4141923279405353),
#  (('cell', 'enhanc', 'act'), 1.4141880810540235),
#  (('respons', 'secur', 'govern'), 1.4141880810540235),
#  (('new', 'sourc', 'review'), 1.41416897006472)]

# %% [markdown]
# Or n-grams (for any number n)

# %%
Ngrams = nltk.ngrams(whReleases['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)
# Out:
# {('stem', 'cell', 'research', 'whitehous'): 2, ('stem', 'cell', 'enhanc', 'act'): 2, ('begin', 'bring', 'troop', 'home'): 2, ('bring', 'troop', 'home', 'iraq'): 2, ('senat', 'sheldon', 'whitehous', 'said'): 3, ('sheldon', 'whitehous', 'said', 'today'): 3, ('member', 'senat', 'select', 'committe'): 2, ('senat', 'select', 'committe', 'intellig'): 2, ('take', 'respons', 'secur', 'govern'): 2, ('senat', 'jack', 'reed', 'sheldon'): 2, ('jack', 'reed', 'sheldon', 'whitehous'): 3, ('whitehous', 'welcom', 'rhode', 'island'): 2, ('portugues', 'american', 'citizen', 'rhode'): 2, ('american', 'citizen', 'rhode', 'island'): 2}

# %% [markdown]
# ## <span style="color:red">*Exercise 3*</span>
#
# <span style="color:red">Construct cells immediately below this that identify statistically significant bigrams, trigrams, quadgrams, higher-order *n*grams and skipgrams. Explore whether these collocations are idiomatic and so irreducible to the semantic sum of their component words. You can do this by examination of conditional frequencies (e.g., what else is 'united' besides the 'United States'). If these phrases are idiomatic, what do they suggest about the culture of the world producing them?
#
# <span style="color:red">**Stretch**: In Manning and Schütze's textbook, there Section 5.3.2 explores how to use the *t*-test to find words whose co-occurance patterns best distinguish two words. Implement that and use it to explore phrases in your corpus. For instance, you could tell what words come after "America" much more often than after "Iraq"?</span>

# %% [markdown]
# In this part, I intend to find significant collocations in Harry Potter and the Sorcerer's Stone. The coding class I apply here is `nltk.collocations.CigramCollocationFinder`.
#
# ### Bigrams
#
# At first, I will count the number of bigrams in my corpora.

# %%
hpBigrams = nltk.collocations.BigramCollocationFinder.from_words(hpStoneSentencesDF['normalized_tokens'].sum())
print("There are {} bigrams in the finder".format(hpBigrams.N))
# Out:
# There are 42603 bigrams in the finder

# %% [markdown]
# In order to select out those most significant bigrams, I will use a function which gives us the scores of the bigrams.

# %%
def bigramScoring(count, wordsTuple, total):
    return count

print(hpBigrams.nbest(bigramScoring, 10))
# Out:
# [('said', 'harri'), ('said', 'ron'), ('uncl', 'vernon'), ('said', 'hagrid'), ('professor', 'mcgonagal'), ('harri', 'wa'), ('aunt', 'petunia'), ('mr', 'dursley'), ('wa', 'go'), ('harri', 'ron')]

# %% [markdown]
# However, two words can co-occur accidentally. To examine the statistical significance of the bigrams, I will use the statistical methods of likelihood ratio.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
hpBigrams.score_ngrams(bigram_measures.likelihood_ratio)[:40]
# other options include student_t, chi_sq, likelihood_ratio, pmi
# Out:
# [(('uncl', 'vernon'), 1258.2788769496065),
#  (('professor', 'mcgonagal'), 864.2143059668725),
#  (('aunt', 'petunia'), 615.1667705078339),
#  (('mr', 'dursley'), 428.63377998049015),
#  (('said', 'ron'), 426.91125224253364),
#  (('said', 'hagrid'), 331.10067854219665),
#  (('said', 'harri'), 309.8149051859824),
#  (('crabb', 'goyl'), 216.33192033078106),
#  (('fred', 'georg'), 203.5291024908316),
#  (('hi', 'eye'), 177.82701158270038),
#  (('hi', 'head'), 177.82701158270038),
#  (('privet', 'drive'), 174.7981966365198),
#  (('platform', 'nine'), 167.75536877511584),
#  (('mr', 'ollivand'), 166.54390036088586),
#  (('common', 'room'), 162.54193292447457),
#  (('could', 'see'), 143.5793081443167),
#  (('leaki', 'cauldron'), 141.6401549437068),
#  (('hi', 'hand'), 139.8115803036555),
#  (('nimbu', 'two'), 135.68119879910518),
#  (('madam', 'pomfrey'), 135.15756637169187),
#  (('lee', 'jordan'), 133.26640311722034),
#  (('hermion', 'granger'), 132.4987264459631),
#  (('nicola', 'flamel'), 126.35110339185596),
#  (('madam', 'hooch'), 124.7282862132742),
#  (('two', 'thousand'), 120.40121427519001),
#  (('said', 'hermion'), 119.56776640134687),
#  (('professor', 'dumbledor'), 119.52782968370312),
#  (('first', 'year'), 118.45674552524795),
#  (('chocol', 'frog'), 115.23301706916784),
#  (('professor', 'flitwick'), 114.385847362848),
#  (('diagon', 'alley'), 112.67257229038569),
#  (('hi', 'face'), 112.1695282022162),
#  (('next', 'morn'), 111.40582919132518),
#  (('mr', 'norri'), 111.2571357921988),
#  (('sorcer', 'stone'), 109.15822789429613),
#  (('invis', 'cloak'), 108.51999918911635),
#  (('great', 'hall'), 108.02497536809778),
#  (('ron', 'hermion'), 106.20981489435823),
#  (('harri', 'felt'), 102.64841556090163),
#  (('fat', 'ladi'), 102.4010033684051)]

# %% [markdown]
# Also, I will use t-test to double-check the significance of bigrams.

# %%
hpBigrams.score_ngrams(bigram_measures.student_t)[:40]
# Out:
# [(('uncl', 'vernon'), 9.97055841137948),
#  (('said', 'harri'), 9.922267519199885),
#  (('said', 'ron'), 9.735020545122246),
#  (('professor', 'mcgonagal'), 8.795190361927148),
#  (('said', 'hagrid'), 8.673051431745764),
#  (('aunt', 'petunia'), 6.771352214307971),
#  (('mr', 'dursley'), 6.742641126631962),
#  (('hi', 'eye'), 5.994677274722123),
#  (('hi', 'head'), 5.994677274722123),
#  (('said', 'hermion'), 5.777909457333431),
#  (('wa', 'go'), 5.707975135296977),
#  (('hi', 'hand'), 5.418369811465397),
#  (('could', 'see'), 5.186903225735978),
#  (('ron', 'hermion'), 5.131527059404804),
#  (('harri', 'could'), 5.117192172376923),
#  (('wa', 'veri'), 5.066655556795571),
#  (('hi', 'face'), 5.026440624988379),
#  (('harri', 'ron'), 4.863208912950204),
#  (('harri', 'potter'), 4.727292856960183),
#  (('said', 'dumbledor'), 4.707621102048067),
#  (('harri', 'felt'), 4.526470427201387),
#  (('professor', 'dumbledor'), 4.467020555558991),
#  (('hi', 'feet'), 4.141739393748448),
#  (('look', 'like'), 4.1255698245526355),
#  (('wa', 'still'), 4.013207448047893),
#  (('fred', 'georg'), 3.9949299345116542),
#  (('mr', 'ollivand'), 3.98496584747553),
#  (('hermion', 'granger'), 3.962884069197005),
#  (('first', 'year'), 3.955402201722883),
#  (('ye', 'said'), 3.949842745028074),
#  (('crabb', 'goyl'), 3.8701954794073394),
#  (('thi', 'time'), 3.8353402342558036),
#  (('common', 'room'), 3.7331257038173207),
#  (('hi', 'mother'), 3.7183597686631282),
#  (('harri', 'wa'), 3.6899674009250454),
#  (('thi', 'wa'), 3.663636238256334),
#  (('harri', 'ask'), 3.599844003222541),
#  (('hi', 'arm'), 3.5403033957014096),
#  (('hi', 'wand'), 3.5387969044181484),
#  (('first', 'time'), 3.5261279673172887)]

# %% [markdown]
# According to the t-test results, we can see that bigram including "uncle vernon", "professor macgonagal", "common room", "fred georg", etc, are statistically significant.
#
# ### Trigrams

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
hpTrigrams = nltk.collocations.TrigramCollocationFinder.from_words(hpStoneSentencesDF['normalized_tokens'].sum())
hpTrigrams.score_ngrams(trigram_measures.student_t)[:20]
# Out:
# [(('nimbu', 'two', 'thousand'), 3.464097101347196),
#  (('said', 'uncl', 'vernon'), 3.462571494055726),
#  (('said', 'professor', 'mcgonagal'), 3.462423032176046),
#  (('harri', 'could', 'see'), 2.989783489514883),
#  (('shook', 'hi', 'head'), 2.828150100223305),
#  (('harri', 'ron', 'hermion'), 2.8037755351770404),
#  (('hagrid', 'said', 'harri'), 2.5795308599628775),
#  (('said', 'hagrid', 'harri'), 2.5795308599628775),
#  (('get', 'past', 'fluffi'), 2.4494472988217995),
#  (('professor', 'mcgonagal', 'wa'), 2.446020233474692),
#  (('ye', 'said', 'harri'), 2.4349313000575123),
#  (('said', 'ron', 'look'), 2.424440705709304),
#  (('seven', 'hundr', 'thirteen'), 2.236067181638913),
#  (('everi', 'flavor', 'bean'), 2.2360670993424634),
#  (('vault', 'seven', 'hundr'), 2.2360663857780363),
#  (('hermion', 'granger', 'wa'), 2.234320945837478),
#  (('said', 'harri', 'wa'), 2.212967796472),
#  (('hundr', 'fifti', 'point'), 1.9999903339674254),
#  (('fred', 'georg', 'weasley'), 1.999987623246936),
#  (('malfoy', 'crabb', 'goyl'), 1.9999853004018986)]

# %% [markdown]
# According to the t-test results, trigrams including "nimbu two thousand", "said uncle vernon", "harry could see", "get past fluffi", etc, are statistically significant.
#
# ### Quadgram and N-grams
#
# Here we use a loop to identify N-grams collocation in the text. By setting the size number as 4, we can look for quadgram in the book of Harry Potter.

# %%
Ngrams = nltk.ngrams(hpStoneSentencesDF['normalized_tokens'].sum(), 4)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)
# Out:
# {('know', 'said', 'professor', 'mcgonagal'): 2, ('could', 'kill', 'littl', 'boy'): 2, ('world', 'know', 'hi', 'name'): 2, ('first', 'time', 'hi', 'life'): 4, ('uncl', 'vernon', 'sister', 'marg'): 2, ('said', 'uncl', 'vernon', 'tri'): 2, ('read', 'hogwart', 'school', 'witchcraft'): 2, ('dumbledor', 'onli', 'one', 'wa'): 2, ('say', 'die', 'codswallop', 'opinion'): 2, ('die', 'codswallop', 'opinion', 'dunno'): 2, ('got', 'ta', 'get', 'ter'): 2, ('hagrid', 'said', 'harri', 'loudli'): 2, ('yeh', 'mad', 'ter', 'tri'): 2, ('mad', 'ter', 'tri', 'rob'): 2, ('magic', 'wand', 'thi', 'wa'): 2, ('vault', 'seven', 'hundr', 'thirteen'): 4, ('harri', 'push', 'hi', 'cart'): 2, ('said', 'harri', 'push', 'hi'): 2, ('harri', 'shook', 'hi', 'head'): 4, ('harri', 'pull', 'back', 'hi'): 2, ('peopl', 'come', 'muggl', 'famili'): 2, ('betti', 'bott', 'everi', 'flavor'): 2, ('bott', 'everi', 'flavor', 'bean'): 3, ('grindelwald', 'discoveri', 'twelv', 'use'): 2, ('tore', 'hi', 'eye', 'away'): 2, ('compart', 'door', 'slid', 'open'): 2, ('learn', 'cours', 'book', 'heart'): 2, ('harri', 'look', 'ron', 'wa'): 2, ('charli', 'romania', 'studi', 'dragon'): 2, ('ye', 'said', 'harri', 'wa'): 2, ('hagrid', 'big', 'hairi', 'face'): 2, ('kept', 'lose', 'hi', 'toad'): 2, ('hi', 'friend', 'crabb', 'goyl'): 2, ('word', 'like', 'professor', 'mcgonagal'): 2, ('like', 'professor', 'mcgonagal', 'snape'): 2, ('got', 'hi', 'feet', 'trembl'): 2, ('nimbu', 'two', 'thousand', 'ron'): 2, ('hi', 'nimbu', 'two', 'thousand'): 3, ('said', 'ron', 'ca', 'said'): 2, ('guard', 'stone', 'apart', 'fluffi'): 2, ('invis', 'cloak', 'said', 'harri'): 2, ('go', 'straight', 'owleri', 'send'): 2, ('straight', 'owleri', 'send', 'hedwig'): 2, ('owleri', 'send', 'hedwig', 'todumbledor'): 2, ('told', 'yeh', 'could', 'die'): 2, ('gryffindor', 'hous', 'fifti', 'point'): 2}

# %% [markdown]
# Here we got some quadgram like 'could kill the little boy', 'first time his life', 'his nimbus two thousand'.
#
# Also, by changing the size number into any number N, we can find N-grams in the text.
#
# ### Skip-gram

# %% [markdown]
# We can look into uncontinuous collocations (skip-gram) by changing the default window_size from 2 to any number greater than 2.

# %%
#Skip-gram
hpSkipgram = nltk.collocations.BigramCollocationFinder.from_words(hpStoneSentencesDF['normalized_tokens'].sum(), window_size = 4)
hpSkipgram.score_ngrams(bigram_measures.student_t)[:20]
# Out:
# [(('uncl', 'vernon'), 5.80921907332773),
#  (('said', 'ron'), 5.2531541032699645),
#  (('professor', 'mcgonagal'), 5.101432609341488),
#  (('said', 'harri'), 4.9327803890977755),
#  (('said', 'hagrid'), 4.612919669398673),
#  (('aunt', 'petunia'), 3.896765988144939),
#  (('mr', 'dursley'), 3.8901061547024436),
#  (('ron', 'hermion'), 3.295503497350232),
#  (('hi', 'eye'), 3.2348650407263655),
#  (('hi', 'head'), 3.2348650407263655),
#  (('said', 'hermion'), 2.9667728981207357),
#  (('hi', 'face'), 2.961812736876101),
#  (('hi', 'hand'), 2.923171993518655),
#  (('could', 'see'), 2.8246503530528737),
#  (('wa', 'go'), 2.7674910490120266),
#  (('wa', 'veri'), 2.700867345621757),
#  (('harri', 'felt'), 2.6936365027456954),
#  (('professor', 'dumbledor'), 2.6412064010463503),
#  (('harri', 'could'), 2.5530951226845136),
#  (('harri', 'ron'), 2.5527084602525076)]

# %% [markdown]
# Because the searching for skip-gram is inclusive, so we will get continuous bigrams as well. In this case, most significant bigrams are continuous ones. So the results are basically similar to our former exploration of bigram.

# %% [markdown]
# ### Frequency Distribution of Collocations

# %% [markdown]
# We can see whether the collocations we found are idiomatic and irreducible by looking at the frequency distribution of them. If a certain collocation shows up frequently (compare to others), we can say that this collocation is worth investigating.
#
# Firstly, let's check the frequency distribution of bigrams.

# %%
Ngrams = nltk.ngrams(hpStoneSentencesDF['normalized_tokens'].sum(), 2)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
print(Filtered)
# Out:
# {
): 3, ('first', 'thing'): 3, ('thing', 'saw'): 2, ('wa', 'sit'): 5, ('garden', 'wall'): 2, ('wall', 'wa'): 3, ('around', 'eye'): 2, ('said', 'mr'): 8, ('cat', 'move'): 2, ('look', 'wa'): 7, ('wa', 'thi'): 4, ('let', 'hous'): 2, ('hous', 'wa'): 5, ('hi', 'wife'): 3, ('next', 'door'): 5, ('went', 'live'): 2, ('live', 'room'): 6, ('hardli', 'ever'): 2, ('ever', 'seen'): 4, ('everi', 'direct'): 2, ('earli', 'next'): 2, ('next', 'week'): 4, ('sat', 'frozen'): 2, ('shoot', 'star'): 3, ('cup', 'tea'): 4, ('clear', 'hi'): 4, ('look', 'shock'): 3, ('funni', 'stuff'): 2, ('lot', 'peopl'): 3, ('dursley', 'well'): 2, ('well', 'thought'): 3, ('thought', 'mayb'): 2, ('mayb', 'wa'): 3, ('wa', 'someth'): 4, ('dare', 'tell'): 2, ('suppos', 'said'): 2, ('hi', 'name'): 12, ('harri', 'nasti'): 2, ('oh', 'ye'): 3, ('ye', 'said'): 18, ('hi', 'heart'): 9, ('say', 'anoth'): 2, ('anoth', 'word'): 3, ('bed', 'mr'): 2, ('front', 'garden'): 2, ('cat', 'wa'): 2, ('wa', 'stare'): 3, ('thing', 'could'): 2, ('well', 'think'): 2, ('fell', 'asleep'): 5, ('lay', 'awak'): 2, ('turn', 'hi'): 11, ('mind', 'hi'): 5, ('wa', 'reason'): 2, ('veri', 'well'): 7, ('petunia', 'could'): 2, ('wrong', 'wa'): 2, ('eye', 'fix'): 3, ('far', 'corner'): 2, ('fact', 'wa'): 3, ('noth', 'like'): 2, ('like', 'thi'): 9, ('thi', 'man'): 2, ('wa', 'tall'): 2, ('tall', 'thin'): 3, ('veri', 'old'): 2, ('hi', 'hair'): 8, ('hair', 'beard'): 4, ('long', 'robe'): 2, ('blue', 'eye'): 3, ('behind', 'hi'): 6, ('hi', 'nose'): 12, ('nose', 'wa'): 4, ('wa', 'veri'): 33, ('long', 'crook'): 2, ('albu', 'dumbledor'): 8, ('name', 'hi'): 2, ('hi', 'cloak'): 6, ('wa ...

# %% [markdown]
# Change the Filtered dictionary into a list and sort it based on the collocation frequency.

# %%
sortFilter = [(k,Filtered[k])for k in sorted(Filtered, key=Filtered.get, reverse=True)]
for k,v in sortFilter: 
    print (k,v)
# Out:
# ('said', 'harri') 139
# ('said', 'ron') 109
# ('uncl', 'vernon') 100
# ('said', 'hagrid') 87
# ('professor', 'mcgonagal') 78
# ('harri', 'wa') 61
# ('mr', 'dursley') 46
# ('aunt', 'petunia') 46
# ('wa', 'go') 45
# ('harri', 'ron') 44
# ('said', 'hermion') 42
# ('hi', 'head') 40
# ('hi', 'eye') 40
# ('harri', 'could') 40
# ('wa', 'veri') 33
# ('hi', 'hand') 33
# ('ron', 'hermion') 31
# ('could', 'see') 29
# ('hi', 'face') 29
# ('harri', 'potter') 28
# ('said', 'dumbledor') 27
# ('thi', 'wa') 24
# ('harri', 'felt') 23
# ('harri', 'look') 23
# ('wa', 'look') 21
# ('professor', 'dumbledor') 21
# ('harri', 'said') 21
# ('wa', 'still') 20
# ('look', 'like') 20
# ('hagrid', 'wa') 20
# ('hi', 'feet') 19
# ('ye', 'said') 18
# ('hagrid', 'said') 18
# ('harri', 'ask') 18
# ('harri', 'hermion') 18
# ('thi', 'time') 16
# ('first', 'year') 16
# ('mr', 'ollivand') 16
# ('fred', 'georg') 16
# ('hermion', 'granger') 16
# ('back', 'hi') 15
# ('hi', 'mother') 15
# ('hi', 'wand') 15
# ('ron', 'wa') 15
# ('crabb', 'goyl') 15
# ('snape', 'wa') 15
# ('wa', 'almost') 14
# ('hi', 'arm') 14
# ('common', 'room') 14
# ('mr', 'potter') 13
# ('right', 'said') 13
# ('said', 'professor') 13
# ('harri', 'hi') 13
# ('come', 'back') 13
# ('first', 'time') 13
# ('hi', 'life') 13
# ('harri', 'tri') 13
# ('professor', 'quirrel') 13
# ('harri', 'told') 13
# ('dudley', 'wa') 12
# ('hi', 'name') 12
# ('hi', 'nose') 12
# ('look', 'hi') 12
# ('onli', 'one') 12
# ('next', 'morn') 12
# ('wa', 'one') 12
# ('said', 'uncl') 12
# ('harri', 'harri') 12
# ('back', 'harri') 12
# ('hagrid', 'look') 12
# ('platform', 'nine') 12
# ('great', 'hall') 12
# ('professor', 'flitwick') 12
# ('hi', 'broom') 12
# ('said', 'wood') 12
# ('nimbu', 'two') 12
# ('two', 'thousand') 12
# ('privet', 'drive') 11
# ('hi', 'mind') 11
# ('turn', 'hi') 11
# ('hi', 'aunt') 11
# ('harri', 'knew') 11
# ('though', 'wa') 11
# ('harri', 'thought') 11
# ('hi', 'leg') 11
# ('hi', 'way') 11
# ('yeh', 'know') 11
# ('look', 'harri') 11
# ('ron', 'harri') 11
# ('ron', 'look') 11
# ('get', 'back') 11
# ('hermion', 'wa') 11
# ('harri', 'never') 10
# ('dumbledor', 'said') 10
# ('harri', 'heard') 10
# ('wa', 'harri') 10
# ('wa', 'onli') 10
# ('could', 'hear') 10
# ('tri', 'get') 10
# ('look', 'around') 10
# ('sound', 'like') 10
# ('go', 'back') 10
# ('head', 'wa') 10
# ('wa', 'tri') 10
# ('mr', 'norri') 10
# ('let', 'go') 10
# ('invis', 'cloak') 10
# ('sorcer', 'stone') 10
# ('get', 'past') 10
# ('hi', 'finger') 9
# ('hi', 'heart') 9
# ('like', 'thi') 9
# ('know', 'wa') 9
# ('hi', 'father') 9
# ('look', 'though') 9
# ('hi', 'cupboard') 9
# ('pull', 'hi') 9
# ('think', 'wa') 9
# ('harri', 'saw') 9
# ('wa', 'stand') 9
# ('hi', 'mouth') 9
# ('hi', 'voic') 9
# ('hagrid', 'harri') 9
# ('tell', 'yeh') 9
# ('see', 'wa') 9
# ('get', 'yer') 9
# ('leaki', 'cauldron') 9
# ('harri', 'notic') 9
# ('said', 'boy') 9
# ('nicola', 'flamel') 9
# ('around', 'hi') 9
# ('ron', 'said') 9
# ('madam', 'hooch') 9
# ('nevil', 'wa') 9
# ('madam', 'pomfrey') 9
# ('harri', 'whisper') 9
# ('fifti', 'point') 9
# ('minut', 'later') 8
# ('hi', 'back') 8
# ('wa', 'sure') 8
# ('said', 'mr') 8
# ('hi', 'hair') 8
# ('albu', 'dumbledor') 8
# ('never', 'seen') 8
# ('wa', 'say') 8
# ('hi', 'pocket') 8
# ('look', 'veri') 8
# ('wa', 'full') 8
# ('mr', 'figg') 8
# ('wa', 'hi') 8
# ('harri', 'stare') 8
# ('go', 'harri') 8
# ('harri', 'think') 8
# ('shook', 'hi') 8
# ('face', 'wa') 8
# ('told', 'yeh') 8
# ('harri', 'hagrid') 8
# ('go', 'said') 8
# ('thi', 'year') 8
# ('got', 'ta') 8
# ('witch', 'wizard') 8
# ('harri', 'turn') 8
# ('look', 'ron') 8
# ('lee', 'jordan') 8
# ('chocol', 'frog') 8
# ('entranc', 'hall') 8
# ('said', 'nevil') 8
# ('number', 'four') 7
# ('look', 'wa') 7
# ('veri', 'well') 7
# ('yeah', 'said') 7
# ('hi', 'first') 7
# ('harri', 'got') 7
# ('wa', 'much') 7
# ('thi', 'harri') 7
# ('even', 'though') 7
# ('wa', 'talk') 7
# ('one', 'wa') 7
# ('someon', 'wa') 7
# ('harri', 'know') 7
# ('happen', 'wa') 7
# ('want', 'ter') 7
# ('right', 'harri') 7
# ('harri', 'pull') 7
# ('ministri', 'magic') 7
# ('harri', 'would') 7
# ('one', 'said') 7
# ('seven', 'hundr') 7
# ('know', 'get') 7
# ('look', 'forward') 7
# ('becaus', 'wa') 7
# ('wa', 'start') 7
# ('harri', 'push') 7
# ('said', 'perci') 7
# ('everi', 'flavor') 7
# ('see', 'hi') 7
# ('ron', 'mutter') 7
# ('draco', 'malfoy') 7
# ('us', 'said') 7
# ('hous', 'cup') 7
# ('gryffindor', 'tabl') 7
# ('said', 'malfoy') 7
# ('fat', 'ladi') 7
# ('miss', 'granger') 7
# ('point', 'gryffindor') 7
# ('past', 'fluffi') 7
# ('never', 'even') 6
# ('wa', 'noth') 6
# ('wa', 'wear') 6
# ('say', 'someth') 6
# ('wa', 'call') 6
# ('old', 'man') 6
# ('live', 'room') 6
# ('behind', 'hi') 6
# ('hi', 'cloak') 6
# ('go', 'wa') 6
# ('know', 'said') 6
# ('everyon', 'wa') 6
# ('tri', 'kill') 6
# ('aunt', 'uncl') 6
# ('ye', 'ye') 6
# ('better', 'get') 6
# ('could', 'make') 6
# ('tri', 'rememb') 6
# ('wa', 'back') 6
# ('hi', 'bed') 6
# ('hi', 'newspap') 6
# ('tabl', 'wa') 6
# ('last', 'year') 6
# ('face', 'harri') 6
# ('away', 'harri') 6
# ('wa', 'realli') 6
# ('anyth', 'els') 6
# ('put', 'hi') 6
# ('around', 'harri') 6
# ('next', 'day') 6
# ('go', 'go') 6
# ('hi', 'seat') 6
# ('time', 'wa') 6
# ('wa', 'good') 6
# ('harri', 'move') 6
# ('look', 'said') 6
# ('harri', 'sat') 6
# ('ever', 'sinc') 6
# ('smelt', 'stick') 6
# ('let', 'see') 6
# ('got', 'back') 6
# ('tri', 'find') 6
# ('ask', 'harri') 6
# ('five', 'minut') 6
# ('ten', 'minut') 6
# ('take', 'hi') 6
# ('cours', 'said') 6
# ('harri', 'head') 6
# ('thi', 'said') 6
# ('sorri', 'said') 6
# ('yeh', 'get') 6
# ('everi', 'time') 6
# ('made', 'hi') 6
# ('good', 'said') 6
# ('diagon', 'alley') 6
# ('hi', 'shoulder') 6
# ('lean', 'forward') 6
# ('shut', 'said') 6
# ('go', 'tri') 6
# ('king', 'cross') 6
# ('give', 'us') 6
# ('potter', 'harri') 6
# ('told', 'ron') 6
# ('flavor', 'bean') 6
# ('ron', 'turn') 6
# ('rais', 'hi') 6
# ('want', 'go') 6
# ('ca', 'see') 6
# ('whisper', 'harri') 6
# ('step', 'forward') 6
# ('hi', 'ear') 6
# ('weasley', 'twin') 6
# ('high', 'tabl') 6
# ('onto', 'hi') 6
# ('mcgonagal', 'wa') 6
# ('professor', 'snape') 6
# ('third', 'floor') 6
# ('get', 'rid') 6
# ('quirrel', 'wa') 6
# ('said', 'snape') 6
# ('hi', 'broomstick') 6
# ('get', 'us') 6
# ('wood', 'wa') 6
# ('quidditch', 'match') 6
# ('would', 'never') 6
# ('hermion', 'look') 6
# ('potter', 'wa') 5
# ('mirror', 'wa') 5
# ('look', 'back') 5
# ('walk', 'straight') 5
# ('wa', 'sit') 5
# ('hous', 'wa') 5
# ('next', 'door') 5
# ('fell', 'asleep') 5
# ('mind', 'hi') 5
# ('lemon', 'drop') 5
# ('told', 'wa') 5
# ('could', 'kill') 5
# ('potter', 'come') 5
# ('wa', 'hold') 5
# ('sit', 'said') 5
# ('said', 'giant') 5
# ('fast', 'asleep') 5
# ('hi', 'forehead') 5
# ('could', 'say') 5
# ('front', 'door') 5
# ('well', 'said') 5
# ('wipe', 'hi') 5
# ('good', 'luck') 5
# ('veri', 'last') 5
# ('ten', 'year') 5
# ('get', 'harri') 5
# ('car', 'crash') 5
# ('wa', 'first') 5
# ('mother', 'father') 5
# ('hi', 'parent') 5
# ('arm', 'around') 5
# ('half', 'hour') 5
# ('door', 'harri') 5
# ('said', 'anyth') 5
# ('one', 'thing') 5
# ('ice', 'cream') 5
# ('one', 'harri') 5
# ('behind', 'harri') 5
# ('green', 'light') 5
# ('cours', 'wa') 5
# ('top', 'hat') 5
# ('wander', 'around') 5
# ('said', 'one') 5
# ('hi', 'new') 5
# ('oh', 'said') 5
# ('everyon', 'els') 5
# ('harri', 'pick') 5
# ('harri', 'went') 5
# ('wa', 'point') 5
# ('harri', 'realiz') 5
# ('vernon', 'wa') 5
# ('could', 'go') 5
# ('eh', 'said') 5
# ('veri', 'good') 5
# ('minut', 'go') 5
# ('door', 'wa') 5
# ('yeh', 'got') 5
# ('second', 'later') 5
# ('insid', 'hi') 5
# ('hagrid', 'call') 5
# ('harri', 'jump') 5
# ('realiz', 'wa') 5
# ('next', 'second') 5
# ('still', 'got') 5
# ('come', 'harri') 5
# ('give', 'harri') 5
# ('ter', 'get') 5
# ('harri', 'shook') 5
# ('three', 'time') 5
# ('hundr', 'thirteen') 5
# ('vault', 'seven') 5
# ('door', 'open') 5
# ('harri', 'gasp') 5
# ('harri', 'lean') 5
# ('hi', 'neck') 5
# ('year', 'said') 5
# ('thought', 'wa') 5
# ('befor', 'harri') 5
# ('told', 'hagrid') 5
# ('well', 'well') 5
# ('harri', 'kept') 5
# ('said', 'wa') 5
# ('red', 'hair') 5
# ('push', 'hi') 5
# ('harri', 'watch') 5
# ('said', 'fred') 5
# ('harri', 'nod') 5
# ('wa', 'come') 5
# ('one', 'anoth') 5
# ('open', 'door') 5
# ('think', 'said') 5
# ('ask', 'ron') 5
# ('weasley', 'ron') 5
# ('dark', 'art') 5
# ('know', 'think') 5
# ('hi', 'famili') 5
# ('hold', 'hi') 5
# ('granger', 'wa') 5
# ('quit', 'still') 5
# ('well', 'done') 5
# ('gryffindor', 'tower') 5
# ('seamu', 'finnigan') 5
# ('someth', 'els') 5
# ('told', 'us') 5
# ('go', 'bed') 5
# ('bloodi', 'baron') 5
# ('gryffindor', 'hous') 5
# ('wa', 'hermion') 5
# ('malfoy', 'crabb') 5
# ('harri', 'caught') 5
# ('hi', 'robe') 5
# ('wa', 'keep') 5
# ('ron', 'could') 5
# ('broom', 'wa') 5
# ('mr', 'weasley') 5
# ('georg', 'weasley') 5
# ('portrait', 'hole') 5
# ('back', 'bed') 5
# ('come', 'said') 5
# ('room', 'harri') 5
# ('suit', 'armor') 5
# ('hermion', 'said') 5
# ('hermion', 'harri') 5
# ('mountain', 'troll') 5
# ('one', 'get') 5
# ('locker', 'room') 5
# ('rest', 'team') 5
# ('knew', 'wa') 5
# ('make', 'sure') 5
# ('said', 'quirrel') 5
# ('dursley', 'wa') 4
# ('could', 'bear') 4
# ('peopl', 'cloak') 4
# ('stop', 'dead') 4
# ('name', 'wa') 4
# ('man', 'wa') 4
# ('ha', 'gone') 4
# ('wa', 'imagin') 4
# ('wa', 'thi') 4
# ('ever', 'seen') 4
# ('next', 'week') 4
# ('cup', 'tea') 4
# ('clear', 'hi') 4
# ('wa', 'someth') 4
# ('hair', 'beard') 4
# ('nose', 'wa') 4
# ('back', 'insid') 4
# ('back', 'dursley') 4
# ('thank', 'said') 4
# ('though', 'thi') 4
# ('everyon', 'know') 4
# ('howev', 'wa') 4
# ('last', 'night') 4
# ('lili', 'jame') 4
# ('never', 'know') 4
# ('place', 'said') 4
# ('dumbledor', 'think') 4
# ('know', 'hi') 4
# ('head', 'harri') 4
# ('insid', 'harri') 4
# ('came', 'back') 4
# ('walk', 'back') 4
# ('thing', 'happen') 4
# ('voic', 'harri') 4
# ('front', 'step') 4
# ('year', 'ago') 4
# ('harri', 'well') 4
# ('put', 'harri') 4
# ('harri', 'dudley') 4
# ('wa', 'becaus') 4
# ('parent', 'die') 4
# ('die', 'said') 4
# ('ask', 'question') 4
# ('big', 'one') 4
# ('harri', 'heart') 4
# ('feel', 'sorri') 4
# ('leav', 'harri') 4
# ('could', 'take') 4
# ('rat', 'wa') 4
# ('hour', 'later') 4
# ('later', 'harri') 4
# ('could', 'believ') 4
# ('time', 'hi') 4
# ('think', 'anyth') 4
# ('close', 'harri') 4
# ('one', 'ever') 4
# ('wa', 'alreadi') 4
# ('dudley', 'gang') 4
# ('anyon', 'els') 4
# ('lock', 'door') 4
# ('dudley', 'pier') 4
# ('befor', 'could') 4
# ('want', 'see') 4
# ('anyway', 'harri') 4
# ('boa', 'constrictor') 4
# ('harri', 'made') 4
# ('way', 'said') 4
# ('petunia', 'dudley') 4
# ('school', 'harri') 4
# ('harri', 'one') 4
# ('told', 'harri') 4
# ('harri', 'want') 4
# ('like', 'wa') 4
# ('open', 'hi') 4
# ('mr', 'h') 4
# ('someth', 'harri') 4
# ('letter', 'wa') 4
# ('deep', 'breath') 4
# ('harri', 'thi') 4
# ('snap', 'hi') 4
# ('take', 'thi') 4
# ('wa', 'lie') 4
# ('leapt', 'hi') 4
# ('harri', 'walk') 4
# ('tri', 'catch') 4
# ('slam', 'door') 4
# ('speed', 'toward') 4
# ('onli', 'got') 4
# ('better', 'go') 4
# ('wa', 'smile') 4
# ('insid', 'wa') 4
# ('crunch', 'nois') 4
# ('yeh', 'yer') 4
# ('yer', 'letter') 4
# ('ter', 'tell') 4
# ('thi', 'boy') 4
# ('found', 'hi') 4
# ('gasp', 'harri') 4
# ('mum', 'dad') 4
# ('ca', 'go') 4
# ('wa', 'hagrid') 4
# ('day', 'harri') 4
# ('yer', 'mum') 4
# ('head', 'boy') 4
# ('hi', 'side') 4
# ('yeh', 'could') 4
# ('whi', 'go') 4
# ('back', 'hagrid') 4
# ('reason', 'wa') 4
# ('lot', 'ter') 4
# ('ta', 'get') 4
# ('get', 'ter') 4
# ('kept', 'hi') 4
# ('wa', 'suddenli') 4
# ('felt', 'though') 4
# ('held', 'hi') 4
# ('tri', 'rob') 4
# ('wa', 'quit') 4
# ('back', 'thi') 4
# ('station', 'harri') 4
# ('see', 'harri') 4
# ('harri', 'pant') 4
# ('histori', 'magic') 4
# ('wa', 'tini') 4
# ('point', 'harri') 4
# ('clap', 'hi') 4
# ('shake', 'hand') 4
# ('quirrel', 'said') 4
# ('harri', 'professor') 4
# ('harri', 'hand') 4
# ('thought', 'would') 4
# ('stand', 'back') 4
# ('plump', 'woman') 4
# ('hi', 'chest') 4
# ('right', 'right') 4
# ('harri', 'call') 4
# ('hagrid', 'ask') 4
# ('hi', 'knee') 4
# ('help', 'harri') 4
# ('said', 'griphook') 4
# ('wa', 'dark') 4
# ('hi', 'long') 4
# ('wa', 'empti') 4
# ('madam', 'malkin') 4
# ('play', 'quidditch') 4
# ('muggl', 'famili') 4
# ('like', 'professor') 4
# ('harri', 'forehead') 4
# ('harri', 'suddenli') 4
# ('harri', 'took') 4
# ('harri', 'swallow') 4
# ('harri', 'onli') 4
# ('hogwart', 'said') 4
# ('said', 'first') 4
# ('wa', 'listen') 4
# ('rubbish', 'said') 4
# ('never', 'heard') 4
# ('though', 'harri') 4
# ('nine', 'ten') 4
# ('hi', 'trunk') 4
# ('one', 'twin') 4
# ('two', 'boy') 4
# ('ron', 'got') 4
# ('saw', 'hi') 4
# ('hi', 'scar') 4
# ('never', 'mind') 4
# ('thi', 'ron') 4
# ('see', 'later') 4
# ('noth', 'said') 4
# ('say', 'name') 4
# ('eye', 'away') 4
# ('warn', 'harri') 4
# ('harri', 'ye') 4
# ('potter', 'said') 4
# ('dumbledor', 'wa') 4
# ('tri', 'take') 4
# ('quidditch', 'team') 4
# ('wa', 'hang') 4
# ('hall', 'wa') 4
# ('marbl', 'staircas') 4
# ('ron', 'whisper') 4
# ('tabl', 'harri') 4
# ('fell', 'hi') 4
# ('got', 'hi') 4
# ('drop', 'hi') 4
# ('small', 'voic') 4
# ('dumbledor', 'harri') 4
# ('feet', 'wa') 4
# ('nearli', 'headless') 4
# ('wa', 'right') 4
# ('malfoy', 'harri') 4
# ('nevil', 'said') 4
# ('wa', 'cri') 4
# ('like', 'harri') 4
# ('spiral', 'staircas') 4
# ('wa', 'malfoy') 4
# ('veri', 'hard') 4
# ('peev', 'wa') 4
# ('manag', 'get') 4
# ('pile', 'book') 4
# ('back', 'get') 4
# ('hi', 'turban') 4
# ('high', 'air') 4
# ('snape', 'said') 4
# ('hospit', 'wing') 4
# ('rock', 'cake') 4
# ('back', 'castl') 4
# ('ron', 'would') 4
# ('tell', 'anyon') 4
# ('malfoy', 'wa') 4
# ('jump', 'hi') 4
# ('onc', 'wa') 4
# ('thought', 'harri') 4
# ('keep', 'hi') 4
# ('caught', 'sight') 4
# ('quidditch', 'cup') 4
# ('got', 'go') 4
# ('portrait', 'fat') 4
# ('three', 'us') 4
# ('filch', 'wa') 4
# ('school', 'said') 4
# ('quidditch', 'field') 4
# ('suppos', 'think') 4
# ('hundr', 'fifti') 4
# ('hi', 'lip') 4
# ('pull', 'harri') 4
# ('thing', 'want') 4
# ('run', 'around') 4
# ('could', 'feel') 4
# ('wa', 'snape') 4
# ('room', 'wa') 4
# ('bright', 'blue') 4
# ('snape', 'could') 4
# ('whole', 'school') 4
# ('hi', 'nimbu') 4
# ('jordan', 'wa') 4
# ('go', 'stop') 4
# ('snape', 'tri') 4
# ('tell', 'us') 4
# ('great', 'wizard') 4
# ('find', 'flamel') 4
# ('outsid', 'corridor') 4
# ('hi', 'reflect') 4
# ('look', 'mirror') 4
# ('ron', 'come') 4
# ('thi', 'mirror') 4
# ('dumbledor', 'smile') 4
# ('elixir', 'life') 4
# ('stone', 'wa') 4
# ('go', 'straight') 4
# ('go', 'dumbledor') 4
# ('said', 'filch') 4
# ('ronan', 'bane') 4
# ('thought', 'snape') 4
# ('voldemort', 'could') 4
# ('devil', 'snare') 4
# ('wa', 'big') 3
# ('much', 'time') 3
# ('wa', 'mr') 3
# ('good', 'reason') 3
# ('pick', 'hi') 3
# ('owl', 'flutter') 3
# ('past', 'window') 3
# ('half', 'past') 3
# ('tabbi', 'cat') 3
# ('stare', 'back') 3
# ('back', 'mr') 3
# ('eye', 'fell') 3
# ('owl', 'swoop') 3
# ('averi', 'good') 3
# ('stretch', 'hi') 3
# ('way', 'back') 3
# ('seiz', 'hi') 3
# ('hi', 'mustach') 3
# ('potter', 'son') 3
# ('wa', 'even') 3
# ('muggl', 'like') 3
# ('root', 'spot') 3
# ('four', 'first') 3
# ('first', 'thing') 3
# ('wall', 'wa') 3
# ('hi', 'wife') 3
# ('shoot', 'star') 3
# ('look', 'shock') 3
# ('lot', 'peopl') 3
# ('well', 'thought') 3
# ('mayb', 'wa') 3
# ('oh', 'ye') 3
# ('anoth', 'word') 3
# ('wa', 'stare') 3
# ('eye', 'fix') 3
# ('fact', 'wa') 3
# ('tall', 'thin') 3
# ('blue', 'eye') 3
# ('look', 'suddenli') 3
# ('still', 'stare') 3
# ('found', 'wa') 3
# ('would', 'abl') 3
# ('see', 'anyth') 3
# ('anyth', 'wa') 3
# ('see', 'professor') 3
# ('black', 'hair') 3
# ('hair', 'wa') 3
# ('dear', 'professor') 3
# ('dedalu', 'diggl') 3
# ('gone', 'dumbledor') 3
# ('certainli', 'seem') 3
# ('call', 'hi') 3
# ('seem', 'notic') 3
# ('oh', 'right') 3
# ('one', 'know') 3
# ('know', 'whi') 3
# ('dumbledor', 'gave') 3
# ('jump', 'feet') 3
# ('kick', 'hi') 3
# ('aunt', 'anduncl') 3
# ('sit', 'back') 3
# ('would', 'surpris') 3
# ('world', 'know') 3
# ('dumbledor', 'eye') 3
# ('right', 'place') 3
# ('wa', 'huge') 3
# ('hair', 'hi') 3
# ('give', 'hagrid') 3
# ('took', 'harri') 3
# ('dursley', 'hous') 3
# ('hagrid', 'let') 3
# ('back', 'toth') 3
# ('luck', 'harri') 3
# ('cloak', 'wa') 3
# ('know', 'thi') 3
# ('yet', 'harri') 3
# ('petunia', 'wa') 3
# ('harri', 'woke') 3
# ('walk', 'toward') 3
# ('befor', 'hi') 3
# ('dudley', 'birthday') 3
# ('forgotten', 'harri') 3
# ('race', 'bike') 3
# ('veri', 'fast') 3
# ('time', 'dudley') 3
# ('onli', 'thing') 3
# ('could', 'ever') 3
# ('ever', 'rememb') 3
# ('top', 'hi') 3
# ('harri', 'need') 3
# ('harri', 'must') 3
# ('dudley', 'look') 3
# ('said', 'dudley') 3
# ('harri', 'put') 3
# ('dudley', 'go') 3
# ('go', 'red') 3
# ('moment', 'look') 3
# ('said', 'aunt') 3
# ('dudley', 'sat') 3
# ('look', 'angri') 3
# ('horror', 'harri') 3
# ('wa', 'easi') 3
# ('harri', 'listen') 3
# ('wo', 'let') 3
# ('oh', 'good') 3
# ('moment', 'later') 3
# ('pier', 'wa') 3
# ('pier', 'dudley') 3
# ('wa', 'strang') 3
# ('morn', 'howev') 3
# ('veri', 'angri') 3
# ('tell', 'harri') 3
# ('seem', 'think') 3
# ('might', 'get') 3
# ('head', 'look') 3
# ('harri', 'best') 3
# ('long', 'time') 3
# ('becaus', 'hi') 3
# ('wa', 'allow') 3
# ('reptil', 'hous') 3
# ('along', 'wall') 3
# ('wa', 'wors') 3
# ('see', 'anyon') 3
# ('gave', 'harri') 3
# ('know', 'harri') 3
# ('wa', 'nice') 3
# ('look', 'thi') 3
# ('harri', 'seen') 3
# ('wa', 'safe') 3
# ('could', 'rememb') 3
# ('hi', 'onli') 3
# ('seem', 'know') 3
# ('dudley', 'ask') 3
# ('walk', 'away') 3
# ('holiday', 'start') 3
# ('wa', 'wa') 3
# ('wa', 'whi') 3
# ('hand', 'wa') 3
# ('first', 'day') 3
# ('one', 'day') 3
# ('buy', 'hi') 3
# ('one', 'seem') 3
# ('even', 'dudley') 3
# ('wa', 'horribl') 3
# ('hi', 'smelt') 3
# ('mail', 'slot') 3
# ('get', 'mail') 3
# ('mail', 'harri') 3
# ('dudley', 'harri') 3
# ('letter', 'harri') 3
# ('stare', 'hi') 3
# ('book', 'back') 3
# ('went', 'back') 3
# ('hi', 'letter') 3
# ('read', 'letter') 3
# ('door', 'behind') 3
# ('hi', 'stomach') 3
# ('could', 'possibl') 3
# ('said', 'final') 3
# ('harri', 'moment') 3
# ('wa', 'mistak') 3
# ('yell', 'uncl') 3
# ('took', 'deep') 3
# ('er', 'ye') 3
# ('think', 'thi') 3
# ('mail', 'arriv') 3
# ('go', 'get') 3
# ('h', 'potter') 3
# ('right', 'behind') 3
# ('behind', 'uncl') 3
# ('wa', 'made') 3
# ('clutch', 'hi') 3
# ('push', 'door') 3
# ('one', 'could') 3
# ('vernon', 'made') 3
# ('go', 'away') 3
# ('pack', 'hi') 3
# ('would', 'take') 3
# ('knock', 'hi') 3
# ('harri', 'someth') 3
# ('someth', 'wa') 3
# ('long', 'thin') 3
# ('thin', 'packag') 3
# ('veri', 'cold') 3
# ('tonight', 'said') 3
# ('room', 'made') 3
# ('heard', 'someth') 3
# ('three', 'two') 3
# ('saw', 'wa') 3
# ('back', 'sofa') 3
# ('pocket', 'hi') 3
# ('harri', 'open') 3
# ('sort', 'thing') 3
# ('hi', 'coat') 3
# ('start', 'make') 3
# ('realli', 'know') 3
# ('never', 'thought') 3
# ('wave', 'hi') 3
# ('yer', 'parent') 3
# ('mom', 'dad') 3
# ('know', 'yeh') 3
# ('fix', 'harri') 3
# ('yeh', 'said') 3
# ('never', 'told') 3
# ('school', 'witchcraft') 3
# ('first', 'class') 3
# ('quill', 'roll') 3
# ('roll', 'parchment') 3
# ('hi', 'teeth') 3
# ('given', 'harri') 3
# ('wa', 'open') 3
# ('quickli', 'wa') 3
# ('wa', 'said') 3
# ('see', 'great') 3
# ('face', 'look') 3
# ('yeh', 'mind') 3
# ('one', 'doe') 3
# ('harri', 'suggest') 3
# ('bit', 'hi') 3
# ('wa', 'afraid') 3
# ('get', 'hi') 3
# ('could', 'find') 3
# ('hagrid', 'hi') 3
# ('hi', 'fist') 3
# ('fell', 'silent') 3
# ('floor', 'harri') 3
# ('night', 'tri') 3
# ('go', 'give') 3
# ('spell', 'book') 3
# ('hi', 'umbrella') 3
# ('one', 'last') 3
# ('look', 'hagrid') 3
# ('hi', 'beard') 3
# ('wa', 'hogwart') 3
# ('got', 'lot') 3
# ('could', 'tell') 3
# ('knock', 'door') 3
# ('harri', 'scrambl') 3
# ('littl', 'bronz') 3
# ('open', 'window') 3
# ('ani', 'money') 3
# ('yeh', 'want') 3
# ('harri', 'follow') 3
# ('follow', 'hagrid') 3
# ('sky', 'wa') 3
# ('use', 'magic') 3
# ('though', 'said') 3
# ('harri', 'anoth') 3
# ('whi', 'would') 3
# ('read', 'hi') 3
# ('harri', 'learn') 3
# ('left', 'alon') 3
# ('veri', 'difficult') 3
# ('hagrid', 'want') 3
# ('thi', 'moment') 3
# ('stone', 'step') 3
# ('one', 'want') 3
# ('want', 'one') 3
# ('time', 'hagrid') 3
# ('thousand', 'magic') 3
# ('close', 'behind') 3
# ('book', 'shop') 3
# ('place', 'wa') 3
# ('one', 'side') 3
# ('hat', 'wa') 3
# ('wa', 'great') 3
# ('dori', 'crockford') 3
# ('alway', 'want') 3
# ('ca', 'tell') 3
# ('young', 'man') 3
# ('look', 'terrifi') 3
# ('would', 'let') 3
# ('get', 'away') 3
# ('grin', 'harri') 3
# ('oh', 'yeah') 3
# ('mind', 'wa') 3
# ('point', 'hi') 3
# ('even', 'hagrid') 3
# ('solid', 'wall') 3
# ('hagrid', 'got') 3
# ('harri', 'wish') 3
# ('tri', 'look') 3
# ('wa', 'shake') 3
# ('gold', 'wa') 3
# ('step', 'toward') 3
# ('got', 'said') 3
# ('got', 'letter') 3
# ('open', 'onc') 3
# ('wa', 'dragon') 3
# ('gon', 'na') 3
# ('wall', 'hagrid') 3
# ('silver', 'sickl') 3
# ('brown', 'paper') 3
# ('might', 'well') 3
# ('harri', 'start') 3
# ('long', 'black') 3
# ('wand', 'said') 3
# ('harri', 'play') 3
# ('yet', 'said') 3
# ('harri', 'feel') 3
# ('brilliant', 'said') 3
# ('much', 'like') 3
# ('like', 'go') 3
# ('think', 'let') 3
# ('old', 'wizard') 3
# ('wizard', 'famili') 3
# ('four', 'ball') 3
# ('slytherin', 'said') 3
# ('ago', 'said') 3
# ('good', 'idea') 3
# ('hagrid', 'would') 3
# ('got', 'yeh') 3
# ('harri', 'realli') 3
# ('good', 'afternoon') 3
# ('hagrid', 'must') 3
# ('wa', 'loud') 3
# ('move', 'closer') 3
# ('scar', 'harri') 3
# ('hagrid', 'shuffl') 3
# ('tape', 'measur') 3
# ('unicorn', 'hair') 3
# ('never', 'get') 3
# ('thi', 'one') 3
# ('tri', 'harri') 3
# ('harri', 'wand') 3
# ('even', 'notic') 3
# ('sure', 'could') 3
# ('worri', 'harri') 3
# ('time', 'hogwart') 3
# ('bring', 'back') 3
# ('hi', 'throat') 3
# ('way', 'get') 3
# ('harri', 'mouth') 3
# ('harri', 'swung') 3
# ('hi', 'cart') 3
# ('ten', 'harri') 3
# ('onli', 'joke') 3
# ('veri', 'import') 3
# ('befor', 'ron') 3
# ('close', 'hi') 3
# ('wa', 'wait') 3
# ('boy', 'wa') 3
# ('ye', 'pleas') 3
# ('sat', 'next') 3
# ('someth', 'said') 3
# ('perci', 'prefect') 3
# ('get', 'one') 3
# ('blown', 'toilet') 3
# ('see', 'look') 3
# ('wa', 'ever') 3
# ('clamber', 'onto') 3
# ('slid', 'open') 3
# ('ron', 'twin') 3
# ('compart', 'door') 3
# ('ron', 'stare') 3
# ('stare', 'harri') 3
# ('harri', 'found') 3
# ('say', 'got') 3
# ('never', 'ani') 3
# ('name', 'said') 3
# ('could', 'carri') 3
# ('bott', 'everi') 3
# ('pumpkin', 'pasti') 3
# ('harri', 'take') 3
# ('way', 'harri') 3
# ('start', 'feel') 3
# ('would', 'know') 3
# ('unwrap', 'hi') 3
# ('dark', 'wizard') 3
# ('twelv', 'use') 3
# ('hang', 'around') 3
# ('look', 'care') 3
# ('tri', 'turn') 3
# ('told', 'seen') 3
# ('turn', 'thi') 3
# ('noth', 'happen') 3
# ('mutter', 'harri') 3
# ('know', 'found') 3
# ('go', 'look') 3
# ('harri', 'gryffindor') 3
# ('wa', 'wonder') 3
# ('power', 'dark') 3
# ('ron', 'ask') 3
# ('hi', 'brother') 3
# ('wa', 'nevil') 3
# ('turn', 'back') 3
# ('said', 'hi') 3
# ('ron', 'ron') 3
# ('ron', 'bit') 3
# ('fir', 'year') 3
# ('lose', 'hi') 3
# ('hagrid', 'rais') 3
# ('swung', 'open') 3
# ('pull', 'door') 3
# ('take', 'place') 3
# ('hi', 'left') 3
# ('talk', 'much') 3
# ('ani', 'second') 3
# ('move', 'along') 3
# ('though', 'hi') 3
# ('harri', 'quickli') 3
# ('sort', 'hat') 3
# ('whole', 'hall') 3
# ('hat', 'ron') 3
# ('ani', 'moment') 3
# ('shout', 'hat') 3
# ('new', 'gryffindor') 3
# ('cheer', 'harri') 3
# ('perhap', 'wa') 3
# ('hat', 'shout') 3
# ('next', 'harri') 3
# ('look', 'pleas') 3
# ('harri', 'step') 3
# ('last', 'thing') 3
# ('way', 'great') 3
# ('last', 'word') 3
# ('wa', 'get') 3
# ('perci', 'weasley') 3
# ('age', 'ago') 3
# ('say', 'word') 3
# ('ask', 'perci') 3
# ('thing', 'like') 3
# ('four', 'hundr') 3
# ('sir', 'nichola') 3
# ('littl', 'chat') 3
# ('slytherin', 'tabl') 3
# ('wa', 'pleas') 3
# ('treacl', 'tart') 3
# ('great', 'uncl') 3
# ('uncl', 'algi') 3
# ('come', 'see') 3
# ('talk', 'professor') 3
# ('turban', 'wa') 3
# ('harri', 'gotten') 3
# ('snape', 'harri') 3
# ('snape', 'look') 3
# ('hear', 'thi') 3
# ('thi', 'mean') 3
# ('stuck', 'hi') 3
# ('go', 'ask') 3
# ('quirrel', 'turban') 3
# ('eye', 'like') 3
# ('break', 'rule') 3
# ('time', 'week') 3
# ('professor', 'sprout') 3
# ('take', 'care') 3
# ('hi', 'bodi') 3
# ('get', 'start') 3
# ('lesson', 'turn') 3
# ('ani', 'idea') 3
# ('like', 'ron') 3
# ('ron', 'final') 3
# ('ron', 'snape') 3
# ('day', 'befor') 3
# ('first', 'week') 3
# ('wa', 'lucki') 3
# ('lucki', 'harri') 3
# ('potion', 'lesson') 3
# ('word', 'like') 3
# ('mcgonagal', 'snape') 3
# ('tut', 'tut') 3
# ('look', 'straight') 3
# ('hermion', 'stood') 3
# ('taken', 'gryffindor') 3
# ('seem', 'like') 3
# ('heard', 'snape') 3
# ('way', 'across') 3
# ('across', 'theground') 3
# ('ron', 'start') 3
# ('ron', 'pretend') 3
# ('gryffindor', 'common') 3
# ('becaus', 'nevil') 3
# ('els', 'wa') 3
# ('malfoy', 'quickli') 3
# ('ground', 'harri') 3
# ('harri', 'broom') 3
# ('parvati', 'patil') 3
# ('harri', 'yell') 3
# ('us', 'troubl') 3
# ('back', 'toward') 3
# ('toward', 'ground') 3
# ('corridor', 'harri') 3
# ('two', 'said') 3
# ('done', 'said') 3
# ('left', 'thi') 3
# ('around', 'school') 3
# ('get', 'caught') 3
# ('voic', 'spoke') 3
# ('hermion', 'snap') 3
# ('hermion', 'turn') 3
# ('wa', 'tryingto') 3
# ('trophi', 'room') 3
# ('keep', 'eye') 3
# ('corner', 'heard') 3
# ('thi', 'way') 3
# ('idea', 'go') 3
# ('told', 'hermion') 3
# ('hermion', 'gasp') 3
# ('back', 'gryffindor') 3
# ('knew', 'someon') 3
# ('right', 'wa') 3
# ('said', 'peev') 3
# ('snap', 'ron') 3
# ('ron', 'moan') 3
# ('minut', 'harri') 3
# ('three', 'head') 3
# ('pig', 'snout') 3
# ('floor', 'wa') 3
# ('mind', 'said') 3
# ('ron', 'thought') 3
# ('wonder', 'could') 3
# ('ani', 'old') 3
# ('malfoy', 'face') 3
# ('wa', 'eat') 3
# ('ron', 'sigh') 3
# ('even', 'harri') 3
# ('harri', 'left') 3
# ('stand', 'around') 3
# ('goal', 'post') 3
# ('three', 'chaser') 3
# ('ten', 'point') 3
# ('rose', 'high') 3
# ('think', 'got') 3
# ('could', 'get') 3
# ('swish', 'flick') 3
# ('fire', 'harri') 3
# ('wingardium', 'leviosa') 3
# ('knock', 'harri') 3
# ('heard', 'said') 3
# ('doe', 'know') 3
# ('ron', 'pull') 3
# ('harri', 'mutter') 3
# ('come', 'one') 3
# ('troll', 'wa') 3
# ('harri', 'time') 3
# ('hermion', 'tri') 3
# ('turn', 'slowli') 3
# ('one', 'look') 3
# ('look', 'troll') 3
# ('could', 'think') 3
# ('get', 'troubl') 3
# ('five', 'point') 3
# ('would', 'move') 3
# ('quidditch', 'age') 3
# ('tri', 'steal') 3
# ('hermion', 'think') 3
# ('want', 'anyth') 3
# ('onto', 'field') 3
# ('fred', 'weasley') 3
# ('marcu', 'flint') 3
# ('whole', 'crowd') 3
# ('hi', 'breath') 3
# ('along', 'row') 3
# ('snape', 'would') 3
# ('look', 'one') 3
# ('week', 'befor') 3
# ('snape', 'came') 3
# ('name', 'somewher') 3
# ('hermion', 'took') 3
# ('flamel', 'wa') 3
# ('madam', 'pinc') 3
# ('merri', 'christma') 3
# ('think', 'know') 3
# ('cloak', 'said') 3
# ('use', 'well') 3
# ('feel', 'like') 3
# ('door', 'look') 3
# ('chess', 'set') 3
# ('sleep', 'harri') 3
# ('restrict', 'section') 3
# ('back', 'librari') 3
# ('harri', 'stood') 3
# ('filch', 'snape') 3
# ('smile', 'wave') 3
# ('stand', 'next') 3
# ('mirror', 'hi') 3
# ('harri', 'go') 3
# ('infront', 'mirror') 3
# ('mirror', 'eris') 3
# ('show', 'us') 3
# ('ronald', 'weasley') 3
# ('sight', 'harri') 3
# ('ca', 'said') 3
# ('smile', 'face') 3
# ('stone', 'harri') 3
# ('see', 'could') 3
# ('someth', 'ron') 3
# ('saw', 'snape') 3
# ('hood', 'figur') 3
# ('see', 'quirrel') 3
# ('thi', 'made') 3
# ('guard', 'stone') 3
# ('go', 'see') 3
# ('hagrid', 'frown') 3
# ('harri', 'anxious') 3
# ('hermion', 'hagrid') 3
# ('norbert', 'wa') 3
# ('rid', 'norbert') 3
# ('nevil', 'harri') 3
# ('look', 'stun') 3
# ('unicorn', 'blood') 3
# ('unicorn', 'bin') 3
# ('nevil', 'fang') 3
# ('hi', 'crossbow') 3
# ('good', 'even') 3
# ('thi', 'forest') 3
# ('seen', 'anythin') 3
# ('ask', 'wa') 3
# ('potter', 'know') 3
# ('stone', 'voldemort') 3
# ('voldemort', 'come') 3
# ('steal', 'stone') 3
# ('talk', 'said') 3
# ('high', 'voic') 3
# ('ron', 'went') 3
# ('well', 'harri') 3
# ('chamber', 'wa') 3
# ('white', 'queen') 3
# ('black', 'flame') 3
# ('wa', 'quirrel') 3
# ('find', 'stone') 3
# ('thank', 'veri') 2
# ('veri', 'much') 2
# ('hardli', 'ani') 2
# ('small', 'son') 2
# ('son', 'call') 2
# ('fear', 'wa') 2
# ('anyon', 'found') 2
# ('potter', 'mr') 2
# ('sever', 'year') 2
# ('pretend', 'sister') 2
# ('like', 'mr') 2
# ('mr', 'mr') 2
# ('sky', 'outsid') 2
# ('thing', 'would') 2
# ('window', 'half') 2
# ('throw', 'hi') 2
# ('littl', 'tyke') 2
# ('hi', 'car') 2
# ('drive', 'wa') 2
# ('notic', 'first') 2
# ('read', 'map') 2
# ('jerk', 'hi') 2
# ('wa', 'tabbi') 2
# ('cat', 'hi') 2
# ('dursley', 'could') 2
# ('suppos', 'thiswa') 2
# ('whisper', 'excitedli') 2
# ('dursley', 'thi') 2
# ('wa', 'probabl') 2
# ('dursley', 'alway') 2
# ('hi', 'offic') 2
# ('good', 'mood') 2
# ('across', 'road') 2
# ('word', 'say') 2
# ('right', 'heard') 2
# ('son', 'harri') 2
# ('harri', 'mr') 2
# ('want', 'say') 2
# ('dash', 'back') 2
# ('back', 'across') 2
# ('hurri', 'hi') 2
# ('stroke', 'hi') 2
# ('peopl', 'call') 2
# ('call', 'harri') 2
# ('harri', 'come') 2
# ('outsid', 'door') 2
# ('almost', 'fell') 2
# ('smile', 'said') 2
# ('passersbi', 'stare') 2
# ('noth', 'could') 2
# ('stood', 'root') 2
# ('home', 'wa') 2
# ('imagin', 'thing') 2
# ('thing', 'saw') 2
# ('garden', 'wall') 2
# ('around', 'eye') 2
# ('cat', 'move') 2
# ('let', 'hous') 2
# ('went', 'live') 2
# ('hardli', 'ever') 2
# ('everi', 'direct') 2
# ('earli', 'next') 2
# ('sat', 'frozen') 2
# ('funni', 'stuff') 2
# ('dursley', 'well') 2
# ('thought', 'mayb') 2
# ('dare', 'tell') 2
# ('suppos', 'said') 2
# ('harri', 'nasti') 2
# ('say', 'anoth') 2
# ('owleri', 'send') 2
# ('send', 'hedwig') 2
# ('hedwig', 'todumbledor') 2
# ('sort', 'plant') 2
# ('plant', 'thing') 2
# ('ron', 'lucki') 2
# ('kill', 'said') 2
# ('harri', 'point') 2
# ('face', 'hi') 2
# ('ye', 'look') 2
# ('look', 'big') 2
# ('hermion', 'stay') 2
# ('open', 'next') 2
# ('white', 'piec') 2
# ('anoth', 'door') 2
# ('black', 'piec') 2
# ('bishop', 'hermion') 2
# ('move', 'forward') 2
# ('leav', 'free') 2
# ('wa', 'lost') 2
# ('nettl', 'wine') 2
# ('smallest', 'bottl') 2
# ('oh', 'harri') 2
# ('harri', 'sure') 2
# ('tri', 'save') 2
# ('keep', 'quirrel') 2
# ('lord', 'voldemort') 2
# ('master', 'harri') 2
# ('rope', 'bind') 2
# ('quirrel', 'face') 2
# ('good', 'evil') 2
# ('watch', 'quirrel') 2
# ('quirrel', 'curs') 2
# ('quirrel', 'doe') 2
# ('use', 'boy') 2
# ('come', 'quirrel') 2
# ('look', 'lie') 2
# ('back', 'quirrel') 2
# ('anoth', 'bodi') 2
# ('felt', 'quirrel') 2
# ('harri', 'scar') 2
# ('shriek', 'voldemort') 2
# ('voldemort', 'quirrel') 2
# ('curs', 'harri') 2
# ('could', 'touch') 2
# ('quirrel', 'arm') 2
# ('could', 'quirrel') 2
# ('mr', 'ronald') 2
# ('arriv', 'time') 2
# ('mind', 'death') 2
# ('death', 'next') 2
# ('voldemort', 'harri') 2
# ('well', 'voldemort') 2
# ('gone', 'ha') 2
# ('dumbledor', 'sigh') 2
# ('stone', 'gone') 2
# ('hi', 'rocker') 2
# ('could', 'die') 2
# ('slytherin', 'serpent') 2
# ('next', 'year') 2
# ('three', 'hundr') 2
# ('point', 'third') 2
# ('room', 'went') 2
# ('hous', 'fifti') 2
# ('award', 'gryffindor') 2
# ('hundr', 'point') 2
# ('point', 'mr') 2
# ('thi', 'summer') 2

# %% [markdown]
# As we can see, most of the statistically significant bigrams ('said harry', 'said ron', 'uncle veron', 'aunt petunia', 'harry ron', 'his eye', 'fred georg', etc.) are also most frequent bigrams in the text. Therefore, I consider them as idiomatic collocations.
#
# We can also look at the frequency distribution of trigrams.

# %%
Ngrams = nltk.ngrams(hpStoneSentencesDF['normalized_tokens'].sum(), 3)
Counts = {}
for ngram in list(Ngrams):
    if ngram in Counts.keys():
        Counts[ngram] += 1
    else:
        Counts[ngram] = 1
Filtered = {}
for key in Counts.keys():
    if Counts[key] < 2:
        pass
    else:
        Filtered[key] = Counts[key]
sortFilter = [(k,Filtered[k])for k in sorted(Filtered, key=Filtered.get, reverse=True)]
for k,v in sortFilter: 
    print (k,v)
# Out:
# ('said', 'professor', 'mcgonagal') 12
# ('said', 'uncl', 'vernon') 12
# ('nimbu', 'two', 'thousand') 12
# ('harri', 'could', 'see') 9
# ('shook', 'hi', 'head') 8
# ('harri', 'ron', 'hermion') 8
# ('said', 'hagrid', 'harri') 7
# ('hagrid', 'said', 'harri') 7
# ('said', 'harri', 'wa') 6
# ('ye', 'said', 'harri') 6
# ('professor', 'mcgonagal', 'wa') 6
# ('said', 'ron', 'look') 6
# ('get', 'past', 'fluffi') 6
# ('seven', 'hundr', 'thirteen') 5
# ('vault', 'seven', 'hundr') 5
# ('everi', 'flavor', 'bean') 5
# ('hermion', 'granger', 'wa') 5
# ('hi', 'aunt', 'uncl') 4
# ('hi', 'mother', 'father') 4
# ('first', 'time', 'hi') 4
# ('time', 'hi', 'life') 4
# ('aunt', 'petunia', 'dudley') 4
# ('said', 'harri', 'look') 4
# ('said', 'harri', 'tri') 4
# ('uncl', 'vernon', 'wa') 4
# ('take', 'hi', 'eye') 4
# ('said', 'harri', 'hagrid') 4
# ('got', 'ta', 'get') 4
# ('harri', 'push', 'hi') 4
# ('harri', 'shook', 'hi') 4
# ('said', 'harri', 'ron') 4
# ('hi', 'eye', 'away') 4
# ('harri', 'wa', 'look') 4
# ('malfoy', 'crabb', 'goyl') 4
# ('fred', 'georg', 'weasley') 4
# ('hundr', 'fifti', 'point') 4
# ('lee', 'jordan', 'wa') 4
# ('said', 'ron', 'harri') 4
# ('right', 'said', 'ron') 4
# ('hi', 'head', 'wa') 4
# ('mr', 'dursley', 'wa') 3
# ('hi', 'eye', 'fell') 3
# ('said', 'mr', 'dursley') 3
# ('hi', 'mind', 'hi') 3
# ('hi', 'nose', 'wa') 3
# ('hi', 'aunt', 'anduncl') 3
# ('know', 'hi', 'name') 3
# ('ye', 'said', 'dumbledor') 3
# ('yeah', 'said', 'hagrid') 3
# ('good', 'luck', 'harri') 3
# ('said', 'harri', 'well') 3
# ('said', 'aunt', 'petunia') 3
# ('know', 'said', 'harri') 3
# ('wa', 'go', 'harri') 3
# ('thank', 'said', 'harri') 3
# ('hi', 'smelt', 'stick') 3
# ('harri', 'wa', 'point') 3
# ('yell', 'uncl', 'vernon') 3
# ('took', 'deep', 'breath') 3
# ('behind', 'uncl', 'vernon') 3
# ('uncl', 'vernon', 'made') 3
# ('long', 'thin', 'packag') 3
# ('wa', 'veri', 'good') 3
# ('hi', 'face', 'wa') 3
# ('leapt', 'hi', 'feet') 3
# ('quill', 'roll', 'parchment') 3
# ('wa', 'onli', 'one') 3
# ('yer', 'mum', 'dad') 3
# ('said', 'hagrid', 'wa') 3
# ('made', 'hi', 'way') 3
# ('harri', 'head', 'wa') 3
# ('harri', 'wa', 'sure') 3
# ('harri', 'told', 'hagrid') 3
# ('said', 'mr', 'ollivand') 3
# ('clear', 'hi', 'throat') 3
# ('platform', 'nine', 'ten') 3
# ('said', 'harri', 'push') 3
# ('said', 'one', 'twin') 3
# ('bott', 'everi', 'flavor') 3
# ('wa', 'start', 'feel') 3
# ('ron', 'mutter', 'harri') 3
# ('us', 'said', 'ron') 3
# ('ron', 'whisper', 'harri') 3
# ('nevil', 'said', 'ron') 3
# ('great', 'uncl', 'algi') 3
# ('said', 'ron', 'snape') 3
# ('harri', 'professor', 'mcgonagal') 3
# ('like', 'professor', 'mcgonagal') 3
# ('rubbish', 'said', 'hagrid') 3
# ('gryffindor', 'common', 'room') 3
# ('hi', 'broom', 'wa') 3
# ('got', 'hi', 'feet') 3
# ('harri', 'said', 'ron') 3
# ('knew', 'someon', 'wa') 3
# ('portrait', 'fat', 'ladi') 3
# ('harri', 'ron', 'thought') 3
# ('ron', 'hermion', 'wa') 3
# ('said', 'harri', 'think') 3
# ('told', 'ron', 'hermion') 3
# ('hi', 'nimbu', 'two') 3
# ('noth', 'said', 'harri') 3
# ('invis', 'cloak', 'said') 3
# ('clap', 'hi', 'hand') 3
# ('said', 'harri', 'anxious') 3
# ('get', 'rid', 'norbert') 3
# ('thank', 'veri', 'much') 2
# ('wa', 'mr', 'dursley') 2
# ('jerk', 'hi', 'head') 2
# ('wa', 'tabbi', 'cat') 2
# ('mr', 'dursley', 'alway') 2
# ('stood', 'root', 'spot') 2
# ('wa', 'imagin', 'thing') 2
# ('number', 'four', 'first') 2
# ('first', 'thing', 'saw') 2
# ('say', 'anoth', 'word') 2
# ('bed', 'mr', 'dursley') 2
# ('cat', 'wa', 'still') 2
# ('wa', 'tall', 'thin') 2
# ('found', 'wa', 'look') 2
# ('wa', 'look', 'hi') 2
# ('professor', 'mcgonagal', 'turn') 2
# ('said', 'dumbledor', 'gentli') 2
# ('know', 'said', 'professor') 2
# ('wa', 'go', 'tell') 2
# ('though', 'thi', 'wa') 2
# ('say', 'wa', 'go') 2
# ('lili', 'jame', 'potter') 2
# ('could', 'kill', 'littl') 2
# ('kill', 'littl', 'boy') 2
# ('kick', 'hi', 'mother') 2
# ('harri', 'potter', 'come') 2
# ('sit', 'back', 'onth') 2
# ('world', 'know', 'hi') 2
# ('ye', 'ye', 'right') 2
# ('said', 'dumbledor', 'sound') 2
# ('dumbledor', 'professor', 'mcgonagal') 2
# ('like', 'bolt', 'lightn') 2
# ('professor', 'mcgonagal', 'wake') 2
# ('professor', 'mcgonagal', 'professor') 2
# ('professor', 'mcgonagal', 'said') 2
# ('ten', 'year', 'ago') 2
# ('harri', 'potter', 'wa') 2
# ('aunt', 'petunia', 'wa') 2
# ('hi', 'bed', 'pull') 2
# ('wa', 'harri', 'could') 2
# ('could', 'ever', 'rememb') 2
# ('ask', 'question', 'wa') 2
# ('harri', 'wa', 'turn') 2
# ('uncl', 'vernon', 'look') 2
# ('hi', 'face', 'fell') 2
# ('thi', 'big', 'one') 2
# ('harri', 'uncl', 'vernon') 2
# ('remot', 'control', 'airplan') 2
# ('mouth', 'fell', 'open') 2
# ('harri', 'heart', 'gave') 2
# ('harri', 'wa', 'left') 2
# ('aunt', 'petunia', 'look') 2
# ('snap', 'aunt', 'petunia') 2
# ('said', 'harri', 'listen') 2
# ('fling', 'arm', 'around') 2
# ('good', 'lord', 'said') 2
# ('hour', 'later', 'harri') 2
# ('harri', 'could', 'believ') 2
# ('could', 'believ', 'hi') 2
# ('think', 'anyth', 'els') 2
# ('taken', 'harri', 'asid') 2
# ('pull', 'hi', 'head') 2
# ('wa', 'go', 'go') 2
# ('complain', 'aunt', 'petunia') 2
# ('one', 'harri', 'wa') 2
# ('reptil', 'hous', 'wa') 2
# ('glass', 'though', 'wa') 2
# ('die', 'car', 'crash') 2
# ('harri', 'potter', 'hi') 2
# ('uncl', 'vernon', 'old') 2
# ('thi', 'wa', 'veri') 2
# ('wa', 'veri', 'funni') 2
# ('first', 'day', 'stonewal') 2
# ('aunt', 'petunia', 'took') 2
# ('wa', 'horribl', 'smell') 2
# ('ask', 'aunt', 'petunia') 2
# ('hi', 'first', 'day') 2
# ('uncl', 'vernon', 'came') 2
# ('uncl', 'vernon', 'sister') 2
# ('vernon', 'sister', 'marg') 2
# ('harri', 'harri', 'pick') 2
# ('harri', 'went', 'back') 2
# ('look', 'though', 'might') 2
# ('made', 'choke', 'nois') 2
# ('vernon', 'aunt', 'petunia') 2
# ('harri', 'hi', 'cupboard') 2
# ('moment', 'uncl', 'vernon') 2
# ('one', 'uncl', 'vernon') 2
# ('wa', 'rather', 'quiet') 2
# ('uncl', 'vernon', 'seem') 2
# ('harri', 'leapt', 'air') 2
# ('eye', 'uncl', 'vernon') 2
# ('peopl', 'mind', 'work') 2
# ('uncl', 'vernon', 'tri') 2
# ('slam', 'door', 'shut') 2
# ('ten', 'minut', 'later') 2
# ('uncl', 'vernon', 'stop') 2
# ('mr', 'h', 'potter') 2
# ('hi', 'head', 'got') 2
# ('harri', 'someth', 'wa') 2
# ('room', 'uncl', 'vernon') 2
# ('wa', 'go', 'fall') 2
# ('minut', 'go', 'wa') 2
# ('sat', 'bolt', 'upright') 2
# ('man', 'wa', 'stand') 2
# ('hi', 'eye', 'glint') 2
# ('hide', 'behind', 'hi') 2
# ('uncl', 'vernon', 'harri') 2
# ('harri', 'said', 'giant') 2
# ('wa', 'onli', 'babi') 2
# ('hut', 'wa', 'full') 2
# ('hagrid', 'look', 'shock') 2
# ('hi', 'hand', 'said') 2
# ('yeh', 'know', 'yeh') 2
# ('found', 'hi', 'voic') 2
# ('said', 'harri', 'eagerli') 2
# ('yeh', 'said', 'hagrid') 2
# ('yer', 'letter', 'harri') 2
# ('stretch', 'hi', 'hand') 2
# ('read', 'hogwart', 'school') 2
# ('hogwart', 'school', 'witchcraft') 2
# ('said', 'hagrid', 'clap') 2
# ('dumbledor', 'given', 'harri') 2
# ('go', 'said', 'hagrid') 2
# ('great', 'muggl', 'like') 2
# ('said', 'harri', 'knew') 2
# ('ter', 'tell', 'yeh') 2
# ('yeh', 'know', 'much') 2
# ('wizard', 'went', 'bad') 2
# ('hi', 'name', 'wa') 2
# ('dumbledor', 'onli', 'one') 2
# ('onli', 'one', 'wa') 2
# ('flash', 'green', 'light') 2
# ('insid', 'hi', 'coat') 2
# ('say', 'die', 'codswallop') 2
# ('die', 'codswallop', 'opinion') 2
# ('codswallop', 'opinion', 'dunno') 2
# ('hogwart', 'uncl', 'vernon') 2
# ('wa', 'go', 'give') 2
# ('want', 'ter', 'go') 2
# ('name', 'ever', 'sinc') 2
# ('ever', 'sinc', 'wa') 2
# ('yeh', 'get', 'yer') 2
# ('ta', 'get', 'ter') 2
# ('open', 'hi', 'eye') 2
# ('scrambl', 'hi', 'feet') 2
# ('said', 'harri', 'loudli') 2
# ('school', 'harri', 'wa') 2
# ('yeh', 'mad', 'ter') 2
# ('mad', 'ter', 'tri') 2
# ('ter', 'tri', 'rob') 2
# ('safest', 'place', 'world') 2
# ('dumbledor', 'said', 'harri') 2
# ('famou', 'hi', 'defeat') 2
# ('grindelwald', 'discoveri', 'twelv') 2
# ('discoveri', 'twelv', 'use') 2
# ('alchemi', 'hi', 'partner') 2
# ('tore', 'hi', 'eye') 2
# ('ron', 'warn', 'harri') 2
# ('said', 'harri', 'ye') 2
# ('scabber', 'rat', 'wa') 2
# ('compart', 'door', 'slid') 2
# ('door', 'slid', 'open') 2
# ('wand', 'noth', 'happen') 2
# ('learn', 'cours', 'book') 2
# ('cours', 'book', 'heart') 2
# ('harri', 'look', 'ron') 2
# ('look', 'ron', 'wa') 2
# ('wa', 'reliev', 'see') 2
# ('harri', 'potter', 'said') 2
# ('centuri', 'said', 'harri') 2
# ('yeah', 'said', 'ron') 2
# ('back', 'hi', 'seat') 2
# ('harri', 'tri', 'take') 2
# ('harri', 'wa', 'wonder') 2
# ('charli', 'romania', 'studi') 2
# ('romania', 'studi', 'dragon') 2
# ('someth', 'like', 'thi') 2
# ('wa', 'look', 'harri') 2
# ('ron', 'said', 'harri') 2
# ('dark', 'could', 'see') 2
# ('hagrid', 'big', 'hairi') 2
# ('big', 'hairi', 'face') 2
# ('kept', 'lose', 'hi') 2
# ('lose', 'hi', 'toad') 2
# ('door', 'swung', 'open') 2
# ('hi', 'left', 'ear') 2
# ('hi', 'eye', 'fix') 2
# ('talk', 'one', 'anoth') 2
# ('professor', 'mcgonagal', 'told') 2
# ('point', 'wizard', 'hat') 2
# ('hufflepuff', 'shout', 'hat') 2
# ('better', 'get', 'back') 2
# ('hi', 'friend', 'crabb') 2
# ('friend', 'crabb', 'goyl') 2
# ('next', 'second', 'wa') 2
# ('said', 'small', 'voic') 2
# ('caught', 'hi', 'eye') 2
# ('away', 'harri', 'look') 2
# ('harri', 'look', 'hi') 2
# ('hi', 'feet', 'wa') 2
# ('sir', 'nichola', 'de') 2
# ('said', 'ron', 'suddenli') 2
# ('nearli', 'headless', 'nick') 2
# ('like', 'thi', 'said') 2
# ('back', 'onto', 'hi') 2
# ('harri', 'wa', 'pleas') 2
# ('come', 'see', 'great') 2
# ('atth', 'high', 'tabl') 2
# ('talk', 'professor', 'dumbledor') 2
# ('came', 'sudden', 'halt') 2
# ('harri', 'wa', 'go') 2
# ('wa', 'go', 'ask') 2
# ('see', 'hi', 'face') 2
# ('three', 'time', 'week') 2
# ('wa', 'histori', 'magic') 2
# ('ghost', 'professor', 'binn') 2
# ('way', 'great', 'hall') 2
# ('us', 'said', 'harri') 2
# ('hedwig', 'brought', 'harri') 2
# ('word', 'like', 'professor') 2
# ('professor', 'mcgonagal', 'snape') 2
# ('sit', 'said', 'harri') 2
# ('one', 'thousand', 'magic') 2
# ('said', 'harri', 'quietli') 2
# ('point', 'taken', 'gryffindor') 2
# ('told', 'hagrid', 'wa') 2
# ('said', 'hagrid', 'glanc') 2
# ('harri', 'ron', 'delight') 2
# ('harri', 'could', 'help') 2
# ('wa', 'lie', 'tabl') 2
# ('wa', 'search', 'fact') 2
# ('know', 'good', 'said') 2
# ('walk', 'back', 'castl') 2
# ('would', 'tell', 'anyon') 2
# ('veri', 'pleas', 'hermion') 2
# ('hi', 'hand', 'onc') 2
# ('madam', 'hooch', 'wa') 2
# ('get', 'us', 'troubl') 2
# ('us', 'troubl', 'harri') 2
# ('ron', 'turn', 'hi') 2
# ('turn', 'hi', 'broomstick') 2
# ('hi', 'fist', 'harri') 2
# ('hi', 'feet', 'trembl') 2
# ('classroom', 'wa', 'empti') 2
# ('wa', 'first', 'time') 2
# ('clue', 'wa', 'go') 2
# ('well', 'done', 'said') 2
# ('thi', 'year', 'said') 2
# ('wa', 'hermion', 'granger') 2
# ('said', 'ron', 'hermion') 2
# ('hermion', 'wa', 'go') 2
# ('fat', 'ladi', 'gone') 2
# ('said', 'ron', 'got') 2
# ('trophi', 'room', 'malfoy') 2
# ('run', 'harri', 'yell') 2
# ('without', 'ani', 'idea') 2
# ('hermion', 'said', 'harri') 2
# ('harri', 'realiz', 'wa') 2
# ('stand', 'quit', 'still') 2
# ('said', 'ron', 'final') 2
# ('dog', 'wa', 'guard') 2
# ('hi', 'eye', 'saw') 2
# ('harri', 'ron', 'wa') 2
# ('two', 'thousand', 'ron') 2
# ('befor', 'ron', 'could') 2
# ('said', 'malfoy', 'quickli') 2
# ('never', 'mind', 'said') 2
# ('harri', 'notic', 'seem') 2
# ('tri', 'catch', 'hi') 2
# ('great', 'hall', 'halloween') 2
# ('stupid', 'said', 'ron') 2
# ('doe', 'know', 'troll') 2
# ('bit', 'hi', 'lip') 2
# ('ron', 'pull', 'harri') 2
# ('pull', 'door', 'open') 2
# ('hi', 'arm', 'around') 2
# ('pull', 'hi', 'wand') 2
# ('rose', 'high', 'high') 2
# ('professor', 'mcgonagal', 'come') 2
# ('fifti', 'point', 'gryffindor') 2
# ('look', 'harri', 'look') 2
# ('common', 'room', 'wa') 2
# ('first', 'quidditch', 'match') 2
# ('five', 'point', 'gryffindor') 2
# ('harri', 'ron', 'andhermion') 2
# ('harri', 'went', 'bed') 2
# ('great', 'hall', 'wa') 2
# ('walk', 'onto', 'field') 2
# ('ron', 'hermion', 'join') 2
# ('said', 'fred', 'weasley') 2
# ('clamber', 'onto', 'hi') 2
# ('said', 'hagrid', 'pat') 2
# ('power', 'dark', 'magic') 2
# ('harri', 'wa', 'suddenli') 2
# ('look', 'ron', 'said') 2
# ('five', 'minut', 'harri') 2
# ('look', 'one', 'anoth') 2
# ('got', 'keep', 'eye') 2
# ('snape', 'tri', 'kill') 2
# ('ron', 'would', 'mind') 2
# ('could', 'find', 'flamel') 2
# ('said', 'hermion', 'onc') 2
# ('said', 'ron', 'sleepili') 2
# ('said', 'ron', 'turn') 2
# ('common', 'room', 'harri') 2
# ('climb', 'portrait', 'hole') 2
# ('even', 'though', 'harri') 2
# ('hi', 'knee', 'let') 2
# ('drain', 'hi', 'face') 2
# ('door', 'stood', 'ajar') 2
# ('walk', 'straight', 'past') 2
# ('stand', 'right', 'behind') 2
# ('said', 'ron', 'come') 2
# ('push', 'door', 'open') 2
# ('harri', 'harri', 'felt') 2
# ('harri', 'felt', 'though') 2
# ('said', 'dumbledor', 'harri') 2
# ('said', 'dumbledor', 'quietli') 2
# ('harri', 'wa', 'still') 2
# ('slytherin', 'hous', 'championship') 2
# ('said', 'ron', 'pretend') 2
# ('said', 'ron', 'ca') 2
# ('ron', 'ca', 'said') 2
# ('worth', 'twelv', 'malfoy') 2
# ('walk', 'away', 'harri') 2
# ('said', 'hermion', 'harri') 2
# ('know', 'whether', 'wa') 2
# ('snape', 'award', 'hufflepuff') 2
# ('harri', 'jump', 'hi') 2
# ('harri', 'could', 'hear') 2
# ('hood', 'figur', 'came') 2
# ('harri', 'lean', 'forward') 2
# ('found', 'get', 'past') 2
# ('quirrel', 'said', 'snape') 2
# ('could', 'see', 'quirrel') 2
# ('sorcer', 'stone', 'snape') 2
# ('guard', 'stone', 'apart') 2
# ('stone', 'apart', 'fluffi') 2
# ('behind', 'hi', 'back') 2
# ('said', 'hagrid', 'listen') 2
# ('hagrid', 'said', 'hermion') 2
# ('hagrid', 'said', 'ron') 2
# ('said', 'hermion', 'well') 2
# ('snap', 'hi', 'finger') 2
# ('could', 'go', 'dumbledor') 2
# ('cloak', 'said', 'harri') 2
# ('told', 'madam', 'pomfrey') 2
# ('midnight', 'saturday', 'said') 2
# ('harri', 'could', 'think') 2
# ('said', 'hagrid', 'frown') 2
# ('malfoy', 'nevil', 'fang') 2
# ('ronan', 'said', 'hagrid') 2
# ('good', 'even', 'hagrid') 2
# ('mar', 'bright', 'tonight') 2
# ('seen', 'anythin', 'ronan') 2
# ('stop', 'say', 'name') 2
# ('voldemort', 'come', 'back') 2
# ('hagrid', 'would', 'never') 2
# ('jump', 'hi', 'feet') 2
# ('want', 'anyth', 'els') 2
# ('talk', 'said', 'ron') 2
# ('see', 'professor', 'dumbledor') 2
# ('go', 'trapdoor', 'tonight') 2
# ('obviou', 'said', 'ron') 2
# ('well', 'harri', 'said') 2
# ('cours', 'said', 'hermion') 2
# ('step', 'forward', 'nevil') 2
# ('said', 'ron', 'peer') 2
# ('want', 'go', 'first') 2
# ('go', 'straight', 'owleri') 2
# ('straight', 'owleri', 'send') 2
# ('owleri', 'send', 'hedwig') 2
# ('send', 'hedwig', 'todumbledor') 2
# ('said', 'ron', 'lucki') 2
# ('right', 'said', 'hermion') 2
# ('way', 'said', 'harri') 2
# ('said', 'harri', 'point') 2
# ('hi', 'face', 'hi') 2
# ('good', 'said', 'harri') 2
# ('high', 'voic', 'spoke') 2
# ('harri', 'felt', 'quirrel') 2
# ('rais', 'hi', 'hand') 2
# ('mr', 'ronald', 'weasley') 2
# ('mind', 'death', 'next') 2
# ('made', 'hi', 'head') 2
# ('told', 'yeh', 'could') 2
# ('yeh', 'could', 'die') 2
# ('gryffindor', 'hous', 'fifti') 2
# ('hous', 'fifti', 'point') 2
# ('award', 'gryffindor', 'hous') 2

# %% [markdown]
# According to the sorting results of trigrams, 3-words collocation has lower frequency in the Harry Potter book. However, most of the statistically significant trigrams ('said professor maconagal','said uncle vernon', 'nimbus two thousand', 'harry could see', 'shook his head','harry ron hermione',etc) are also has high frequency. Therefore, we can say that they are experiential idiomatic and irreducible.

# %% [markdown]
# ### Interpretations
#
# Based on these findings about idomatic collocations, I can make some interpretations about the linguistic and cultural implications of JK Rowling's first Harry Potter book.
#
# 1) Among all the collocations I found, some of them are “magical terminology“, which created by JK Rowling and only can be seen in the HP series, like 'Nimbus two thousand' and 'his wand'. This reveals a remarable feature of HP series that it creates a magical world with its distinct world view, full of fantasy and imagination.
#
# 2) A large amount of collocations are the name of characters or words related to main characters. Like "Professor Maconagal", "uncle Vernon", "Harry told Hagrid". More importantly, the most frequent significant bigram is "said Harry", while a lot of other collocation also related to Harry. This feature shows that this is a book with a definite focus on the story of the main character - Harry Potter, rather than some other fantasy fiction like The Lord of the Ring, which has a more dispersed story structure.
#
# 3) The collocation of "said + name of character" is very common in the book, which shows the author's preference of using dialogue or conversation to develop the story. Also, the large amount of dialogues also makes JK Rowling's book pretty readable.
#
# 4) There also exists some funny collocations as we can see that certain characters are tend to co-occur in the book. For example, "Fred and George" / "Harry, Ron, Hermoine" & "Malfoy, Crabb, Goyle" are significant collocations in bigram and trigram respectively. We can understanding the author's intention on character relationships by looking into such collocations.
#
# 5) It's worth mention that most of the high-frequency words and significant collocations are very simple vocabularies and simple collocation. A strong example is the collocations related to verbs, like "Harry could see", "shook his hand", "Harry look", "he felt". This feature makes this book very easy to read, even the reader is very young or not a native English speaker.
#
# 6) The frequency of N-grams are generally less than trigrams, while the frequency of trigrams of generally less than bigrams. This finding shows that even JK Rowling tend to use easy words in her book, the diversity of words' co-occurence and the sentences structures may not monotonous.
#
# 7) In conclusion, all these findings I mentioned above contributed to a remarkable feature of the Harry Potter book -  its interestingness and readability, which can be a reason to explain why HP series is popular among teenagers in the worldwide scale.

# %% [markdown]
# # Distributional distances
#
# If we want to compare different corpora, we need a distance or divergence that compares the two distributions.
#
# We will use the:
#
# + Kullback-Leibler (KL) divergence
# + $\chi^2$ divergence
# + Kolmogorov-Smirnov (KS) distance
# + Wasserstein distance
#
# ### Kullback-Leibler and $x^2$ divergences ###
#
# KL and $\chi^2$ divergences are members of the broader <a "href=https://en.wikipedia.org/wiki/F-divergence" target="_blank">$f$-divergence</a> family, a function of $D_f (P || Q)$ that calculates the difference between two probability distributions P and Q. The KL $f(t)$ is $ t \text{ log } t $, while the $\chi^2$ is $t^2-1$. KL comes from information and $\chi^2$ from measure theory. As such, the KL divergence computes the relative entropy between two distributions--how they differ in bits, while the $\chi^2$ whether the same statistical inferences can be drawn from them both.
#
# Specifically, given two discrete probability distributions $P$ and $Q$, the Kullback-Leibler divergence from $Q$ to $P$ is defined as:
#
# $D_{\mathrm{KL}}(P\|Q) = \sum_i P(i) \, \log\frac{P(i)}{Q(i)}$.
#
# The [scipy.stats.entropy()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.entropy.html) function does the calculation for you, which takes in two arrays of probabilities and computes the KL divergence. Note that the KL divergence is in general not commutative, i.e. $D_{\mathrm{KL}}(P\|Q) \neq D_{\mathrm{KL}}(Q\|P)$ .
#
# Also note that the KL divernce is the sum of elementwise divergences. Scipy provides [scipy.special.kl_div()](https://docs.scipy.org/doc/scipy/reference/generated/scipy.special.kl_div.html#scipy-special-kl-div) which calculates elementwise divergences for you.
#
# The $\chi^2$ Divergence is defined as:
#
# $D_{\mathrm{\chi^2}}(P\|Q) = \sum_i \left(\frac{P(i)}{Q(i)}-1\right)^2$.
#
# This is also noncommutative, and the code can be drawn directly from scipy.
#
# ### Kolmogorov-Smirnov ###
#
# The two-sample Kolmogovorov-Smirnov test statistic calculates the distance between the cumulative distribution function of the two distributions to be compared, and, along with the $x^2$ divergence, is among the most common approaches two calculating a distance in statistics. It can be interpreted as a test of whether two distributions are drawn from the same underlying distribution. As with the others, the code is readily available in scipy.
#
# ### Wasserstein Distance ###
#
# When this is computed on a Euclidian metric structure (e.g., numbers of words), this is also known as the earth mover’s distance, because it can be seen as the minimum amount of "work" required to transform $P$ into $Q$, where "work" is measured as the amount of distribution weight that must be moved, multiplied by the distance it has to be moved.
#
# ### Computing ###
#
# To do this we will need to create the arrays, lets compare the Whitehouse releases with the Kennedy releases. First we have to download them and load them into a DataFrame.

# %%
kenReleases = getGithubFiles('https://api.github.com/repos/lintool/GrimmerSenatePressReleases/contents/raw/Kennedy', maxFiles = 10)
kenReleases[:5]
# Out:
#                                         download_url  \
# 0  https://raw.githubusercontent.com/lintool/Grim...
# 1  https://raw.githubusercontent.com/lintool/Grim...
# 2  https://raw.githubusercontent.com/lintool/Grim...
# 3  https://raw.githubusercontent.com/lintool/Grim...
# 4  https://raw.githubusercontent.com/lintool/Grim...
#
#                                             html_url                    name  \
# 0  https://github.com/lintool/GrimmerSenatePressR...  01Apr2005Kennedy14.txt
# 1  https://github.com/lintool/GrimmerSenatePressR...  01Aug2005Kennedy12.txt
# 2  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy10.txt
# 3  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy11.txt
# 4  https://github.com/lintool/GrimmerSenatePressR...  01Aug2006Kennedy12.txt
#
#                                  path  \
# 0  raw/Kennedy/01Apr2005Kennedy14.txt
# 1  raw/Kennedy/01Aug2005Kennedy12.txt
# 2  raw/Kennedy/01Aug2006Kennedy10.txt
# 3  raw/Kennedy/01Aug2006Kennedy11.txt
# 4  raw/Kennedy/01Aug2006Kennedy12.txt
#
#                                                 text
# 0           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 1           FOR IMMEDIATE RELEASE   FOR IMMEDIATE...
# 2           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 3           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...
# 4           FOR IMMEDIATE RELEASE  FOR IMMEDIATE ...

# %% [markdown]
# Then we can tokenize, stem and remove stop words, like we did for the Whitehouse press releases

# %%
kenReleases['tokenized_text'] = kenReleases['text'].apply(lambda x: nltk.word_tokenize(x))
kenReleases['normalized_tokens'] = kenReleases['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))

# %% [markdown]
# Now we need to compare the two collection of words, remove those not found in both, and assign the remaining ones indices.

# %%
whWords = set(whReleases['normalized_tokens'].sum())
kenWords = set(kenReleases['normalized_tokens'].sum())

#Change & to | if you want to keep all words
overlapWords = whWords & kenWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['student']
# Out:
# 229

# %% [markdown]
# Now we can count the occurrences of each word in the corpora and create our arrays. Note that we don't have to use numpy arrays as we do here. We could just use a list, but the arrays are faster in numpy so we encourage you to get in the habit of using them.

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

whProbArray = makeProbsArray(whReleases['normalized_tokens'], overlapWordsDict)
kenProbArray = makeProbsArray(kenReleases['normalized_tokens'], overlapWordsDict)
kenProbArray.sum()
#There is a little bit of a floating point math error
#but it's too small to see with print and too small matter here
# Out:
# 0.9999999999999999

# %% [markdown]
# We can now compute the KL divergence. Pay attention to the asymmetry. Use [the Jensen–Shannon divergence](https://en.wikipedia.org/wiki/Jensen%E2%80%93Shannon_divergence), which is the average KL divergence between each distribution and the average of both distributions (i.e., the midpoint), if you want symmetry.

# %%
wh_kenDivergence = scipy.stats.entropy(whProbArray, kenProbArray)
print (wh_kenDivergence)
ken_whDivergence = scipy.stats.entropy(kenProbArray, whProbArray)
print (ken_whDivergence)
# Out:
# 0.6176419677476953
# 0.5877085657188859

# %% [markdown]
# Then, we can do the elementwise calculation and see which words best distinguish the two corpora.

# %%
wh_kenDivergence_ew = scipy.special.kl_div(whProbArray, kenProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = wh_kenDivergence_ew
kl_df[:10]
# Out:
#       word  elementwise divergence
# 0    sever            7.004197e-04
# 1     pass            9.505188e-05
# 2  circuit            2.293277e-07
# 3   action            1.101070e-03
# 4    initi            4.815330e-05
# 5     fact            1.568293e-03
# 6     show            7.962677e-04
# 7   recogn            6.329703e-05
# 8   depart            1.764987e-02
# 9     sent            1.898911e-04

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:10]
# Out:
#          word  elementwise divergence
# 195      iraq                0.086929
# 45       bush                0.042354
# 54       stem                0.021884
# 252       law                0.020547
# 10    protect                0.019358
# 296  american                0.018154
# 8      depart                0.017650
# 307     bring                0.014128
# 251    member                0.012429
# 162       war                0.011739

# %% [markdown]
# Now we will apply what we learned today to the Guternberg texts in nltk and see if we can detect patterns between them.
#
# First, let's transform every text into normalized tokens. Note that in this first step, no stopword is removed.

# %%
fileids = nltk.corpus.gutenberg.fileids()
corpora = []
for fileid in fileids:
    words = nltk.corpus.gutenberg.words(fileid)
    normalized_tokens = normlizeTokens(words, stopwordLst = [], stemmer = snowball)
    corpora.append(normalized_tokens)

# %% [markdown]
# Then, let's separate the normalized tokens into stopwords and non-stopwords.

# %%
corpora_s = []
corpora_nons = []
for corpus in corpora:
    s = []
    nons = []
    for word in corpus:
        if word in stop_words_nltk:
            s.append(word)
        else:
            nons.append(word)
    corpora_s.append(s)
    corpora_nons.append(nons)

# %% [markdown]
# Define some covenient funtions for calculating divergence and distances.

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %% [markdown]
# Now we will calculate the KL divergence for each pair of corpora, turn the results into a matrix, and visualize the matrix as a heatmap. Recall that $D_{\mathrm{KL}}(P\|Q)$ measures the amount of information loss when $Q$ is used to approximate $P$. Here, the rows are the $P$s used for calculating KL divergences, and the columns are the $Q$s. So, each cell measures the amount of information loss when the word distribution of the column text is used to approximate the word distribution of the row text. Because the KL divergence is directional, such that the divergence of $P$ from $Q$ is different from the same of $Q$ from $P$, the matrix is assymetric and contains unique information above and below the diagonal. The same is true for the $\chi^2$ divergence.

# %%
L = []
for p in corpora:
    l = []
    for q in corpora:
        l.append(Divergence(p,q, difference = 'KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Note that works by the same author have the lowest within-group KL divergences.
#
# To reveal more patterns, let's do a multidimensional scaling of the matrix.

# %%
mds = sklearn.manifold.MDS()
pos = mds.fit(M).embedding_
x = pos[:,0]
y = pos[:,1]
fig, ax = plt.subplots(figsize = (6,6))
plt.plot(x, y, ' ')
for i, txt in enumerate(fileids):
    ax.annotate(txt, (x[i],y[i]))
# Out:
# /Users/czd/anaconda3/lib/python3.6/site-packages/sklearn/manifold/mds.py:411: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %% [markdown]
# Do you see any patterns in the image shown above? Does it make sense?
#
# We may just want to focus on the distrbution of stopwords or non-stopwords. Let's do the analysis again first for stopwords and then for non-stopwords.

# %%
L = []
for p in corpora_s:
    l = []
    for q in corpora_s:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KL'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# Now we compute the same for the assymmetric $\chi^2$ Divergence.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Chi2'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# For the KS distance:

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='KS'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# And finally for the Wasserstein or "earth mover's" Distance.

# %%
L = []
for p in corpora_nons:
    l = []
    for q in corpora_nons:
        l.append(Divergence(p,q, difference='Wasserstein'))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids, index = fileids)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# You can see that the Bible is highly divergent and this makes reading the plot somewhat difficult. Let's fix this by taking the log of each cell, which will reduce the distance of the Bible from other texts as an outlier.

# %%
ax = sns.heatmap(div.apply(np.log).replace([np.inf, -np.inf], np.nan))
plt.show()

# %% [markdown]
# This is more legible, as it continues to show that the Bible is divergent, but other structure is also visible, such as the divergence of Austen's *Emma* and *Sense and Sensibility*, and Edgeworth's *The Parent's Assistant*.
#
# If we want to rerun this on a new data set of our own composition, we can be a bit more efficient with our coding. Let's use the Shakespeare texts from last week as example:

# %%
shakespeare_df = lucem_illud.loadTextDirectory('../data/Shakespeare')

# %% [markdown]
# Now we stem and remove stopwords

# %%
shakespeare_df['tokenized_text'] = shakespeare_df['text'].apply(lambda x: nltk.word_tokenize(x))
shakespeare_df['normalized_tokens'] = shakespeare_df['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = porter))

# %% [markdown]
# Create the corpus file and generate the heatmap:

# %%
measure = 'KS' #"KL", "Chi2", "KS", "Wasserstein"
num_of_texts = 10 #The bigger this number the slower it will run, you can also try selecting your own plays
fileids_sp = list(shakespeare_df[:num_of_texts].index)
corpora_sp = list(shakespeare_df[:num_of_texts]['normalized_tokens'])
L = []
for p in corpora_sp:
    l = []
    for q in corpora_sp:
        l.append(Divergence(p,q, difference=measure))
    L.append(l)
M = np.array(L)
fig = plt.figure()
div = pandas.DataFrame(M, columns = fileids_sp, index = fileids_sp)
ax = sns.heatmap(div)
plt.show()

# %% [markdown]
# What are "The Passionate Pilgrim" and "The Phoenix and the Turtle"? Little known poems by Shakespeare that are unsurprisingly hard to classify, as they are so different from everything else he wrote.

# %% [markdown]
# ## <span style="color:red">*Exercise 4*</span>
#
# <span style="color:red">Construct cells immediately below this that calculate the KL and $\chi^2$ divergences, and the KS and Wasserstein distances between four separate corpora, plot these with heatmaps, and then array them in two dimensions with multidimensional scaling as above. What does this reveal about relations between the corpora? Which analysis (and divergence or distribution) distinguishes the authors or documents better?
#
# <span style="color:red">**Stretch**: Calculate the <a "href=https://en.wikipedia.org/wiki/Jensen–Shannon_divergence" target="_blank">Jensen-Shannon Divergence</a> between your four corpora. What is the relationship between the KL and JS divergences?</span>

# %% [markdown]
# In this part, I intend to introduce more Harry Potter book into my analysis. They are: a) Harry Potter and the Goblet of Fire, which is the fourth book of HP series, written by JK Rowling, b)Harry Potter and the Hald Blood Prince, which is the sixth book of HP series, written by JK Rowling, and c)Draco Dormiens, which is a fanfiction of HP series, written by a book fan. What I want to do in this part is to see if the content and linguisic features changed among the HP series, since the plots of Harry Potter were getting darker and more sophisticated. Moreover, I also want to check the fanfictions, which written by HP lovers, are different from the original HP books in wrting styles.

# %% [markdown]
# ## Import More Corpuses

# %% [markdown]
# ### Harry Potter and the Half Blood Prince

# %% [markdown]
# Import the data.

# %%
hp_halfblood_prince_pdf = "http://publish.uwo.ca/~hamendt/WD%20final%20Project/litertaure/Half%20Blood%20Prince.pdf"

hpPrinceRequest = requests.get(hp_halfblood_prince_pdf,stream=True)
hpPrinceBytes = io.BytesIO(hpPrinceRequest.content)
hpPrinceContent = readPDF(hpPrinceBytes)
print(hpPrinceContent[:550])
len(hpPrinceContent)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Harry Potter
#
# AND THE  HALF-BLOOD PRINCE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# also by j. k. rowling
#
# Harry Potter and the Sorcerer’s Stone
#
# Year One at Hogwarts
#
# Harry Potter and the Chamber of Secrets
#
# Year Two at Hogwarts
#
# Harry Potter and the Prisoner of Azkaban
#
# Year Three at Hogwarts
#
# Harry Potter and the Goblet of Fire
#
# Year Four at Hogwarts
#
# Harry Potter and the Order of the Phoenix
#
# Year Five at Hogwarts
#
# Harry Potter and the Half-Blood Prince
#
# Year Six at Hogwarts
#
# Harry Potter and the
# 1086439

# %% [markdown]
# Convert the text into `DataFrame`. Then tokenize, stem and remove stop words.

# %%
#Convert the text into dataframe
hpPrinceSentences = hpPrinceContent.replace('\n','').split('.')
hpPrinceDF = pandas.DataFrame(hpPrinceSentences,columns=['text'])
#Add a column to contain tokenized text
hpPrinceDF['tokenized_text'] = hpPrinceDF['text'].apply(lambda x: nltk.word_tokenize(x))
#Add a column to contain normalized tokens
hpPrinceDF['normalized_tokens'] = hpPrinceDF['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
hpPrinceDF
# Out:
#                                                     text  \
# 0
#
#
#
#            Harry Potter AND THE  HALF-B...
# 1                                                      k
# 2       rowling Harry Potter and the Sorcerer’s Stone...
# 3                                                      K
# 4       Rowling ILLUSTRATIONS  BY  Mary  GrandPré    ...
# 5            LEVINE BOOKS AN IMPRINT OF SCHOLASTIC Press
# 6
#    To Mackenzie, My beautiful daughter, I de...
# 7                             Text copyright © 2005 by J
# 8                                                      K
# 9       Rowling  Illustrations by Mary Grandpré copyr...
# 10      HARRY POTTER, characters, names and related i...
# 11                    Harry Potter Publishing Rights © J
# 12                                                     K
# 13                                               Rowling
# 14                                   All rights reserved
# 15                                 Published by Arthur A
# 16            Levine Books, an imprint of Scholastic Inc
# 17                               , Publishers since 1920
# 18      scholastic, the lantern logo and associated l...
# 19       No part of this publication may be reproduce...
# 20      For information regarding permission, write t...
# 21     , Attention: Permissions Department, 557 Broad...
# 27     [The, more, he, attempted, to, focus, on, the,...
# 28     [This, particular, opponent, had, appeared, on...
# 29     [The, Prime, Minister, ’, s, pulse, quickened,...
# ...                                                  ...
# 13534  [“, But, it, ’, ll, be, a, short, visit, ,, an...
# 13535  [”, “, But, where, will, you, go, if, you, don...
# 13536  [He, had, had, the, idea, in, his, head, ever,...
# 13537  [“, For, me, ,, it, started, there, ,, all, of...
# 13538  [I, ’, ve, just, got, a, feeling, I, need, to,...
# 13539  [And, I, can, visit, my, parents, ’, graves, ,...
# 13540           [”, “, And, then, what, ?, ”, said, Ron]
# 13541  [“, Then, I, ’, ve, got, to, track, down, the,...
# 13542  [“, That, ’, s, what, he, wanted, me, to, do, ...
# 13543  [If, Dumbledore, was, right, —, and, I, ’, m, ...
# 13544  [I, ’, ve, got, to, find, them, and, destroy, ...
# 13545  [And, if, I, meet, Severus, Snape, along, the,...
# 13546                  [”, There, was, a, long, silence]
# 13547  [The, crowd, had, almost, dispersed, now, ,, t...
# 13548  [“, We, ’, ll, be, there, ,, Harry, ,, ”, said...
# 13549  [“, What, ?, ”, “, At, your, aunt, and, uncle,...
# 13550  [“, And, then, we, ’, ll, go, with, you, where...
# 13551  [”, “, No, —, ”, said, Harry, quickly, ;, he, ...
# 13552  [“, You, said, to, us, once, before, ,, ”, sai...
# 13553  [We, ’, ve, had, time, ,, haven, ’, t, we, ?, ...
# 13554  [“, But, mate, ,, you, ’, re, (, cid:145, ), 6...
# 13555  [”, “, Why, ?, ”, “, Bill, and, Fleur, ’, s, w...
# 13556  [“, Yeah, ,, we, shouldn, ’, t, miss, that, ,,...
# 13557  [His, hand, closed, automatically, around, the...
# 13558  [(, cid:145, ), 652, (, cid:145, ), This, book...
# 13559  [The, art, for, both, the, jacket, and, the, i...
# 13560  [The, text, was, set, in, 12-point, Adobe, Gar...
# 13561  [The, book, was, typeset, by, Brad, Walrod, an...
# 13562  [The, Managing, Editor, was, Karyn, Browne, ;,...
# 13563                                                 []
#
#                                        normalized_tokens
# 0                        [harri, potter, princ, also, j]
# 1                                                    [k]
# 2      [rowl, harri, potter, sorcer, stone, year, one...
# 3                                                    [k]
# 4                [rowl, illustr, mari, grandpré, arthur]
# 5                [levin, book, imprint, scholast, press]
# 6              [mackenzi, beauti, daughter, dedic, twin]
# 7                                   [text, copyright, j]
# 8                                                    [k]
# 9      [rowl, illustr, mari, grandpré, copyright, war...
# 10     [harri, potter, charact, name, relat, indicia,...
# 11                    [harri, potter, publish, right, j]
# 12                                                   [k]
# 13                                                [rowl]
# 14                                       [right, reserv]
# 15                                     [publish, arthur]
# 16                 [levin, book, imprint, scholast, inc]
# 17                                       [publish, sinc]
# 18     [scholast, lantern, logo, associ, logo, tradem...
# 19     [part, public, may, reproduc, store, retriev, ...
# 20       [inform, regard, permiss, write, scholast, inc]
# 21     [attent, permiss, depart, broadway, new, york,...
# 22     [librari, congress, control, number, isbn, pri...
# 23                                                    []
# 24                                                    []
# 25     [first, american, edit, juli, c, n, e, n, one,...
# 26     [wait, call, presid, far, distant, countri, wo...
# 27     [attempt, focus, print, page, befor, clear, pr...
# 28     [particular, oppon, appear, news, veri, day, o...
# 29     [prime, minist, puls, quicken, veri, thought, ...
# ...                                                  ...
# 13534                         [short, visit, gone, good]
# 13535  [go, come, back, school, thought, might, go, b...
# 13536  [idea, head, ever, sinc, night, white, tomb, d...
# 13537                                            [start]
# 13538                              [got, feel, need, go]
# 13539                       [visit, parent, grave, like]
# 13540                                        [said, ron]
# 13541  [got, track, rest, horcrux, said, harri, eye, ...
# 13542                                  [want, whi, told]
# 13543              [dumbledor, right, sure, still, four]
# 13544  [got, find, destroy, got, go, seventh, bit, vo...
# 13545  [meet, severus, snape, along, way, ad, much, b...
# 13546                                     [long, silenc]
# 13547  [crowd, almost, dispers, straggler, give, monu...
# 13548                                 [harri, said, ron]
# 13549                      [aunt, uncl, hous, said, ron]
# 13550                                   [go, wherev, go]
# 13551  [said, harri, quick, count, meant, understand,...
# 13552  [said, us, onc, befor, said, hermion, quiet, t...
# 13553                  [time, whatev, happen, said, ron]
# 13554  [mate, chapter, thirti, go, come, round, mum, ...
# 13555  [whi, bill, fleur, wed, rememb, harri, look, s...
# 13556                          [yeah, miss, said, final]
# 13557  [hand, close, automat, around, fake, horcrux, ...
# 13558                 [book, art, direct, david, saylor]
# 13559  [art, jacket, interior, creat, use, pastel, to...
# 13560  [text, set, adob, garamond, typefac, base, typ...
# 13561  [book, typeset, brad, walrod, print, bound, rr...
# 13562  [manag, editor, karyn, brown, continu, editor,...
# 13563                                                 []
#
# [13564 rows x 3 columns]

# %% [markdown]
# ### Harry Potter and the Goblet of Fire

# %%
hp_goblet_fire_pdf = "http://publish.uwo.ca/~hamendt/WD%20final%20Project/litertaure/Goblet%20of%20Fire.pdf"

hpGobletRequest = requests.get(hp_goblet_fire_pdf,stream=True)
hpGobletBytes = io.BytesIO(hpGobletRequest.content)
hpGobletContent = readPDF(hpGobletBytes)
print(hpGobletContent[:550])
len(hpGobletContent)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
# Harry Potter
#
# AND THE  GOBLET OF FIRE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# also by j. k. rowling
#
# Harry Potter and the Sorcerer’s Stone
#
# Year One at Hogwarts
#
# Harry Potter and the Chamber of Secrets
#
# Year Two at Hogwarts
#
# Harry Potter and the Prisoner of Azkaban
#
# Year Three at Hogwarts
#
# Harry Potter and the Goblet of Fire
#
# Year Four at Hogwarts
#
# Harry Potter and the Order of the Phoenix
#
# Year Five at Hogwarts
#
# Harry Potter and the Half-Blood Prince
#
# Year Six at Hogwarts
#
# Harry Potter and the Deathly Hallows
#
# Ye
# 1230122

# %%
#Convert the text into dataframe
hpGobletSentences = hpGobletContent.replace('\n','').split('.')
hpGobletDF = pandas.DataFrame(hpGobletSentences,columns=['text'])
#Add a column to contain tokenized text
hpGobletDF['tokenized_text'] = hpGobletDF['text'].apply(lambda x: nltk.word_tokenize(x))
#Add a column to contain normalized tokens
hpGobletDF['normalized_tokens'] = hpGobletDF['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball))
hpGobletDF
# Out:
#                                                     text  \
# 0
#
#
#
#         Harry Potter AND THE  GOBLET OF ...
# 1                                                      k
# 2       rowling Harry Potter and the Sorcerer’s Stone...
# 3                                                      K
# 4       Rowling ILLUSTRATIONS  BY  Mary  GrandPré    ...
# 5            LEVINE BOOKS AN IMPRINT OF SCHOLASTIC Press
# 6
#  To Peter Rowling, In Memory of Mr
# 7       Ridley And to Susan Sladden, Who helped Harry...
# 8                                                      K
# 9       Rowling  Illustrations by Mary GrandPre copyr...
# 10                                   All rights reserved
# 11      Published by Scholastic Press, a division of ...
# 12                               , Publishers since 1920
# 13      SCHOLASTIC, SCHOLASTIC PRESS, and the LANTERN...
# 14       HARRY POTTER and all related characters and ...
# 15       No part of this publication may be reproduce...
# 16      For information regarding permission, write t...
# 17     , Attention: Permissions Department, 555 Broad...
# 18       Library of Congress Cataloging-in-Publicatio...
# 19      40 39 38 37 36 35 34 33                      ...
# 20                                                     S
# 21                                                     A
# 22          55  First American edition, July 2000
#  C...
# 23      Crouch · 535 TWENTY-NINE The Dream · 564 THIR...
# 24      It stood on a hill overlooking the village, s...
# 25      Once a fine-looking manor, and easily the lar...
# 26      The Little Hangletons all agreed that the old...
# 27     ” Half  a  century  ago,  something  strange  ...
# 28       The  story  had  been picked over so many ti...
# 29      Every version of the tale, however, started i...
# ...                                                  ...
# 17393
# 17394    although  she might not be so keen for you t...
# 17395
# 17396
# 17397
# 17398  ” “Harry,” Fred began, but Harry pulled out hi...
# 17399   “Look,” he said flatly, “take it, or I’ll hex...
# 17400                          I know some good ones now
# 17401   Just do me one favor, okay? Buy Ron some diff...
# 17402  ” He  left  the  compartment  before  they  co...
# 17403   (cid:145) 733 (cid:145)
# CHAPTER  THIRTY-SEVE...
# 17404                                                Mrs
# 17405                           Weasley was close by him
# 17406   She hugged Harry very tightly when she saw hi...
# 17407                               Keep in touch, Harry
# 17408  ” “See you, Harry,” said Ron, clapping him on ...
# 17409   “ ’Bye,  Harry!”  said  Hermione,  and  she  ...
# 17410   “Harry  —  thanks,”  George  muttered,  while...
# 17411   Harry  winked  at  them,  turned  to  Uncle  ...
# 17412   There was no point worrying yet, he told hims...
# 17413   As Hagrid had said, what would come, would come
# 17414
# 17415
# 17416           and he would have to meet it when it did
# 17417   (cid:145) 734 (cid:145)
#
#    This book was ar...
# 17418   The art for both the jacket and the interior ...
# 17419   The text was set in 12-point Adobe Garamond, ...
# 17420   The book was typeset by Brad Walrod and was p...
# 17421   The Managing Editor was Manuela Soares and th...
# 17422
#
#
#
#
#
#                                           tokenized_text  \
# 0      [Harry, Potter, AND, THE, GOBLET, OF, FIRE, al...
# 1                                                    [k]
# 2      [rowling, Harry, Potter, and, the, Sorcerer, ’...
# 3                                                    [K]
# 4      [Rowling, ILLUSTRATIONS, BY, Mary, GrandPré, A...
# 5      [LEVINE, BOOKS, AN, IMPRINT, OF, SCHOLASTIC, P...
# 6            [To, Peter, Rowling, ,, In, Memory, of, Mr]
# 7      [Ridley, And, to, Susan, Sladden, ,, Who, help...
# 8                                                    [K]
# 9      [Rowling, Illustrations, by, Mary, GrandPre, c...
# 10                               [All, rights, reserved]
# 11     [Published, by, Scholastic, Press, ,, a, divis...
# 12                          [,, Publishers, since, 1920]
# 13     [SCHOLASTIC, ,, SCHOLASTIC, PRESS, ,, and, the...
# 14     [HARRY, POTTER, and, all, related, characters,...
# 15     [No, part, of, this, publication, may, be, rep...
# 16     [For, information, regarding, permission, ,, w...
# 17     [,, Attention, :, Permissions, Department, ,, ...
# 18     [Library, of, Congress, Cataloging-in-Publicat...
# 19     [40, 39, 38, 37, 36, 35, 34, 33, 05, 06, 07, 0...
# 20                                                   [S]
# 21                                                   [A]
# 22     [55, First, American, edition, ,, July, 2000, ...
# 23     [Crouch, ·, 535, TWENTY-NINE, The, Dream, ·, 5...
# 24     [It, stood, on, a, hill, overlooking, the, vil...
# 25     [Once, a, fine-looking, manor, ,, and, easily,...
# 26     [The, Little, Hangletons, all, agreed, that, t...
# 27     [”, Half, a, century, ago, ,, something, stran...
# 28     [The, story, had, been, picked, over, so, many...
# 29     [Every, version, of, the, tale, ,, however, ,,...
# ...                                                  ...
# 17393                                                 []
# 17394  [although, she, might, not, be, so, keen, for,...
# 17395                                                 []
# 17396                                                 []
# 17397                                                 []
# 17398  [”, “, Harry, ,, ”, Fred, began, ,, but, Harry...
# 17399  [“, Look, ,, ”, he, said, flatly, ,, “, take, ...
# 17400                   [I, know, some, good, ones, now]
# 17401  [Just, do, me, one, favor, ,, okay, ?, Buy, Ro...
# 17402  [”, He, left, the, compartment, before, they, ...
# 17403  [(, cid:145, ), 733, (, cid:145, ), CHAPTER, T...
# 17404                                              [Mrs]
# 17405                     [Weasley, was, close, by, him]
# 17406  [She, hugged, Harry, very, tightly, when, she,...
# 17407                        [Keep, in, touch, ,, Harry]
# 17408  [”, “, See, you, ,, Harry, ,, ”, said, Ron, ,,...
# 17409  [“, ’, Bye, ,, Harry, !, ”, said, Hermione, ,,...
# 17410  [“, Harry, —, thanks, ,, ”, George, muttered, ...
# 17411  [Harry, winked, at, them, ,, turned, to, Uncle...
# 17412  [There, was, no, point, worrying, yet, ,, he, ...
# 17413  [As, Hagrid, had, said, ,, what, would, come, ...
# 17414                                                 []
# 17415                                                 []
# 17416  [and, he, would, have, to, meet, it, when, it,...
# 17417  [(, cid:145, ), 734, (, cid:145, ), This, book...
# 17418  [The, art, for, both, the, jacket, and, the, i...
# 17419  [The, text, was, set, in, 12-point, Adobe, Gar...
# 17420  [The, book, was, typeset, by, Brad, Walrod, an...
# 17421  [The, Managing, Editor, was, Manuela, Soares, ...
# 17422                                                 []
#
#                                        normalized_tokens
# 0                 [harri, potter, goblet, fire, also, j]
# 1                                                    [k]
# 2      [rowl, harri, potter, sorcer, stone, year, one...
# 3                                                    [k]
# 4                [rowl, illustr, mari, grandpré, arthur]
# 5                [levin, book, imprint, scholast, press]
# 6                              [peter, rowl, memori, mr]
# 7      [ridley, susan, sladden, help, harri, cupboard...
# 8                                                    [k]
# 9      [rowl, illustr, mari, grandpr, copyright, warn...
# 10                                       [right, reserv]
# 11      [publish, scholast, press, divis, scholast, inc]
# 12                                       [publish, sinc]
# 13     [scholast, scholast, press, lantern, logo, tra...
# 14     [harri, potter, relat, charact, element, trade...
# 15     [part, public, may, reproduc, store, retriev, ...
# 16       [inform, regard, permiss, write, scholast, inc]
# 17     [attent, permiss, depart, broadway, new, york,...
# 18     [librari, congress, data, avail, librari, cong...
# 19                                            [print, u]
# 20                                                    []
# 21                                                    []
# 22     [first, american, edit, juli, content, one, ri...
# 23     [crouch, dream, thirti, pensiev, third, task, ...
# 24     [stood, hill, overlook, villag, window, board,...
# 25     [onc, manor, easili, largest, grandest, build,...
# 26           [littl, hangleton, agre, old, hous, creepi]
# 27     [half, centuri, ago, someth, strang, horribl, ...
# 28     [stori, pick, mani, time, embroid, mani, place...
# 29     [everi, version, tale, howev, start, place, fi...
# ...                                                  ...
# 17393                                                 []
# 17394  [although, might, keen, join, ministri, anymor...
# 17395                                                 []
# 17396                                                 []
# 17397                                                 []
# 17398            [harri, fred, began, harri, pull, wand]
# 17399                      [look, said, flat, take, hex]
# 17400                                  [know, good, one]
# 17401  [one, favor, okay, buy, ron, differ, dress, ro...
# 17402  [left, compart, befor, could, say, anoth, word...
# 17403     [chapter, uncl, vernon, wait, beyond, barrier]
# 17404                                              [mrs]
# 17405                                   [weasley, close]
# 17406  [hug, harri, veri, tight, saw, whisper, ear, t...
# 17407                               [keep, touch, harri]
# 17408                [see, harri, said, ron, clap, back]
# 17409  [bye, harri, said, hermion, someth, never, don...
# 17410     [harri, thank, georg, mutter, fred, nod, side]
# 17411  [harri, wink, turn, uncl, vernon, follow, sile...
# 17412  [point, worri, yet, told, got, back, dursley, ...
# 17413           [hagrid, said, would, come, would, come]
# 17414                                                 []
# 17415                                                 []
# 17416                                      [would, meet]
# 17417                 [book, art, direct, david, saylor]
# 17418  [art, jacket, interior, creat, use, pastel, to...
# 17419  [text, set, adob, garamond, typefac, base, typ...
# 17420  [book, typeset, brad, walrod, print, bound, qu...
# 17421  [manag, editor, manuela, soar, manufactur, dir...
# 17422                                                 []
#
# [17423 rows x 3 columns]

# %% [markdown]
# ### Harry Potter Fanfictions

# %%
hp_fanfic_pdf = "http://broomcupboard.net/fanfiction/DracoDormiens.pdf"

hpFanficRequest = requests.get(hp_fanfic_pdf,stream=True)
hpFanficBytes = io.BytesIO(hpFanficRequest.content)
hpFanficContent = readPDF(hpFanficBytes)
print(hpFanficContent[:550])
len(hpFanficContent)
# Out:
#
#
#
#
#
#
# Draco Dormiens
#
#
#
# Part One of the Draco Trilogy
#
#
# Disclaimer: This story is based on characters and situations created and owned
# by JK Rowling, various publishers including but not limited to Bloomsbury Books,
# Scholastic Books and Raincoast Books, and Warner Bros., Inc. No money is being
# made and no copyright or trademark infringement is intended. This work
# contains quotes from movies and television shows, stories and plays, novels and
# films. They are cited at the end of each chapter. Other citations can be made
# where neces
# 406264

# %%
#Convert the text into dataframe
hpFanficSentences = hpFanficContent.replace('\n','').split('.')
hpFanficDF = pandas.DataFrame(hpFanficSentences,columns=['text'])
#Add a column to contain tokenized text
hpFanficDF['tokenized_text'] = hpFanficDF['text'].apply(lambda x: nltk.word_tokenize(x))
#Add a column to contain normalized tokens
hpFanficDF['normalized_tokens'] = hpFanficDF['tokenized_text'].apply(lambda x: normlizeTokens(x, stopwordLst = stop_words_nltk, stemmer = snowball
# 7     [Sometimes, I, make, source, errors, in, good,...
# 8     [Sometimes, I, do, n't, know, where, something...
# 9     [Let, me, know, any, of, these, things, ,, and...
# 10    [Author, 's, Notes, :, This, fanfiction, is, a...
# 11    [It, was, written, in, the, year, following, G...
# 12    [It, posits, a, universe, in, which, Sirius, i...
# 13    [~~~~~~~~~~~~~, Chapter, One, :, The, Polyjuic...
# 14    [``, Can, anyone, tell, me, what, this, is, ?,...
# 15    [Hermione´s, hand, shot, into, the, air, ,, as...
# 16    [``, Polyjuice, Potion, ,, '', she, said, prom...
# 17    [She, was, probably, recalling, how, it, taste...
# 18                                [Snape, ignored, her]
# 19    [``, Anyone, ?, '', he, said, ,, scanning, the...
# 20    [Draco, Malfoy, raised, a, pale, ,, lazy, hand...
# 21    [``, Polyjuice, Potion, ,, '', he, drawled, ou...
# 22                             [Harry, glared, at, him]
# 23    [Where, the, rest, of, the, class, looked, swe...
# 24    [``, Very, good, ,, Draco, !, '', said, Snape,...
# 25                   [``, Five, points, for, Slytherin]
# 26    [Now, ,, '', he, went, on, ,, ``, Can, anyone,...
# 27    [``, Weasley, ?, '', Ron, ,, startled, in, mid...
# 28    [``, Snape, ,, looking, disappointed, ,, said,...
# 29    [``, He, did, not, give, five, points, to, Gry...
# ...                                                 ...
# 6379  [``, Hermione, !, '', ``, I, ca, n't, help, it...
# 6380  [``, It, 's, too, funny, !, '', And, now, Drac...
# 6381  [Harry, had, never, seen, him, laugh, like, th...
# 6382  [He, actually, sat, down, on, the, ground, ,, ...
# 6383  [Slowly, ,, Harry, started, to, smile, ,, and,...
# 6384  [The, sound, of, their, laughter, ,, rising, i...
# 6385  [References, :, 1, ), ``, Oh, ,, no, ,, '', sa...
# 6386           [``, All, down, to, shouting, ,, really]
# 6387                               [``, --, Blackadder]
# 6388  [2, ), ``, '', Meanwhile, ,, '', continued, Dr...
# 6389                             [``, --, The, X-Files]
# 6390  [3, ), ``, I, will, come, back, here, and, I, ...
# 6391  [Understood, ?, '', ``, Understood, ,, '', sai...
# 6392        [``, And, a, big, gold, star, for, imagery]
# 6393                                        [``, Buffy]
# 6394  [[, B, }, 4, ), [, /B, ], ``, I, just, never, ...
# 6395  [You, 've, always, been, like, a, part, of, me...
# 6396  [I, never, sit, around, thinking, about, how, ...
# 6397              [It, 's, just, a, part, of, my, life]
# 6398  [But, if, I, lost, it, --, if, I, could, n't, ...
# 6399  [It, goes, like, this, ,, ``, I, never, though...
# 6400  [I, always, thought, of, you, as, a, part, of,...
# 6401  [You, do, n't, go, around, thinking, 'I, love,...
# 6402                [To, be, mad, ,, or, to, be, blind]
# 6403                      [I, ca, n't, talk, about, it]
# 6404                             [It, 's, how, I, feel]
# 6405  [``, I, memorized, that, speech, when, I, was,...
# 6406  [The, Perilous, Gard, is, by, Elizabeth, Marie...
# 6407  [All, illustrations, in, this, document, were,...
# 6408                                                 []
#
#                                       normalized_tokens
# 0     [draco, dormien, part, one, draco, trilog, dis...
# 1                                                 [inc]
# 2     [money, made, copyright, trademark, infring, i...
# 3     [work, contain, quot, movi, televis, show, sto...
# 4                                  [cite, end, chapter]
# 5                              [citat, made, necessari]
# 6     [collect, funni, quot, like, pack, rat, alway,...
# 7     [sometim, make, sourc, error, good, faith, lea...
# 8     [sometim, know, someth, come, case, note, anyway]
# 9                   [let, know, ani, thing, add, citat]
# 10         [author, note, fanfict, au, altern, univers]
# 11    [written, year, follow, goblet, fire, doe, inc...
# 12    [posit, univers, sirius, still, aliv, dumbledo...
# 13    [chapter, one, polyjuic, potion, june, boil, h...
# 14    [anyon, tell, ask, miser, class, stifl, robe, ...
# 15                             [hand, shot, air, usual]
# 16    [polyjuic, potion, said, prompt, gave, littl, ...
# 17    [probabl, recal, tast, thought, harri, inward,...
# 18                                       [snape, ignor]
# 19                           [anyon, said, scan, class]
# 20         [draco, malfoy, rais, pale, lazi, hand, air]
# 21             [polyjuic, potion, drawl, corner, mouth]
# 22                                       [harri, glare]
# 23    [rest, class, look, sweati, miser, draco, look...
# 24         [veri, good, draco, said, snape, enthusiast]
# 25                             [five, point, slytherin]
# 26    [went, anyon, tell, doe, round, sudden, ron, b...
# 27    [weasley, ron, startl, said, er, chang, somebo...
# 28             [snape, look, disappoint, said, correct]
# 29    [give, five, point, gryffindor, howev, onli, p...
# ...                                                 ...
# 6379                         [hermion, ca, help, giggl]
# 6380                       [funni, draco, start, laugh]
# 6381  [harri, never, seen, laugh, like, befor, snick...
# 6382  [actual, sat, ground, put, face, hand, shout, ...
# 6383  [slowli, harri, start, smile, look, hermion, b...
# 6384  [sound, laughter, rise, pitch, drift, lake, la...
# 6385                       [refer, oh, said, dumbledor]
# 6386                                    [shout, realli]
# 6387                                         [blackadd]
# 6388  [meanwhil, continu, draco, drop, hogwart, beco...
# 6389                                                 []
# 6390              [come, back, yank, ribcag, wear, hat]
# 6391  [understood, understood, said, harri, grin, de...
# 6392                         [big, gold, star, imageri]
# 6393                                            [buffi]
# 6394                          [b, never, thought, like]
# 6395                   [alway, like, part, like, magic]
# 6396  [never, sit, around, think, love, abl, magic, ...
# 6397                                       [part, life]
# 6398  [lost, could, magic, anymor, alway, thought, c...
# 6399                  [goe, like, never, thought, like]
# 6400            [alway, thought, part, like, eye, hand]
# 6401  [go, around, think, love, eye, love, hand, thi...
# 6402                                       [mad, blind]
# 6403                                         [ca, talk]
# 6404                                             [feel]
# 6405                    [memor, speech, kid, want, use]
# 6406               [peril, gard, elizabeth, mari, pope]
# 6407  [illustr, document, drawn, monica, starl, exce...
# 6408                                                 []
#
# [6409 rows x 3 columns]

# %% [markdown]
# ## Calculate distances

# %% [markdown]
# Compare the four collection of words, remove those not found in all collections, and assign the remaining ones indices.

# %%
stoneWords = set(hpStoneSentencesDF['normalized_tokens'].sum())
gobletWords = set(hpGobletDF['normalized_tokens'].sum())
princeWords = set(hpPrinceDF['normalized_tokens'].sum())
fanficWords = set(hpFanficDF['normalized_tokens'].sum())

#Change & to | if you want to keep all words
overlapWords = stoneWords & princeWords

overlapWordsDict = {word: index for index, word in enumerate(overlapWords)}
overlapWordsDict['student']
# Out:
# 2069

# %% [markdown]
# Count the occurrences of each word in the corpora and create our arrays.

# %%
def makeProbsArray(dfColumn, overlapDict):
    words = dfColumn.sum()
    countList = [0] * len(overlapDict)
    for word in words:
        try:
            countList[overlapDict[word]] += 1
        except KeyError:
            #The word is not common so we skip it
            pass
    countArray = np.array(countList)
    return countArray / countArray.sum()

stoneProbArray = makeProbsArray(hpStoneSentencesDF['normalized_tokens'], overlapWordsDict)
gobletProbArray = makeProbsArray(hpGobletDF['normalized_tokens'], overlapWordsDict)
princeProbArray = makeProbsArray(hpPrinceDF['normalized_tokens'], overlapWordsDict)
fanficProbArray = makeProbsArray(hpFanficDF['normalized_tokens'], overlapWordsDict)

gobletProbArray.sum()
#There is a little bit of a floating point math error
#but it's too small to see with print and too small matter here
# Out:
# 1.0

# %% [markdown]
# We can now compute the KL divergence.

# %%
stone_princeDivergence = scipy.stats.entropy(stoneProbArray, princeProbArray)
print (stone_princeDivergence)
prince_stoneDivergence = scipy.stats.entropy(princeProbArray, stoneProbArray)
print (prince_stoneDivergence)
# Out:
# 0.33977518890070013
# 0.2777966502685937

# %% [markdown]
# Then, we can do the elementwise calculation and see which words best distinguish the two corpora.

# %%
stone_princeDivergence_ew = scipy.special.kl_div(stoneProbArray, princeProbArray)
kl_df = pandas.DataFrame(list(overlapWordsDict.keys()), columns = ['word'], index = list(overlapWordsDict.values()))
kl_df = kl_df.sort_index()
kl_df['elementwise divergence'] = stone_princeDivergence_ew
kl_df[:10]
# Out:
#        word  elementwise divergence
# 0     plant            1.022178e-04
# 1  therefor            5.186750e-05
# 2      fact            5.944904e-05
# 3      king            9.112791e-05
# 4    jacket            8.807414e-07
# 5      beak            1.307248e-05
# 6      pray            6.536238e-06
# 7  circumst            3.274574e-06
# 8    asleep            1.513552e-04
# 9      dens            3.916134e-05

# %%
kl_df.sort_values(by='elementwise divergence', ascending=False)[:30]
# Out:
#            word  elementwise divergence
# 1675         hi                0.083859
# 2130    quirrel                0.009064
# 851      dudley                0.008602
# 1104     hagrid                0.004620
# 1586     vernon                0.004168
# 206   dumbledor                0.004116
# 2121    dursley                0.003427
# 1161       uncl                0.003238
# 1596        yer                0.002914
# 2696       wood                0.002897
# 840     chapter                0.002784
# 1792      ginni                0.002490
# 907        aunt                0.002322
# 1702        yeh                0.002250
# 625     petunia                0.002214
# 1213     fluffi                0.002126
# 1735       said                0.001907
# 328      letter                0.001774
# 1047       upon                0.001683
# 2624         ha                0.001660
# 1559     minist                0.001631
# 668         key                0.001471
# 449       troll                0.001465
# 147      mirror                0.001427
# 2100        ter                0.001418
# 1471   gringott                0.001294
# 1394      stone                0.001287
# 243    ollivand                0.001285
# 161       princ                0.001205
# 172      dragon                0.001179

# %% [markdown]
# Define some covenient funtions for calculating divergence and distances.

# %%
def kl_divergence(X, Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    D_kl = scipy.stats.entropy(p, q)
    return D_kl

def chi2_divergence(X,Y):
    P = X.copy()
    Q = Y.copy()
    P.columns = ['P']
    Q.columns = ['Q']
    df = Q.join(P).fillna(0)
    p = df.iloc[:,1]
    q = df.iloc[:,0]
    return scipy.stats.chisquare(p, q).statistic

def Divergence(corpus1, corpus2, difference="KL"):
    """Difference parameter can equal KL, Chi2, or Wass"""
    freqP = nltk.FreqDist(corpus1)
    P = pandas.DataFrame(list(freqP.values()), columns = ['frequency'], index = list(freqP.keys()))
    freqQ = nltk.FreqDist(corpus2)
    Q = pandas.DataFrame(list(freqQ.values()), columns = ['frequency'], index = list(freqQ.keys()))
    if difference == "KL":
        return kl_divergence(P, Q)
    elif difference == "Chi2":
        return chi2_divergence(P, Q)
    elif difference == "KS":
        try:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency']).statistic
        except:
            return scipy.stats.ks_2samp(P['frequency'], Q['frequency'])
    elif difference == "Wasserstein":
        try:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None).statistic
        except:
            return scipy.stats.wasserstein_distance(P['frequency'], Q['frequency'], u_weights=None, v_weights=None)

# %% [markdown]
# Calculate Chi2 divergence.

# %%
Divergence(stoneProbArray, princeProbArray, difference="Chi2")
# Out:
# 2829.0

# %% [markdown]
# Calculate KS distance.

# %%
Divergence(stoneProbArray, princeProbArray, difference="KS")
# Out:
# 0.06432822060179366

# %% [markdown]
# Calculate Wasserstein distance.

# %%
Divergence(stoneProbArray, princeProbArray, difference="Wasserstein")
# Out:
# 8.429343726426966

# %% [markdown]
# ## Plot Distances

# %% [markdown]
# Next, I will extend my analysis to four Harry Potter books. In these four books, 'Stone', 'Goblet', and 'Prince' are the first, fourth and sixth book of HP series, respectively, while the last one book is a fanfiction of Harry Potter which written by a HP fan.
#
# I will plot the distances/divergence between these four books using heatmap. To this end, I will merge all the four corpus into one corpora.

# %%
hpCorpora = pandas.concat([hpStoneSentencesDF,hpGobletDF,hpPrinceDF,hpFanficDF])
hpCorpora
# Out:
#                                       normalized_tokens  \
# 0     [harri, potter, sorcer, stonechapt, oneth, boy...
# 1                                                  [mr]
# 2     [dursley, number, four, privet, drive, proud, ...
# 3     [lastpeopl, expect, involv, anyth, strang, mys...
# 4                                                  [mr]
# 5     [dursley, wa, director, firm, call, grun, made...
# 6     [wa, big, beefi, man, hardli, ani, neck, altho...
# 7                                                  [mr]
# 8     [dursley, wa, thin, blond, hadnearli, twice, u...
# 9     [dursley, small, son, call, dudley, theiropini...
# 10    [dursley, everyth, want, also, secret, andthei...
# 11                  [could, bear, anyon, found, potter]
# 12                                                 [mr]
# 13                                     [potter, wa, mr]
# 14        [dursley, sister, met, sever, year, fact, mr]
# 15    [dursley, pretend, sister, becaus, hersist, hu...
# 16    [dursley, shudder, think, neighbor, wouldsay, ...
# 17    [dursley, knew, thepott, small, son, never, ev...
# 18    [thi, boywa, anoth, good, reason, keep, potter...
# 19                                                 [mr]
# 20                                                 [mr]
# 21    [dursley, woke, dull, gray, tuesday, storystar...
# 22                                                 [mr]
# 23     [dursley, hum, pick, hi, bore, tie, forwork, mr]
# 24    [dursley, gossip, away, happili, wrestl, screa...
# 25    [none, notic, larg, tawni, owl, flutter, past,...
# 26                              [half, past, eight, mr]
# 27              [dursley, pick, hi, briefcas, peck, mr]
# 28    [dursley, cheek, tri, kiss, dudley, becaus, du...
# 29                            [littl, tyke, chortl, mr]
# ...                                                 ...
# 6379                         [hermion, ca, help, giggl]
# 6380                       [funni, draco, start, laugh]
# 6381  [harri, never, seen, laugh, like, befor, snick...
# 6382  [actual, sat, ground, put, face, hand, shout, ...
# 6383  [slowli, harri, start, smile, look, hermion, b...
# 6384  [sound, laughter, rise, pitch, drift, lake, la...
# 6385                       [refer, oh, said, dumbledor]
# 6386                                    [shout, realli]
# 6387                                         [blackadd]
# 6388  [meanwhil, continu, draco, drop, hogwart, beco...
# 6389                                                 []
# 6390              [come, back, yank, ribcag, wear, hat]
# 6391  [understood, understood, said, harri, grin, de...
# 6392                         [big, gold, star, imageri]
# 6393                                            [buffi]
# 6394                          [b, never, thought, like]
# 6395                   [alway, like, part, like, magic]
# 6396  [never, sit, around, think, love, abl, magic, ...
# 6397                                       [part, life]
# 6398  [lost, could, magic, anymor, alway, thought, c...
# 6399                  [goe, like, never, thought, like]
# 6400            [alway, thought, part, like, eye, hand]
# 6401  [go, around, think, love, eye, love, hand, thi...
# 6402                                       [mad, blind]
# 6403                                         [ca, talk]
# 6404                                             [feel]
# 6405                    [memor, speech, kid, want, use]
# 6406               [peril, gard, elizabeth, mari, pope]
# 6407  [illustr, document, drawn, monica, starl, exce...
# 6408                                                 []
#
#                                   normalized_tokens_POS  \
# 0     [(harri, NN), (potter, NN), (sorcer, NN), (sto...
# 1                                            [(mr, NN)]
# 2     [(dursley, NN), (number, NN), (four, CD), (pri...
# 3     [(lastpeopl, NN), (expect, VBP), (involv, NN),...
# 4                                            [(mr, NN)]
# 5     [(dursley, NN), (wa, NNS), (director, NN), (fi...
# 6     [(wa, NN), (big, JJ), (beefi, NN), (man, NN), ...
# 7                                            [(mr, NN)]
# 8     [(dursley, NN), (wa, NN), (thin, JJ), (blond, ...
# 9     [(dursley, RB), (small, JJ), (son, NN), (call,...
# 10    [(dursley, NN), (everyth, NN), (want, VBP), (a...
# 11    [(could, MD), (bear, VB), (anyon, RP), (found,...
# 12                                           [(mr, NN)]
# 13                   [(potter, NN), (wa, NN), (mr, NN)]
# 14    [(dursley, NN), (sister, NN), (met, VBD), (sev...
# 15    [(dursley, NN), (pretend, VBP), (sister, NN), ...
# 16    [(dursley, NN), (shudder, NN), (think, VBP), (...
# 17    [(dursley, NN), (knew, VBD), (thepott, RB), (s...
# 18    [(thi, NN), (boywa, NN), (anoth, RB), (good, J...
# 19                                           [(mr, NN)]
# 20                                           [(mr, NN)]
# 21    [(dursley, NN), (woke, VBD), (dull, JJ), (gray...
# 22                                           [(mr, NN)]
# 23    [(dursley, NN), (hum, NN), (pick, NN), (hi, NN...
# 24    [(dursley, NN), (gossip, NN), (away, RB), (hap...
# 25    [(none, NN), (notic, JJ), (larg, NN), (tawni, ...
# 26      [(half, NN), (past, JJ), (eight, CD), (mr, NN)]
# 27    [(dursley, NN), (pick, NN), (hi, NN), (briefca...
# 28    [(dursley, NN), (cheek, NN), (tri, NN), (kiss,...
# 29    [(littl, NN), (tyke, NN), (chortl, NN), (mr, NN)]
# ...                                                 ...
# 6379                                                NaN
# 6380                                                NaN
# 6381                                                NaN
# 6382                                                NaN
# 6383                                                NaN
# 6384                                                NaN
# 6385                                                NaN
# 6386                                                NaN
# 6387                                                NaN
# 6388                                                NaN
# 6389                                                NaN
# 6390                                                NaN
# 6391                                                NaN
# 6392                                                NaN
# 6393                                                NaN
# 6394                                                NaN
# 6395                                                NaN
# 6396                                                NaN
# 6397                                                NaN
# 6398                                                NaN
# 6399                                                NaN
# 6400                                                NaN
# 6401                                                NaN
# 6402                                                NaN
# 6403                                                NaN
# 6404                                                NaN
# 6405                                                NaN
# 6406                                                NaN
# 6407                                                NaN
# 6408                                                NaN
#
#       normalized_tokens_count  \
# 0                         7.0
# 1                         1.0
# 2                        12.0
# 3                         9.0
# 4                         1.0
# 5                         7.0
# 6                        12.0
# 7                         1.0
# 8                        20.0
# 9                        10.0
# 10                       12.0
# 11                        5.0
# 12                        1.0
# 13                        3.0
# 14                        7.0
# 15                        8.0
# 16                        8.0
# 17                        8.0
# 18                       12.0
# 19                        1.0
# 20                        1.0
# 21                       19.0
# 22                        1.0
# 23                        8.0
# 24                        9.0
# 25                        8.0
# 26                        4.0
# 27                        6.0
# 28                       13.0
# 29                        4.0
# ...                       ...
# 6379                      NaN
# 6380                      NaN
# 6381                      NaN
# 6382                      NaN
# 6383                      NaN
# 6384                      NaN
# 6385                      NaN
# 6386                      NaN
# 6387                      NaN
# 6388                      NaN
# 6389                      NaN
# 6390                      NaN
# 6391                      NaN
# 6392                      NaN
# 6393                      NaN
# 6394                      NaN
# 6395                      NaN
# 6396                      NaN
# 6397                      NaN
# 6398                      NaN
# 6399                      NaN
# 6400                      NaN
# 6401                      NaN
# 6402                      NaN
# 6403                      NaN
# 6404                      NaN
# 6405                      NaN
# 6406                      NaN
# 6407                      NaN
# 6408                      NaN
#
#                                                    text  \
# 0
# Harry Potter and the Sorcerer's StoneCHAPTER ...
# 1                                               and Mrs
# 2      Dursley, of number four, Privet Drive, were p...
# 13                                   [Potter, was, Mrs]          3.0
# 14    [Dursley, 's, sister, ,, but, they, had, n't, ...         17.0
# 15    [Dursley, pretended, she, did, n't, have, a, s...         23.0
# 16    [The, Dursleys, shuddered, to, think, what, th...         16.0
# 17    [The, Dursleys, knew, that, thePotters, had, a...         19.0
# 18    [This, boywas, another, good, reason, for, kee...         21.0
# 19                                           [When, Mr]          2.0
# 20                                           [and, Mrs]          2.0
# 21    [Dursley, woke, up, on, the, dull, ,, gray, Tu...         33.0
# 22                                                 [Mr]          1.0
# 23    [Dursley, hummed, as, he, picked, out, his, mo...         14.0
# 24    [Dursley, gossiped, away, happily, as, she, wr...         13.0
# 25    [None, of, them, noticed, a, large, ,, tawny, ...         13.0
# 26                       [At, half, past, eight, ,, Mr]          6.0
# 27    [Dursley, picked, up, his, briefcase, ,, pecke...          8.0
# 28    [Dursley, on, the, cheek, ,, and, tried, to, k...         26.0
# 29              [``, Little, tyke, ,, '', chortled, Mr]          7.0
# ...                                                 ...          ...
# 6379  [``, Hermione, !, '', ``, I, ca, n't, help, it...          NaN
# 6380  [``, It, 's, too, funny, !, '', And, now, Drac...          NaN
# 6381  [Harry, had, never, seen, him, laugh, like, th...          NaN
# 6382  [He, actually, sat, down, on, the, ground, ,, ...          NaN
# 6383  [Slowly, ,, Harry, started, to, smile, ,, and,...          NaN
# 6384  [The, sound, of, their, laughter, ,, rising, i...          NaN
# 6385  [References, :, 1, ), ``, Oh, ,, no, ,, '', sa...          NaN
# 6386           [``, All, down, to, shouting, ,, really]          NaN
# 6387                               [``, --, Blackadder]          NaN
# 6388  [2, ), ``, '', Meanwhile, ,, '', continued, Dr...          NaN
# 6389                             [``, --, The, X-Files]          NaN
# 6390  [3, ), ``, I, will, come, back, here, and, I, ...          NaN
# 6391  [Understood, ?, '', ``, Understood, ,, '', sai...          NaN
# 6392        [``, And, a, big, gold, star, for, imagery]          NaN
# 6393                                        [``, Buffy]          NaN
# 6394  [[, B, }, 4, ), [, /B, ], ``, I, just, never, ...          NaN
# 6395  [You, 've, always, been, like, a, part, of, me...          NaN
# 6396  [I, never, sit, around, thinking, about, how, ...          NaN
# 6397              [It, 's, just, a, part, of, my, life]          NaN
# 6398  [But, if, I, lost, it, --, if, I, could, n't, ...          NaN
# 6399  [It, goes, like, this, ,, ``, I, never, though...          NaN
# 6400  [I, always, thought, of, you, as, a, part, of,...          NaN
# 6401  [You, do, n't, go, around, thinking, 'I, love,...          NaN
# 6402                [To, be, mad, ,, or, to, be, blind]          NaN
# 6403                      [I, ca, n't, talk, about, it]          NaN
# 6404                             [It, 's, how, I, feel]          NaN
# 6405  [``, I, memorized, that, speech, when, I, was,...          NaN
# 6406  [The, Perilous, Gard, is, by, Elizabeth, Marie...          NaN
# 6407  [All, illustrations, in, this, document, were,...          NaN
# 6408                                                 []          NaN
#
# [43533 rows x 6 columns]

# %% [markdown]
# I failed in making texts from one same book into one row, like what formatted in the shakespare dataframe. So I don't know how to plot the distance based on the function provided in the code notebook. I will figure this out in the later days within this week and update the progress into github.
